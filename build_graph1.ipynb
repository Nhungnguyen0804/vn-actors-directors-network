# %%
# %%
#  các thư viện
# pip install -r requirements.txt

# %%
import json
# from collectionamespace import defaultdict, Counter, deque
import mwparserfromhell  
import xml.etree.ElementTree as ET
from tqdm import tqdm
import re

# %%
# TẬP HẠT GIỐNG
SEED_LIST_FILE = "seed_list.txt"

XML_FILE = "viwiki-latest-pages-articles.xml"

# %% [markdown]
# # ĐỌC FILE TẬP HẠT GIỐNG

# %% [markdown]
# ## read_seeds

# %%
def read_seeds(path):
    '''Đọc danh sách từ file, mỗi dòng là 1 trang wikipedia.'''
    seed_list = []
    with open(path, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line:  # Bỏ qua dòng trống
                seed_list.append(line)
    return seed_list

# test

print(read_seeds(SEED_LIST_FILE))

# %% [markdown]
# # ĐỌC TEXT TỪ FILE XML WIKIPEDIA

# %%



# %%
# đọc file XML wiki dump 

# mỗi bài viết trong thẻ <page> </page> 

    # Trả về danh sách [(title, text), ...]

# dùng iterparse (đọc từng phần nhỏ)


def read_pages_from_xml(xml_path):
    """
    Đọc từng trang trong file XML (Wikipedia dump).
    Trả về danh sách [(title, text), ...]
    """
    # danh sách lưu kết quả
    pages = []  
    # iterparse => đọc
    context = ET.iterparse(xml_path, events=("start", "end"))

    # Lấy namespace (ở thẻ <mediawiki>)
    event, root = next(context)
    
    if root.tag.startswith("{"):
        namespace = root.tag.split("}")[0].strip("{")
        namespace_prefix = f"{{{namespace}}}"
    else:
        namespace_prefix = ""

    
    # Duyệt từng p.tử trg XML
    for event, element in context:
        if event == "end" and element.tag == namespace_prefix + "page":
            title_element = element.find(f"./{namespace_prefix}title")
            text_element = element.find(f".//{namespace_prefix}text")
            
            # Lấy nd trg các thẻ, nếu k có thì None 
            if title_element is not None:
                title = title_element.text
            else:
                title = None

            if text_element is not None:
                text = text_element.text
            else:
                text = ''

            pages.append((title, text))  # thêm vào danh sách

            element.clear()  # xóa khỏi bộ nhớ

    return pages






# %%
all_pages = read_pages_from_xml(XML_FILE)

wiki_dict = {}
for title, text in all_pages:
    if title:
        wiki_dict[title] = text

def get_wikitext(title):
    """
    Lấy nội dung wikitext từ title
    k tìm thấy, trả về chuỗi rỗng
    """
    if title not in wiki_dict: return ""
    
    wikitext = wiki_dict[title]
    if wikitext.startswith("#đổi") or wikitext.startswith("#redirect"):
        start = wikitext.find('[[')
        end = wikitext.find(']]')
        if start != -1 and end != -1:
            new_title = wikitext[start+2:end].strip()
            return get_wikitext(new_title)

    return wikitext


# %% [markdown]
# ## generate_date_filename

# %%
from datetime import datetime

def generate_date_filename():
    now = datetime.now()
    filename = now.strftime("%d-%m-%Y_%H-%M-%S")
    return filename



# with open("test/test_wikitext.txt", "w", encoding="utf-8") as f:
#     f.write(get_wikitext("Ninh Dương Lan Ngọc"))

# %% [markdown]
# ## chung

# %%
#chung

def save_to_txt(content ,file_name = None, auto_name = False):
    if auto_name or file_name is None:
        file_name = generate_date_filename() 
         
    with open(f"test/{file_name}.txt", "w",  encoding="utf-8") as f:
        f.write(content) 

def save_to_json(content ,file_name = None,auto_name = False):
    if auto_name or file_name is None:
        file_name = generate_date_filename()
    with open(f"test/{file_name}.json", "w",  encoding="utf-8") as f:
        json.dump(content, f, ensure_ascii=False, indent=4)


def print_json_format(res):
    print(json.dumps(res, ensure_ascii=False, indent=4))

def df_to_dict(df, orient='records'):
    return df.to_dict(orient=orient), df.columns.tolist()

# %% [markdown]
# # TRÍCH XUẤT THÔNG TIN CƠ BẢN

# %% [markdown]
# ## extract_infobox_from_wikitext

# %%
def extract_infobox_from_wikitext(wikitext):
    
    if not wikitext:
        return {}
    try:
        # biến chuỗi wikitext => Wikicode obj
        code = mwparserfromhell.parse(wikitext)

    except Exception:
        return {}
    
    # duyệt qua toàn bộ cấu trúc wikitext, trả về list all các template (các khối {{ ... }})
    templates = code.filter_templates() 
   
    info = {}

    for template in templates:
        # template là obj

        # tên của template 
        name = str(template.name).lower()
        infoboxs = ["nhân vật", "phim", "diễn viên", "nghệ sĩ",  
                    "film", "truyền hình", "điện ảnh",
                    "television" , "person"]

        for infobox in infoboxs:
            if infobox in name.lower():
                # iterate params. in list tham so
                for param in template.params:
                    key = str(param.name).strip()
                    value = str(param.value).strip()
                    if key and value:
                        info[key] = value
                # break nếu k rỗng k false 
                if info:
                    break
    return info

# %% [markdown]
# ## check_type_of_infobox

# %%
def check_type_of_infobox(wikitext):
    if not wikitext:
        return {}
    try:
        # biến chuỗi wikitext => Wikicode object
        code = mwparserfromhell.parse(wikitext)

    except Exception:
        return {}
    
    templates = code.filter_templates() 

    # thông tin nhân vật => nhân vật
    person_keys = [
        "nhân vật", "diễn viên", "nghệ sĩ", "person"
    ]
    film_keys = [
        "phim", 
        "film",
        "truyền hình",
        "điện ảnh",
        'television'
    ]
    for template in templates:
        name = str(template.name).lower()
 
        for key in film_keys:
            if key in name.lower(): return "film"
        for key in person_keys:
            if key in name.lower(): return "person"
    return ""




# %%
#test
ndln_wikitext = get_wikitext("Ninh Dương Lan Ngọc")


#test 

matBiec_wikitext = get_wikitext("Mắt biếc (phim)")
print(matBiec_wikitext)
# save_to_txt(matBiec_wikitext,"test/test_film_wikitext")

matBiec_infobox = extract_infobox_from_wikitext(matBiec_wikitext)
print("type mat biec infobox",type(matBiec_infobox))
# save_to_json( matBiec_infobox,"test/test_film_infobox")


# %% [markdown]
# Wikipedia không nói rõ đâu là phim, đâu là người
# chỉ tiêu đề + cú pháp [[...]]
# 
# phân loại liên kết -> người / phim

# %% [markdown]
# ## is_vn_film_wikilink

# %%
# check xem 1 link là phim or k 
def is_vn_film_wikilink(link_title):
    if link_title is None or link_title.strip() == "":
        return False   
     
    # tức là link này k có dấu hiệu nhận biết tại tiêu đề
    # get text ra để check infobox 
    wikitext = get_wikitext(link_title)
    if (check_type_of_infobox(wikitext) == "film"):
        infobox = extract_infobox_from_wikitext(wikitext)
        infobox = {k.lower(): v for k, v in infobox.items()}

        country = None
        language = None

        # Lấy giá trị country / quốc gia
        for key in ['country', 'quốc gia']:
            if key in infobox:
                country = str(infobox[key]).lower()
                break

        # Lấy giá trị language / ngôn ngữ
        for key in ['language', 'ngôn ngữ']:
            if key in infobox:
                language = str(infobox[key]).lower()
                break

        # Ưu tiên country
        if country:
            if any(x in country for x in ['{{vie}}', '{{vn}}', '{{vnm}}', 'việt nam']):
                return True  # Quốc gia là Việt Nam => phim Việt Nam
            else:
                return False  # Quốc gia khác => không phải phim Việt Nam

        # Nếu không có country => dùng language để đoán
        if language and 'tiếng việt' in language:
            return True
        else:
            return "chưa rõ"
                
    

#test 
# is_vn_film_wikilink
# check_type_of_infobox
print(is_vn_film_wikilink("Cô gái từ quá khứ"))
print(is_vn_film_wikilink("Cánh đồng bất tận (phim)"))
print(is_vn_film_wikilink('Kong: Đảo Đầu lâu'))
print(is_vn_film_wikilink('Long Ruồi'))

print(is_vn_film_wikilink('Tèo em'))
print(is_vn_film_wikilink('Tấm Cám: Chuyện chưa kể'))

x = 'Vừa đi vừa khóc'
print(is_vn_film_wikilink(x))

x = 'Cô nàng bướng bỉnh'
print(is_vn_film_wikilink(x))



# %%
#test
print(check_type_of_infobox(x))
x1 = get_wikitext(x)
x2 = extract_infobox_from_wikitext(x1)
print(x2)

# %%
def df_to_filted_vn_film_dict(df):
    dicts, cols = df_to_dict(df)

    film_key = cols[1] # cột thứ 2: tựa phim
    filtered = []
    for d in dicts:
        value = d.get(film_key)
        if is_vn_film_wikilink(value):
            filtered.append(d)
    
    return filtered

# %% [markdown]
# ## is_vn_person_wikilink

# %%
# check 1 link la person or k

def is_vn_person_wikilink(link_title):
    if not link_title or not link_title.strip():
        return False

    wikitext = get_wikitext(link_title)
    if not wikitext:
        print(link_title, "ko có wikitext")
        return False

    # Không phải nhân vật, loại 
    if check_type_of_infobox(wikitext) != "person":
        print(link_title, "check_type_of_infobox không là person")
        return False

    # Lấy INFObox
    infobox = extract_infobox_from_wikitext(wikitext)
    infobox_lower = {k.lower(): str(v).lower() for k, v in infobox.items()}
    vn_keys = ["việt nam", "{{vie}}", "vietnam" ,"{{vnm}}"]

    # quốc tịch 
    for key in ["quốc tịch", "nationality"]:
        if key in infobox_lower:
            value = infobox_lower[key]
            if any(v in value for v in vn_keys):
                return True
            else:
                print(link_title, "quốc tịch KHÔNG phải VN → loại")
                return False

    # check toàn bộ value
    text_all = " ".join(infobox_lower.values()).lower()
    if any(v in text_all for v in vn_keys):
        return True

    # check template name 
    code = mwparserfromhell.parse(wikitext)
    template_names = " ".join(str(t.name).lower() for t in code.filter_templates())
    if any(v in template_names for v in vn_keys):
        return True
 
    if "người việt nam" in wikitext.lower().strip() or "người việt" in wikitext.lower().strip():
        print(link_title,"ko rõ quốc tịch, nhưng mô tả là người vn")
        return True

    # trang định hướng 
    if 'có thể' in wikitext or 'định hướng' in wikitext:
        print(link_title, "ko xác định đc wiki page (định hướng)")
        return False

    print(link_title, "không là người VN")
    return False


#test

# print(is_vn_person_wikilink("Ninh Dương Lan Ngọc"))
# print(is_vn_person_wikilink("Trần Nghĩa (diễn viên)"))
# print(is_vn_person_wikilink("Trúc Anh"))
# print(is_vn_person_wikilink("Victor Vũ"))
# print(is_vn_person_wikilink("Thanh Hiền"))
# print(is_vn_person_wikilink("Taylor Swift"))
print(is_vn_person_wikilink("Lương Thế Thành"))
print(is_vn_person_wikilink("Huy Cường"))
print(is_vn_person_wikilink("Hồng Thy"))

# %%
# print(get_wikitext("Trúc Anh"))
print(check_type_of_infobox(get_wikitext("Trúc Anh")))


# %% [markdown]
# ## unique_list

# %%
#chung
# Bỏ lặp, giữ đúng thứ tự 

def unique_list(items_list):

    seen_items = set()   # chứa các phần tử đã gặp
    result = []          # danh sách kết quả

    for item in items_list:
        if item not in seen_items:
            result.append(item)    # thêm vào kết quả
            seen_items.add(item)   # đánh dấu là đã gặp

    return result


#test 
print(unique_list(["Trấn Thành", "Ngô Thanh Vân", "Trấn Thành"]))

# %% [markdown]
# ## parse_heading

# %%
# == Danh sách phim == => {'level': 2, 'title': 'Danh sách phim'}
def parse_heading(line):
    line = line.strip() # clear space đầu cuối

    # k '=' ở đầu, cuối => pass
    if not line.startswith('=') or not line.endswith('='):
        return None  # không phải tiêu đề wiki

    # Đếm số '=' ở đầu và cuối
    left_eq = len(line) - len(line.lstrip('='))
    right_eq = len(line) - len(line.rstrip('='))

    if left_eq != right_eq: # ==abc===
        return None  # không cân đối, bỏ qua

    # Cắt phần tên tiêu đề ở giữa
    title = line[left_eq:len(line) - right_eq].strip()
    if not title: return None # k content 

    return {
        'level': left_eq, # số lượng '=' --> cấp độ title
        'title': title
    }

# Thử
lines = [
    "== Danh sách phim ==",
    "=== Điện ảnh ===",
    "==== Truyền hình ====",
    "Không phải tiêu đề",
]

for l in lines:
    result = parse_heading(l)
    if result:
        print(result)


# %% [markdown]
# ## is actor, is director

# %%
def is_actor(infobox_dict):
    # lay content của 2 cái ghép thàn 1 chuỗi, check keyword trong chuỗi => true
    job = (infobox_dict.get('công việc', '') 
           + infobox_dict.get('nghề nghiệp', '')
            + infobox_dict.get('occupation', '')
           ).lower()
    return 'diễn viên' in job

def is_director(infobox_dict):
    # true if nha lam phim
    job = (infobox_dict.get('công việc', '') 
           + infobox_dict.get('nghề nghiệp', '')
            + infobox_dict.get('occupation', '')
           ).lower()
    return 'nhà làm phim' in job

t0 = "Victor Vũ"
t1 = extract_infobox_from_wikitext(get_wikitext(t0))
print(t0,'--> actor:', is_actor(t1),'--> director', is_director(t1))
t0 = "Trấn Thành"
t1 = extract_infobox_from_wikitext(get_wikitext(t0))
print(t0,'--> actor:', is_actor(t1),'--> director', is_director(t1))
t0 = "Ngô Thanh Vân"
t1 = extract_infobox_from_wikitext(get_wikitext(t0))
print(t0,'--> actor:', is_actor(t1),'--> director', is_director(t1))
t0 = "Charlie Nguyễn"
t1 = extract_infobox_from_wikitext(get_wikitext(t0))
print(t0,'--> actor:', is_actor(t1),'--> director', is_director(t1))
t0 = "Lý Hải"
t1 = extract_infobox_from_wikitext(get_wikitext(t0))
print(t0,'--> actor:', is_actor(t1),'--> director', is_director(t1))
t0 = "Jun Vũ"
t1 = extract_infobox_from_wikitext(get_wikitext(t0))
print(t0,'--> actor:', is_actor(t1),'--> director', is_director(t1))


# %% [markdown]
# ## extract_films_section

# %%
# extract_films_section from wiki person 

def extract_films_section(wikitext,depth=0):
  

    # check là actor or director 
    infobox_dict = extract_infobox_from_wikitext(wikitext)
    type_node = check_type_of_infobox(wikitext)

    if type_node == 'film': return "==> ko extract films từ wiki film"
    if depth == 0 and is_actor(infobox_dict) == False and is_director(infobox_dict) == False: 
        return "person ko là actor cũng ko là director"
    
    """
    Tách phần wikitext thuộc tiêu đề cấp 2 (== ... ==)
    có 'phim' hoặc 'film' trong tiêu đề.
    Giữ nguyên wikitext gốc, chỉ so khớp tên tiêu đề ở dạng thường.
    Nếu section chỉ chứa liên kết {{chính|...}} thì đệ quy sang trang đó.
    """
    if not wikitext or depth > 2: return ""

    lines = wikitext.splitlines()

    headings = []  # lưu (index_dòng, heading_dict)

    for i, line in enumerate(lines):
        h = parse_heading(line)
        if h:
            headings.append((i, h))

    # chọn heading cấp 2 có từ "phim"/"film"
    chosen = None
    for i, h in headings:
        title_lower = h['title'].lower()
        if h['level'] == 2 and ('danh sách phim' in title_lower or 'phim' in title_lower or 'film' in title_lower):
            chosen = (i, h)
            break
        elif h['level'] == 2 and ('điện ảnh' in title_lower):
            chosen = (i, h)  
            # (51, {'level': 2, 'title': 'Sự nghiệp điện ảnh'})
            break
        elif h['level'] == 2 and ('sự nghiệp' in title_lower):
            chosen = (i, h)
            
            

    if not chosen: return ""

    start_line_index = chosen[0]
    chosen_level = chosen[1]['level'] # 2 => level 2 

    # tìm heading cấp 2 kế tiếp để biết điểm kết thúc
    end_line_index = len(lines)
    for i, h in headings:
        if i > start_line_index and h['level'] == chosen_level:
            end_line_index = i
            break

    # trích phần nội dung giữa hai heading
    section = "\n".join(lines[start_line_index + 1:end_line_index]).strip()
    
    # --- kiểm tra nếu chỉ là liên kết {{chính|...}} hoặc {{main|...}} ---
    main_re = re.search(r"\{\{\s*(?:chính|main)\s*\|\s*([^}|]+)", section, flags=re.IGNORECASE)
    if main_re:
        linked_title = main_re.group(1).strip()
        try:
            linked_wikitext = get_wikitext(linked_title)
            if linked_wikitext:
                # đệ quy sang trang phụ, tăng depth
                return extract_films_section(linked_wikitext, depth=depth + 1)
        except Exception as e:
            print("Lỗi khi lấy wikitext:", e)
    return section

# test
# print(extract_films_section(get_wikitext("Trấn Thành")))
# print(extract_films_section(get_wikitext("Victor Vũ")))
# print('================================')
# print(extract_films_section(get_wikitext("Nguyễn Hòa Bình (doanh nhân)")))
# print('================================')
# print(extract_films_section(get_wikitext("Lý Hải")))
# print('================================')
# print(extract_films_section(get_wikitext("Charlie Nguyễn")))
print('================================')
print(extract_films_section(get_wikitext("Jun Vũ")))

# %% [markdown]
# ## extract_films_from_subsection

# %%
def extract_films_from_subsection(film_section_wikitext):
    if not film_section_wikitext:
        return []

    lines = film_section_wikitext.splitlines()
    headings = []
    results = []
    # --- Thu thập các heading ---
    for i, line in enumerate(lines):
        h = parse_heading(line)
        if h:
            headings.append((i, h))

    # --- Lọc các heading level 3 ---
    level3_heads = [(i, h) for i, h in headings if h["level"] == 3]

    # --- k có heading cấp 3: toàn bộ là 1 phần (nếu có bảng) ---
    if not level3_heads:
        print("extract_films_from_subsection: Section không có heading cấp 3")
        if "{|" in film_section_wikitext:
            results.append({
                "title": "Phim",
                "subsection_wikitext": film_section_wikitext.strip()
            })
        return results

    # --- Có heading cấp 3: xử lý phần trc heading đầu tiên ---
    first_start = level3_heads[0][0]
    # lines là danh sách từng dòng (splitlines() cần nối trc heading 
    before_first = "\n".join(lines[:first_start]).strip()
    if before_first and before_first.startswith("{|"):
        results.append({
            "title": "Phim",
            "subsection_wikitext": before_first
        })
    # --- xử lý từng subsection có heading cấp 3 --- 
    for idx, (start_line, h) in enumerate(level3_heads):
        # xác định end_line là heading kế tiếp hoặc hết file
        end_line = len(lines)
        if idx + 1 < len(level3_heads):
            end_line = level3_heads[idx + 1][0]

        subsection = "\n".join(lines[start_line + 1:end_line]).strip()
        results.append({
            "title": h["title"].strip(),
            "subsection_wikitext": subsection
        })

   
    
    return results

#test
b0 ="Trấn Thành"
b1 = "Ninh Dương Lan Ngọc"
b2 = "Ngô Thanh Vân"
b2 = "Charlie Nguyễn"
b2 = "Jun Vũ"
a0 = b2
a1 = (extract_films_section(get_wikitext(a0)))
# print(a1)
a2= extract_films_from_subsection(a1)
print_json_format(a2)


# %% [markdown]
# ## extract_headers

# %%
def extract_headers(wikitext):
    """
    Trích xuất header hoàn chỉnh từ bảng wikitext (2 dòng header).
    Nếu có ! colspan="n" | HeaderCha thì bỏ HeaderCha, thay bằng n header con dòng dưới.
    """
    wikitext = re.sub(r'style\s*=\s*["\'].*?["\']', '', wikitext)

    lines = wikitext.strip().split('\n')
    header_lines = []
    
    # Lấy tất cả dòng header (bắt đầu bằng !)
    for line in lines:
        line = line.strip()
        if line.startswith('!'):
            header_lines.append(line)
       
    # print('@1__', header_lines)
    if not header_lines:
        return []

    # Xử lý từng dòng thành list các ô
    headers_res = []
    headers_row2 = []
    header_rowspan = False # mặc định header 1 dòng thôi, True là 2 dòng 

    if "rowspan" in header_lines[0]:
        header_rowspan = True
    
    hash_index = None
    for line in header_lines:
        if header_rowspan:
            # print('@2__',line) #! rowspan="2" |Năm
            # bỏ ! đi đã 
            line = line.replace("!",'').strip()
            if line.startswith('rowspan'):
                parts = line.split('|')
                # ['rowspan="2" ', 'Năm']
                headers_res.append(parts[1].strip())
                continue
            elif line.startswith('colspan'):
                headers_res.append('#')
                continue
            else:
                headers_row2.append(line.strip())

        else: 
            if line.startswith("!"):
                line = line[1:] # xóa kí tự đầu 
                columns = line.split('!!')
                for c in columns: headers_res.append(c)
                continue # add xong thì bỏ qa    
            
    for i, item in enumerate(headers_res):
        if item == '#':
            hash_index = i
            break   # nếu chỉ muốn vị trí đầu tiên của '#'
            
    if hash_index is not None:
        headers_res[hash_index:hash_index] = headers_row2 # chèn trước #
        headers_res.remove('#')  # xóa ký tự '#'

    return(headers_res)


#test
wikitext1 = """
|- style="background:#ccc; text-align:center;" 
! rowspan="2" style="width:33px;"|Năm
! rowspan="2" | Tựa đề
! colspan="2" |Vai trò
! rowspan="2" |Vai diễn
! rowspan="2" |Ghi chú
|-
! Đạo diễn
! Sản xuất
|-
"""

wikitext = '''
{| class="wikitable"
# !Năm!!Tựa phim!!Vai diễn!!Ghi chú
|-
'''
print(extract_headers(wikitext1))
print(extract_headers(wikitext))

print(extract_headers(a2[0]['subsection_wikitext']))

# %% [markdown]
# ## clean_wiki_markup

# %%
def clean_wiki_markup(text):
    code = mwparserfromhell.parse(text)

    # Nếu có wikilink [[...]]
    links = code.filter_wikilinks()
    if links:
        return str(links[0].title).strip()

    # Nếu có template {{...}}
    templates = code.filter_templates()
    if templates:
        return str(templates[0].name).strip()

    # Nếu không có gì đặc biệt
    return code.strip_code().strip()

print(clean_wiki_markup("[[Ngô Thanh Vân]] là [[đạo diễn]]"))
print(clean_wiki_markup('[[Ninh Dương Lan Ngọc]]'))
print(clean_wiki_markup('{{Không}}'))
print(clean_wiki_markup("''ABC''"))

# %%
def parse_span(token):
    """
    Nhận 1 token dạng 'rowspan="2" | dữ liệu' hoặc chỉ dữ liệu
    Trả về (rowspan, colspan, data)
    """
    rowspan = 1
    colspan = 1
    data = token.strip()
    
    # Kiểm tra xem có rowspan/colspan không
    parts = data.split('|', 1)  # split 1 lần, còn lại là data
    attr = parts[0].strip()
    
    # check rowspan
    if 'rowspan' in attr:
        try:
            # loại bỏ ký tự thừa
            value = ''.join(c for c in attr if c.isdigit())
            rowspan = int(value)
        except:
            pass
        data = parts[1].strip() if len(parts) > 1 else ''
    
    # check colspan
    if 'colspan' in attr:
        try:
            value = ''.join(c for c in attr if c.isdigit())
            colspan = int(value)
        except:
            pass
        data = parts[1].strip() if len(parts) > 1 else ''
    
    return rowspan, colspan, data

# Test
lines = [
    '|2001',
    "|''Hương dẻ''",
    '| {{Không}}',
    '| {{Không}}',
    '|Na lớn',
    '|rowspan="2" |phim truyền hình',
    '|2004',
    "|''Rouge''",
]

for line in lines:
    if line.startswith('|'):
        r, c, d = parse_span(line[1:])
        print(r, c, d)

# %%
#split_top_level_double tách dòng theo || nhưng bỏ qua những || nằm trong [[...]] hoặc {{...}}
# split theo ||
def split_theo_gach_kep(s):
    """
    Split string s on top-level '||' occurrences (ignore those inside [[...]] or {{...}}).
    Returns list of segments.
    """
    segs = []
    buf = []
    i = 0
    n = len(s)
    # nesting counters for [[...]] and {{...}} and also [ and ] and { and }
    brack = 0
    curl = 0
    squote = 0
    while i < n:
        # check for '[[' or ']]', '{{' or '}}'
        if s.startswith('[[', i):
            brack += 1
            buf.append('[[')
            i += 2
            continue
        if s.startswith(']]', i):
            if brack > 0: brack -= 1
            buf.append(']]'); i += 2; continue
        if s.startswith('{{', i):
            curl += 1
            buf.append('{{'); i += 2; continue
        if s.startswith('}}', i):
            if curl > 0: curl -= 1
            buf.append('}}'); i += 2; continue

        # top-level '||' when not inside brackets/templates
        if s.startswith('||', i) and brack == 0 and curl == 0:
            segs.append(''.join(buf).strip())
            buf = []
            i += 2
            continue

        buf.append(s[i])
        i += 1

    segs.append(''.join(buf).strip())
    return segs

def find_top_level_pipe(s):
    """
    Find index of first top-level '|' used as attribute/value separator,
    ignoring '|' inside [[...]] or {{...}}.
    Returns index or -1 if none.
    """
    i = 0
    n = len(s)
    brack = 0
    curl = 0
    while i < n:
        if s.startswith('[[', i):
            brack += 1; i += 2; continue
        if s.startswith(']]', i):
            if brack > 0: brack -= 1
            i += 2; continue
        if s.startswith('{{', i):
            curl += 1; i += 2; continue
        if s.startswith('}}', i):
            if curl > 0: curl -= 1
            i += 2; continue

        # single '|' char (not '||' because those were handled earlier)
        if s[i] == '|' and brack == 0 and curl == 0:
            return i
        i += 1
    return -1

a5 ='[[abc||cvd]]||abc||efd|b'
print(split_theo_gach_kep(a5))

# %% [markdown]
# ## wikitable_to_df

# %%
import mwparserfromhell
import re
import pandas as pd

import re


def wikitable_to_df(wikitext, headers):
    lines = wikitext.strip().split('\n')
    
    # số cột
    num_cols = len(headers)

    table_rows = []          # danh sách các dòng đã parse
    rowspan_tracker = {}     # theo dõi các ô có rowspan còn kéo dài
    
    current_row_index = -1        # chỉ số hàng đang xử lý
    for line in lines:
        line = line.strip()
      
        # {| class wikitable or open table => pass
        if not line or(line.startswith("{|")): continue
        # end of table
        if line.startswith("|}") or line == "}" or line == "|}" :
            break
        # ---Thêm dòng mới trống:
        # ---đại diện cho 1 hàng dữ liệu mới sắp được điền.
        if line.startswith('|-'):
            table_rows.append([None]*num_cols) #grid = [[None, None, None]]
            current_row_index += 1 #0
            # --- Áp dụng các ô rowspan còn hiệu lực cho dòng hiện tại ---
            for key in list(rowspan_tracker.keys()):
                start_row, col = key
                remaining_rows, value = rowspan_tracker[key]

                # Nếu dòng hiện tại nằm sau dòng bắt đầu rowspan
                if current_row_index > start_row and remaining_rows > 0:
                    # Nếu ô ở vị trí này đang trống thì điền giá trị
                    if table_rows[current_row_index][col] is None:
                        table_rows[current_row_index][col] = value

                    # Giảm số dòng còn lại của rowspan đi 1
                    remaining_rows -= 1
                    if remaining_rows <= 0: del rowspan_tracker[key]
                    else: rowspan_tracker[key] = (remaining_rows, value)

            continue
        
        if line.startswith('!'): continue # pass
        # dòng dữ liệu bình thường bắt đầu bằng '|' 
        if (line.startswith('|')):
            # đảm bảo có một hàng hiện tại; else hãy tạo một hàng (xử lý các bảng bỏ qua '|-' ban đầu) 
            if current_row_index == -1: 
                table_rows.append([None] * num_cols) 
                current_row_index = 0
            # xóa | ở đầu dòng đi
            line = line[1:].strip() 
            # chia thành các phân đoạn '||'
            segments = split_theo_gach_kep(line)

            # --- Tìm vị trí cột trống đầu tiên trong hàng hiện tại ---
            row = table_rows[current_row_index]
            # tìm cột trống đầu tiên để bắt đầu chèn , update col_index khi chèn 
            col_index = 0
            while col_index < num_cols and row[col_index] is not None:
                col_index += 1

            for seg in segments:
                if seg == '':
                    # empty cell => treat as empty string
                    rowspan, colspan, data = 1, 1, ''
                else:
                    rowspan, colspan, data = parse_span(seg)
                
                cell_value = clean_wiki_markup(data)
                # Tìm col_index khả dụng tiếp theo trong trường hợp cột trước đã bị chiếm bởi rowspan/colspan.
                while col_index < num_cols and row[col_index] is not None:
                    col_index += 1
                if col_index >= num_cols:
                    # no space left: skip (or break)
                    break
                # gán giá trị cho cell, theo colspan
                for i in range(colspan):
                    if col_index + i < num_cols:
                        row[col_index + i] = cell_value
                # nếu rowspan > 1 -> lưu lại để áp dụng cho các hàng tiếp theo, remaining rows = rowspan - 1
                if rowspan > 1:
                    rowspan_tracker[(current_row_index, col_index)] = (rowspan - 1, cell_value)
                #tăng các col index qa các cell đã đặt 
                col_index += colspan
            continue

        continue

        
            
    
    # --- Tạo DataFrame ---
    # bỏ các hàng toàn None
    table_rows = [r for r in table_rows if not all(v is None for v in r)]
    df = pd.DataFrame(table_rows, columns=headers)
    return df

# --- Sử dụng ---

#test 
b0 ="Trấn Thành"
b1 = "Ninh Dương Lan Ngọc"
b2 = "Ngô Thanh Vân"
a0 = b2
a1 = (extract_films_section(get_wikitext(a0)))
a2= extract_films_from_subsection(a1)
# print_json_format(a2)

# Tự lấy headers
headers = extract_headers(a2[0]['subsection_wikitext'])
print("Headers:", headers)

# Parse table
df = wikitable_to_df(a2[0]['subsection_wikitext'], headers)
print(df)
save_to_txt(str(df), auto_name = True)


# %% [markdown]
# ## extract_films_from_person_wikitext

# %%
def extract_films_from_person_wikitext(wikitext):
    '''
    wikitext - all
    wikitext - section chứa mọi phim
    wikitext - section từng loại phim 
        [
            {
                "title": "Phim điện ảnh",
                "subsection_wikitext": "{| class=\"wikitable\"\n|- style=\"background:#ccc; text-align:center;\"\n! rowspan=\"2\" style=\"width:33px;\"|Năm\n! rowspan=\"2\" | Tựa đề\n! colspan=\"2\" |Vai trò\n! rowspan=\"2\" |Vai diễn\n! rowspan=\"2\" |Ghi chú\n|-\n! Đạo diễn\n! Sản xuất\n|-\n|2001\n|''Hương dẻ''\n| {{Không}}\n| {{Không}}\n|Na lớn\n|rowspan=\"2\" |phim truyền hình\n|-\n|2004\n|''Rouge''\n| {{Không}}\n| {{Không}}\n|Thủy\n|-\n| rowspan=\"3\" | 2006\n|''Ngôi nhà bí ẩn''\n| {{Không}}\n| {{Không}}\n|Đạo diễn Trúc\n|\n|-\n|''2 trong 1''\n| {{Không}}\n| {{Không}}\n|Như Lan\n| \n|-\n|''Chuyện tình Sài Gòn''\n| {{Không}}\n| {{Không}}\n|Tâm\n|2008 chiếu ở Việt Nam\n|-\n|2007\n|''[[Dòng máu anh hùng]]''\n| {{Không}}\n| {{Không}}\n|Võ Thanh Thúy\n|\n|-\n|2009\n|''[[Bẫy rồng]]''\n| {{Không}}\n| {{Không}}\n|Trinh / Phượng hoàng\n|\n|-\n|2010\n|''Biệt đội ưng biển''\n| {{Không}}\n| {{Không}}\n|Nữ cảnh sát đa quốc gia Tú Mi\n|\n|-\n|2011\n|''Khao khát đỉnh cao''\n| {{Không}}\n| {{Có}}\n|Ngô Thanh Vân\n|phim tài liệu của [[365daband|365]] (nhóm nhạc do cô thành lập)\n|-\n| rowspan=\"3\" |2012\n|''Ngọc viễn đông''\n| {{Không}}\n| {{Không}}\n|Huyên\n|\n|-\n|''[[Ngôi nhà trong hẻm]]''\n| {{Không}}\n| {{Không}}\n|Thảo\n|-\n|''Hành trình''\n| {{Không}}\n| {{Không}}\n|Người chị\n|Phim ngắn\n|-\n|2013\n|''[[Lửa Phật]]''\n| {{Không}}\n| {{Không}}\n|Ánh\n|\n|-\n|2015\n|''Ngày nảy ngày nay''\n| {{Không}}\n| {{Có}}\n|Đan Nương\n|\n|-\n| rowspan=\"3\" |2016\n|''[[Siêu trộm (phim)|Siêu trộm]]''\n| {{Không}}\n| {{Không}}\n|Kỳ\n|Vai diễn khách mời\n|-\n|''Ngọa hổ tàng long 2''\n| {{Không}}\n| {{Không}}\n|Mantis\n|\n|-\n|''[[Tấm Cám: Chuyện chưa kể]]''\n| {{Có}}\n| {{Có}}\n|Dì ghẻ\n|\n|-\n| rowspan=\"4\" |2017\n|''[[Blade & Soul|Blade & Soul: Sứ mệnh người được chọn]]''\n| {{Không}}\n| {{Không}}\n|Sát thủ\n|Phim ngắn\n|-\n|''[[Cô Ba Sài Gòn]]''\n| {{Không}}\n| {{Có}}\n|Bà Thanh Mai\n|\n|-\n|''[[Star Wars: Jedi cuối cùng]]''\n| {{Không}}\n| {{Không}}\n|Paige Tico\n|\n|-\n|''[[Chiếc đũa quyền năng]]''\n| {{Không}}\n| {{Không}}\n|Tien\n|\n|-\n| rowspan=\"2\" |2018\n|''[[Về quê ăn Tết]]''\n| {{Không}}\n| {{Có}}\n|Đậu Xanh\n|\n|-\n|''[[Song lang (phim)|Song lang]]''\n| {{Không}}\n| {{Có}}\n|\n|\n|-\n|2019\n|''[[Hai Phượng]]''\n| {{Không}}\n| {{Có}}\n|Hai Phượng\n|\n|-\n| rowspan=\"3\" |2020\n|''Chim ưng đen''\n| {{Không}}\n| {{Có}}\n| Điệp vụ Hương\n| Phim ngắn\n|-\n|''[[Năm chiến hữu]]''\n| {{Không}}\n| {{Không}}\n|Hanoi Hannah\n|\n|-\n|''[[The Old Guard: Những chiến binh bất tử]]''\n| {{Không}}\n| {{Không}}\n|Quỳnh\n|\n|-\n|2021\n|''[[Trạng Tí phiêu lưu ký]]''\n| {{Không}}\n| {{Có}}\n|\n|\n|-\n| rowspan=\"2\" |2022\n|''The Princess''\n| {{không}}\n| {{không}}\n| Linh\n|\n|-\n|''[[Thanh Sói – Cúc dại trong đêm]]''\n| {{Có}}\n| {{Có}}\n|Dì Lin \"Jacqueline\"\n|\n|-\n|2023\n| ''[[Kẻ kiến tạo]]''\n| {{Không}}\n| {{Không}}\n| Kami\n|\n|-\n|2025\n| ''The Old Guard 2''\n| {{Không}}\n| {{Không}}\n| Quỳnh\n|\n|-\n|}"
            },
            {
                "title": "Chương trình truyền hình",
                "subsection_wikitext": "* 2009: ''[[Hành trình kết nối những trái tim]]''\n* 2010: ''[[Bước nhảy hoàn vũ (2010)|Bước nhảy hoàn vũ]]''\n* 2012, 2013: ''[[Thử thách cùng bước nhảy (chương trình truyền hình)|Thử thách cùng bước nhảy]]'' (giám khảo)\n* 2013: ''[[Project Runway Vietnam: Nhà thiết kế Thời trang Việt Nam|Project Runway Vietnam]]'' (dẫn chương trình)"
            },
            {
                "title": "Diễn xuất trong MV",
                "subsection_wikitext": "* Awakening ([[365daband|365]])\n* Ác mộng ([[365daband|365]])\n* Chia xa ([[Tuấn Hưng]])\n* Dạ khúc cho tình nhân ([[Đàm Vĩnh Hưng]])\n* Dẫu tình đã xa ([[Minh Thuận]]) \n* Hai cô tiên ([[365daband|365]]) (cảnh trong phim ''Ngày nảy ngày nay'')\n* Hai cô tiên (Dance version) ([[365daband|365]])\n* Merry Christmas ([[365daband|365]])\n* Mưa (Avi Kim Anh)\n* Ngọc Lan ([[Trần Thu Hà]])\n* Về quê ăn Tết ([[Jun Phạm]])"
            }
        ]
    
    '''
    
    all_films_section = extract_films_section(wikitext)
    
    films_from_subsection_dict = extract_films_from_subsection(all_films_section)
    films_by_type = {}  # dict kết quả cuối cùng

    for subsection in films_from_subsection_dict:
        type_name = subsection["title"]  # ví dụ: "Phim điện ảnh"
        sub_wikitext = subsection["subsection_wikitext"].strip()

        # --- Nếu không phải bảng wikitable thì bỏ qua ---
        if not sub_wikitext.startswith("{|"):
            print(f"Bỏ qua '{type_name}' (không phải bảng wikitable)")
            continue

        # --- Xử lý bảng wikitable ---
        headers = extract_headers(sub_wikitext)
        df_films = wikitable_to_df(sub_wikitext, headers)
        films_dict = df_to_filted_vn_film_dict(df_films)

        # --- Ghi vào dict kết quả ---
        films_by_type[type_name] = films_dict
        

    return films_by_type

#test 
print_json_format(extract_films_from_person_wikitext(get_wikitext("Trấn Thành")))
# print_json_format(extract_films_from_person_wikitext(ndln_wikitext))

# %% [markdown]
# ## get_all_films_from_films_dict

# %%
def get_all_films_from_films_dict(films_dict):
    all_films = []
    for type_name, films in films_dict.items():
        for film in films:
            # thêm thông tin loại phim để dễ phân biệt
            film_with_type = film.copy()
            film_with_type["Type_film"] = type_name
            all_films.append(film_with_type)
    return all_films

#test
k0 = extract_films_from_person_wikitext(get_wikitext("Trấn Thành"))
k1 = get_all_films_from_films_dict(k0)

k0 = extract_films_from_person_wikitext(ndln_wikitext)
k1 = get_all_films_from_films_dict(k0)

for f in k1:
    print(f)

# %% [markdown]
# ## extract_cast_section

# %%
# def extract_cast_section(wikitext):
#     text_lower = wikitext.lower()
    
#     # == dien vien == , ==dien vien== 
#     keywords = [
#         "== diễn viên ==",
#         "==diễn viên==",
#     ]

#     # tìm vị trí tiêu đề '== diễn viên =='
#     start_position = -1
#     for k in keywords: 
#         pos = text_lower.find(k)
#         if pos != -1:
#             start_position = pos
#             key = k
#             break

    
    
#     if start_position == -1: return "" # str rỗng, ko có 

#     # cắt phần vb sau title dvien
#     content = wikitext[start_position + len(key):] 

#     # tìm vị trí tiêu đề tiếp theo (== ... ==)
#     end_position = content.find("==")
#     if end_position != -1: section = content[:end_position] 
#     else: section = content # k có title next -> lay het 

#     return section.strip() # delete space thừa


# print(extract_cast_section(matBiec_wikitext))

# %%
#test

nhaBaNu = get_wikitext("Nhà bà Nữ")

# %% [markdown]
# ## extract_cast_list

# %%
# import re
# def extract_cast_list(wikitext):
#     wikicode = mwparserfromhell.parse(wikitext)
#     cast_list = []

#     # lay all dòng begin * :*[[Trúc Anh]]
#     lines = []
#     # duyệt từng node => chuyển node thành chuỗi, bỏ khoảng trắng thừa => if line begin * -> add vào lines

#     # default 
#     actor_name_list = []
#     character_list = []
    
#     for node in wikicode.nodes:  
#         # bỏ qa mọi dạng template {{...}}
#         if node.__class__.__name__ == "Template": continue

#         text = str(node).strip()  

#         if ("*" in text) or (not text):
#             continue
        
#         # lấy những line begin [[ , vai 
#         # [[Trúc
#         # vai Hà Lan
#         if text.startswith('[[Tập tin:'): continue       
#         if text.startswith('[['):       
#             if ("[[" in text) and ("]]" in text):
#                 text = text.replace("[[", "").replace("]]", "")
#                 if "|" in text:
#                     text = text.split("|")[0].strip()      
#             actor_name_list.append(text)

#         if (text.startswith('vai')) or (text.startswith('trong vai')):
          
#             match = re.search(r"vai\s+([^,.:]+)", text)
          
#             if match: 
#                 text = match.group(1).strip()
#                 # if res begin "trong", bỏ trong
#                 if text.startswith("trong "):
#                     text = text[6:].strip()

#                 character_list.append(text)
#             else: print("Không tìm thấy vai")


#     for actor, character in zip(actor_name_list, character_list):
#         actor_obj = {
#             "actor_name": actor,
#             "character": character
#         }
#         # add list
#         cast_list.append(actor_obj)

    
#     return cast_list


# #test 

# print(extract_cast_list(extract_cast_section(matBiec_wikitext)))
# print(len(extract_cast_list(extract_cast_section(matBiec_wikitext))))



# %%
# #test 

# print(extract_cast_list(extract_cast_section(nhaBaNu)))

# %% [markdown]
# [[Tập tin:Mắt biếc – Behind the scenes (2).png|nhỏ|Dàn diễn viên phim ''Mắt biếc'']] 
#  
# * 
# [[Trần Nghĩa (diễn viên)|Trần Nghĩa]] 
# vai Ngạn: 

# %% [markdown]
# ## extract_actors_from_film

# %%
# def extract_actors_from_film(wikitext):
#     # Trích danh sách diễn viên từ '== Diễn viên ==' của wikitext phim
#     cast_section = extract_cast_section(wikitext)
    
#     #list 
#     cast_list = extract_cast_list(cast_section)
#     # {name: , char: }


#     vn_cast_list = []
#     for cast in cast_list:
#         actor_name = cast.get('actor_name')  # lấy tên diễn viên
#         if not actor_name: continue  # bỏ qua 

#         if is_vn_person_wikilink(actor_name):
#             vn_cast_list.append(cast)
        
#     return vn_cast_list

# #test
# matBiec_actors = extract_actors_from_film(matBiec_wikitext)

# print(matBiec_actors)

# %% [markdown]
# ## extract_directors_from_film

# %%
def extract_directors_from_film(wikitext):
    infobox = extract_infobox_from_wikitext(wikitext)
    # Đưa tất cả key về lowercase 
    infobox = {k.lower(): v for k, v in infobox.items()}

    possible_keys = ['đạo diễn', 'director', 'directors']
    director = None
    for key in possible_keys:
        if key in infobox:
            director = infobox[key]
            break
        
    if not director:
        return None

    # Parse wikicode từ giá trị của trường đạo diễn
    wikicode = mwparserfromhell.parse(director)
    directors = []

    for link in wikicode.filter_wikilinks():
        # Lấy phần title trong [[title|...]]
        title = str(link.title).strip()
        if title:
            directors.append(title)

    # Nếu không có wikilink => bỏ qua
    if not directors:
        return "đạo diễn không có wikilink"

    return directors if len(directors) > 1 else directors[0]

#test
print(extract_directors_from_film(matBiec_wikitext))

# %%
SEED_LIST = read_seeds(SEED_LIST_FILE)

print(SEED_LIST)

# %%
# print(extract_actors_from_film(get_wikitext("Dòng máu anh hùng")))

# %%
# print(extract_actors_from_film(get_wikitext("Bộ tứ báo thủ")))

# %%
def clean_infobox_markup(text):
    """
    Làm sạch wiki markup trong infobox:
    Giữ lại text hiển thị, bỏ [[link]], {{template}}, thẻ HTML, ký hiệu...
    """
    if not text:
        return ""

    code = mwparserfromhell.parse(text)

    # Wikilinks [[abc]] , [[abc|xyz]]
    for link in code.filter_wikilinks():
        display = str(link.text or link.title)
        text = text.replace(str(link), display)

    # Templates {{...}} 
    for tpl in code.filter_templates():
        name = tpl.name.strip().lower()

        # {{VIE}} or {{vi}} → Việt Nam
        if name in ("vie", "vi", "vietnam"):
            text = text.replace(str(tpl), "Việt Nam")

        # {{birth date and age|1995|06|04}} → 1995-06-04
        elif name.startswith("birth date"):
            try:
                y, m, d = [tpl.get(i).value.strip() for i in range(1, 4)]
                text = text.replace(str(tpl), f"{y}-{m.zfill(2)}-{d.zfill(2)}")
            except Exception:
                text = text.replace(str(tpl), "")

        # {{flatlist|...}}, {{plainlist|...}}, {{hlist|...}}
        elif name in ("flatlist", "plainlist", "hlist", "ubl"):
            try:
                inner = str(tpl.get(1)).replace("\n", " ").replace("*", " ")
                text = text.replace(str(tpl), inner.strip())
            except Exception:
                text = text.replace(str(tpl), "")

        # {{flag|VIE}} → Việt Nam
        elif name == "flag":
            try:
                text = text.replace(str(tpl), str(tpl.get(1)).strip())
            except Exception:
                text = text.replace(str(tpl), "")

        else:
            text = text.replace(str(tpl), "")

    # Xóa thẻ HTML và ký hiệu 
    text = re.sub(r"<ref[^>]*>.*?</ref>", "", text, flags=re.DOTALL)
    text = re.sub(r"<!--.*?-->", "", text, flags=re.DOTALL)  # comment
    text = re.sub(r"<br\s*/?>", ", ", text)  # xuống dòng -> dấu phẩy
    text = re.sub(r"<[^>]+>", "", text)  # thẻ còn lại
    text = re.sub(r"'{2,}", "", text)  # '' hoặc ''' in nghiêng/đậm
    text = re.sub(r"&[a-z]+;", " ", text)  # ký hiệu HTML

    # Làm gọn lại khoảng trắng
    text = re.sub(r"\s+", " ", text).strip()

    return text


print(clean_infobox_markup("[[Ngô Thanh Vân]] là [[đạo diễn]]"))
print(clean_infobox_markup("[[Phim điện ảnh|Phim]] do [[Ngô Thanh Vân]] đạo diễn"))
print(clean_infobox_markup("[[A]] và [[B]] là [[C]]"))
print(clean_infobox_markup('[[Đại học Assumption (Thái Lan)|Đại học Assumption]]'))
print(clean_infobox_markup('[[Hà Nội]], [[Việt Nam]]'))
print(clean_infobox_markup('[[Hà Nội]], [[Việt Nam]]'))




# %% [markdown]
# ## test

# %%
#test
z1 = "Ngô Thanh Vân"
z2 = extract_films_from_person_wikitext(get_wikitext(z1))
print(z1,get_all_films_from_films_dict(z2))

print('=========================================================')

z1 = "Lý Hải"
z2 = extract_films_from_person_wikitext(get_wikitext(z1))
print(z1,get_all_films_from_films_dict(z2))

print('=========================================================')

z1 ="Victor Vũ"
z2 = extract_films_from_person_wikitext(get_wikitext(z1))
print(z1,get_all_films_from_films_dict(z2))
print( '=========================================================')

z1 = "Trấn Thành"
z2 = extract_films_from_person_wikitext(get_wikitext(z1))
print(z1,get_all_films_from_films_dict(z2))

print('=========================================================')

z1 = "Charlie Nguyễn"
z2 = extract_films_from_person_wikitext(get_wikitext(z1))
print(z1,get_all_films_from_films_dict(z2))

print('=========================================================')

z1 = "Jun Vũ"
z2 = extract_films_from_person_wikitext(get_wikitext(z1))
print(z1,get_all_films_from_films_dict(z2))

# %%
def clean_infobox_wikidict(data):
    cleaned_dict = {}
    for key in data:
        value = data[key]
        cleaned_value = clean_infobox_markup(value)
        cleaned_dict[key] = cleaned_value
    return cleaned_dict

#test 

h = "Ninh Dương Lan Ngọc"
h0 = get_wikitext(h)
h1 = extract_infobox_from_wikitext(h0) 
print(h1)
h2 = clean_infobox_wikidict(h1)
print(h2)

# %% [markdown]
# ## get actor

# %%
def is_film_infobox(infobox_dict):
    # neu la infobox của actor, director => ko là infobox film => False 
    if is_actor(infobox_dict) or is_director(infobox_dict): 
        print('=>is_film_infobox: là infobox actor/director, ko là film')
        return False
    keyword = "phim"
    for k, v in infobox_dict.items():
        if keyword in str(k).lower() or keyword in str(v).lower():
            return True
    return False

#test
print('ndln','-->',is_film_infobox(extract_infobox_from_wikitext(ndln_wikitext)))

c = "Mùi ngò gai"
c1 = get_wikitext(c)
c2 = extract_infobox_from_wikitext(c1)
c3 = is_film_infobox(c2)
print(c,'-->',c3)

c = "Mắt biếc (phim)"
c1 = get_wikitext(c)
c2 = extract_infobox_from_wikitext(c1)
c3 = is_film_infobox(c2)
print(c,'-->',c3)

 
c = "Gia sư nữ quái"
c1 = get_wikitext(c)
c2 = extract_infobox_from_wikitext(c1)
c3 = is_film_infobox(c2)
print(c,'-->',c3)

p1 = "Cổng mặt trời (phim truyền hình)"
c = p1
c1 = get_wikitext(c)
c2 = extract_infobox_from_wikitext(c1)
c3 = is_film_infobox(c2)
print(c,'-->',c3)

# %%
# extract_films_section from wiki person 

def extract_actors_section(wikitext,depth=0):
  

    # check là actor or director 
    infobox_dict = extract_infobox_from_wikitext(wikitext)
    
    if depth == 0 and not is_film_infobox(infobox_dict): 
        return "==> cần extract actor mà wikitext ko là film"
    
    """
    Tách phần wikitext thuộc tiêu đề cấp 2 (== ... ==)
    có 'diễn viên' hoặc 'actor' trong tiêu đề.
    Giữ nguyên wikitext gốc, chỉ so khớp tên tiêu đề ở dạng thường.
    Nếu section chỉ chứa liên kết {{chính|...}} thì đệ quy sang trang đó.
    """
    if not wikitext or depth > 2: return ""

    lines = wikitext.splitlines()

    headings = []  # lưu (index_dòng, heading_dict)

    for i, line in enumerate(lines):
        h = parse_heading(line)
        if h:
            headings.append((i, h))

    # chọn heading cấp 2 có từ "phim"/"film"
    chosen = None
    for i, h in headings:
        title_lower = h['title'].lower()
        if h['level'] == 2 and ('diễn viên' in title_lower 
                                or 'actor' in title_lower 
                                or 'actors' in title_lower 
                                or 'nhân vật' in title_lower
                                or 'character' in title_lower):
            chosen = (i, h)
            break
        

    if not chosen: return ""

    start_line_index = chosen[0]
    chosen_level = chosen[1]['level'] # 2 => level 2 

    # tìm heading cấp 2 kế tiếp để biết điểm kết thúc
    end_line_index = len(lines)
    for i, h in headings:
        if i > start_line_index and h['level'] == chosen_level:
            end_line_index = i
            break

    # trích phần nội dung giữa hai heading
    section = "\n".join(lines[start_line_index + 1:end_line_index]).strip()
    
    # --- kiểm tra nếu chỉ là liên kết {{chính|...}} hoặc {{main|...}} ---
    main_re = re.search(r"\{\{\s*(?:chính|main)\s*\|\s*([^}|]+)", section, flags=re.IGNORECASE)
    if main_re:
        linked_title = main_re.group(1).strip()
        try:
            linked_wikitext = get_wikitext(linked_title)
            if linked_wikitext:
                # đệ quy sang trang phụ, tăng depth
                return extract_actors_section(linked_wikitext, depth=depth + 1)
        except Exception as e:
            print("Lỗi khi lấy wikitext:", e)
    return section

# test

# print('================================')
# print(extract_actors_section(get_wikitext("Charlie Nguyễn")))
# print('================================')
# print(extract_actors_section(get_wikitext("Mùi ngò gai")))
p1 = "Chuyện tình mùa thu"
print(extract_actors_section(get_wikitext(p1)))

# %%
def extract_table_rows(wikitext):
    wikitext = wikitext.replace('|-', "@@@")
    parts = wikitext.split('@@@')
    return [p.strip() for p in parts[1:] if p.strip()]

#test 

rows = extract_table_rows(extract_actors_section(get_wikitext("Mùi ngò gai")))
for i, r in enumerate(rows, 1):
    r = r.lower()
    if "lương" in r:
        print(f"--- Row {i} ---")
        print(r)




    

# %%
def clean_string(s):
    return s.replace("'", "").strip()

text = "''Sanaly''\n"
result = clean_string(text)
print(result) 

def extract_all_wikilink(s):
    matches = re.findall(r'\[\[.*?\]\]', s)
    return matches

text = '==  style="text-align:center;"  - colspan="2" [[Lương Thế Thành]]<ref name=":2" [[ninh dương lan ngọc]]/>'
result = extract_all_wikilink(text)
print(result) 

# %% [markdown]
# ### extract_actors_and_roles_from_wikitable_row

# %%
def extract_actors_and_roles_from_wikitable_row(row_text):
    """
    Nhận 1 đoạn văn bản dạng wiki table row (ví dụ: |''Vy''|[[Angela...]]|[[Hồng Ánh]] ...)
    -> Trả về list các dict: {character: ..., actor_name: ...}
    """
    row_text = row_text.strip("|")

    # Tách theo | nhưng KHÔNG nằm trong [[...]]
    parts = re.split(r'\|(?![^[]*\]\])', row_text)
   
    if not parts:
        print('=> no part in row text')
        return []

    # Cột đầu là vai diễn
    character = ""
    for p in parts:
        if "''" in p:
            # Lấy nội dung trong ''...'' nếu có
            character = p.replace("''", "").strip()
            break

    results = []
   
    string = ""
    for p in parts[1:]:
        string += p 

    actor_wikilinks = extract_all_wikilink(string)
    for link in actor_wikilinks:
        actor_name =clean_wiki_markup(link)
        if actor_name:
                results.append({
                    "actor_name": actor_name,
                    "character": character
                    
                })
    # lọc cast vn
    res_filtered = [obj for obj in results if is_vn_person_wikilink(obj["actor_name"])]

    return res_filtered



# --- ví dụ ---
text = """|''Vy''
|[[Angela Phương Trinh]]/[[Phạm Thị Ngọc Trinh|Ngọc Trinh]] (†)<ref name=":2" />
|Ngọc Trinh(†)
|[[Hồng Ánh]]<ref name=":2" />"""
print(extract_actors_and_roles_from_wikitable_row(text))
text = '|\'\'Vy\'\'\n|[[Angela Phương Trinh]]/[[Phạm Thị Ngọc Trinh|Ngọc Trinh]] (†)<ref name=":2" />\n|Ngọc Trinh(†)\n|[[Hồng Ánh]]<ref name=":2" />'
print(extract_actors_and_roles_from_wikitable_row(text))
text = """|''thiện''
| style="text-align:center;" | -
| colspan="2" |[[Lương Thế Thành]]<ref name=":2" />

"""

print(extract_actors_and_roles_from_wikitable_row(text))

# %% [markdown]
# ### extract_actors_from_wikitable

# %%
def extract_actors_from_wikitable(section_wikitext):
    
    wikitable_rows = extract_table_rows(section_wikitext)  # dạng |- abc ... |- 

    actors_list = []
    for r in wikitable_rows:
        obj = extract_actors_and_roles_from_wikitable_row(r)
        if obj: actors_list.append(obj)

    return actors_list


print(len(extract_actors_from_wikitable(extract_actors_section(get_wikitext('Mùi ngò gai')))))
print(extract_actors_from_wikitable(extract_actors_section(get_wikitext('Mùi ngò gai'))))

# %%
m = 'Kim Hiền (diễn viên)'
n = get_wikitext(m)
tenfile = "kimhien"
# save_to_txt(n,tenfile)

info = extract_infobox_from_wikitext(n)
print(info)

# %%
import re
def is_vn_person_wikilink(name):
    # Kiem tra nhanh ten hop le cua dien vien
    # Tra ve True neu co kha nang la ten nguoi Viet/ten hop le
    # Loai bo cac chuoi nhu 'png', 'nhỏ', 'dàn', 'phim', 'gồm' o dau chuoi
    if not name or len(name) < 2 or len(name) > 80:
        return False
    bad_prefixes = [r'^png', r'^nhỏ', r'^dan', r'^phim', r'^gom', r'^co ', r'^có ']
    for p in bad_prefixes:
        if re.search(p, name, flags=re.IGNORECASE):
            return False
    # Neu chuoi chi toan so hoac ky tu la vo nghia thi loai
    if re.fullmatch(r'[\W_]+', name):
        return False
    # Co it nhat mot chu cai
    if not re.search(r'[A-Za-z\u00C0-\u017F]', name):
        return False
    return True

def extract_actors_from_text(wikitext):
    # parse wiki va chuyen thanh chuoi
    wikicode = mwparserfromhell.parse(wikitext)
    raw = str(wikicode)

    # 1 Lam sach toan van: loai bo tag ref va chuan hoa khoang trang
    raw = re.sub(r"<ref[^>]*>.*?</ref>", "", raw, flags=re.DOTALL)
    raw = re.sub(r"<ref[^/]*/>", "", raw)
    raw = " ".join(raw.split())

    # 2 Tach tung muc theo dau '*'
    items = re.split(r"\*", raw)
    cast_list = []

    for item in items:
        item = item.strip()
        if not item:
            continue

        # Loai bo cac prefix du thua nhu 'phim gom', 'co su tham gia', 'png|nho|...'
        item = re.sub(
            r"^(?:[^A-ZÀ-Ỵ]*\b(?:gồm|co|có|voi|với|trong|png|nhỏ|Dan|Dàn|phim)[^A-ZÀ-Ỵ]*)",
            "",
            item,
            flags=re.IGNORECASE
        )

        # 4 Lay actor
        # Neu co link [[...|...]] hoac [[...]] thi lay phan truoc dau '|'
        m_link = re.search(r"\[\[(.+?)(?:\|([^\]]+))?\]\]", item)
        if m_link:
            actor = m_link.group(1)
            # vi tri bat dau va ket thuc cua match de cat phan con lai
            start_pos = m_link.start()
            end_pos = m_link.end()
        else:
            # Neu khong co link thi lay phan truoc 'vai' hoac 'trong vai'
            parts = re.split(r"(?:trong\s+vai|vai)\s+", item, maxsplit=1, flags=re.I)
            if len(parts) > 1:
                actor = parts[0].strip()
                # tim vi tri actor trong chuoi de cat tail
                match_actor = re.search(re.escape(actor), item)
                start_pos = match_actor.start() if match_actor else 0
                end_pos = match_actor.end() if match_actor else 0
            else:
                actor = ""
                start_pos = end_pos = 0

        # 5 Lam sach ten actor: bo cac phan thua o dau, bo ky tu dac biet, chuan hoa space
        actor = re.sub(r"^(?:.*?\*|.*?\b(?:gồm|gom|cung|cùng|voi|với)\b)\s*", "", actor, flags=re.IGNORECASE)
        actor = re.sub(r"^(?:va|và|,)\s*", "", actor, flags=re.IGNORECASE)

        # Xoa cac dau cau nhung GIU nguyen chu co dau
        actor = re.sub(r"[.,;:!?\"“”‘’()\[\]{}<>|\\/]", "", actor)
        # Bo nhieu khoang trang thanh 1
        actor = " ".join(actor.split())

        if not actor:
            continue

        # 3 Lay role chi trong phan sau actor de tranh an nham role cua muc truoc
        tail = item[end_pos:]
        m_role = re.search(r"(?:trong\s+vai|vai)\s+(.+?)(?:[,.:]|$)", tail, flags=re.I)
        role = m_role.group(1).strip(" '\"") if m_role else ""
        # Lam sach role: chuyen ve thuong, loai bo cau muc khong can thiet
        
      
        role = re.sub(r"[\'\"]", "", role).strip()
        role = " ".join(role.split())
        role = role.replace("Cùng một số diễn viên khác",'').strip()

        if not actor or not role:
            continue

        cast_list.append({
            "actor_name": actor,
            "character": role
        })

    # Loc ket qua: chi giu nhung doi tuong co ve la ten dien vien hop le
    res_filtered = [obj for obj in cast_list if is_vn_person_wikilink(obj["actor_name"])]
    return res_filtered
#test 

print(extract_actors_from_text(extract_actors_section(matBiec_wikitext)))
print(len(extract_actors_from_text(extract_actors_section(matBiec_wikitext))))

'''
*
[[Trần Nghĩa (diễn viên)|Trần Nghĩa]]
 vai Ngạn:
<ref>{{Chú thích web|url=http://baodatviet.vn/van-hoa/tin-tuc-giai-tri/victor-vu-truy-lung-nang-mat-biec-va-chang-si-tinh-3368589/|title=Victor Vũ truy lùng nàng Mắt Biếc và chàng si tình|last=|first=|date=5 tháng 11 năm 2018|website=Báo Đất Việt|archive-url=https://web.archive.org/web/20190716065358/http://baodatviet.vn/van-hoa/tin-tuc-giai-tri/victor-vu-truy-lung-nang-mat-biec-va-chang-si-tinh-3368589/|archive-date=2019-07-16|url-status=dead|access-date=20 tháng 1 năm 2019}}</ref>
<ref>{{chú thích web|url=https://ione.vnexpress.net/tin-tuc/phim/vietnam/vuot-qua-hon-1-400-ung-vien-mat-biec-cua-victor-vu-da-lo-dien-3886413.html|website=IONE.VNEXPRESS.NET|tiêu đề=Vượt qua hơn 1.400 ứng viên, 'Mắt Biếc' của Victor Vũ đã lộ diện|ngày truy cập=2019-02-27|ngày=2019-02-26|ngôn ngữ=vi}}</ref>
 Chàng trai sinh ra và lớn lên ở làng Đo Đo, mang dáng vẻ thư sinh cùng tâm hồn nghệ sĩ. Ngạn yêu nhất hai điều trong đời mình: ngôi làng Đo Đo và Hà Lan. Tình yêu Ngạn dành cho Hà Lan gần như vĩnh cửu, không hề phai nhòa sau 30 năm dù Hà Lan đã đem lòng yêu Dũng và hình bóng của Dũng. Phạm Đình Thái Ngân lồng tiếng cho phần hát của nhân vật.
<ref>{{chú thích web|url=https://vnexpress.net/giai-tri/thai-ngan-toi-khong-luy-tinh-nhu-ngan-mat-biec-4032451.html|tiêu đề=Thái Ngân: 'Tôi không lụy tình như Ngạn Mắt biếc'|website=Báo điện tử [[VnExpress]]|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191226235344/https://vnexpress.net/giai-tri/thai-ngan-toi-khong-luy-tinh-nhu-ngan-mat-biec-4032451.html|ngày lưu trữ=2019-12-26|ngày truy cập=2020-01-01|url-status=dead}}</ref>


*
'''
p1 = "Chuyện tình mùa thu"
print((extract_actors_from_text(extract_actors_section(get_wikitext(p1)))))

# %% [markdown]
# ### extract_actors_from_list

# %%
def extract_actors_from_list(wikitext):
    wikicode = mwparserfromhell.parse(wikitext)
    result = []
    for node in wikicode.nodes:     
        text = str(node).strip() 
        
     
        if text.startswith('{{cast list|'): 
   

            parts = text.split('*')

            for line in parts:
                line = line.lstrip('*').strip()
                if not line:
                    continue

                # Xóa <ref>...</ref>, <ref .../>, {{...}}
                line = re.sub(r"<ref[^>]*>.*?</ref>", "", line)
                line = re.sub(r"<ref[^>]*\/>", "", line)
                line = re.sub(r"\{\{[^\}]+\}\}", "", line)

                # Regex cho tên diễn viên
                actor_pattern_linked = r"\[\[([^\]|]+)(?:\|[^\]]+)?\]\]"
                actor_pattern_plain = r"^([^\[]\S.+?)\s+(?:trong|vào)?\s*vai"

                # Regex cho vai diễn
                char_pattern = r"(?:trong|vào)?\s*vai\s*''([^']+)''"

                actor_match = re.search(actor_pattern_linked, line)
                if actor_match:
                    actor_name = actor_match.group(1).strip()
                else:
                    actor_match_plain = re.search(actor_pattern_plain, line)
                    actor_name = actor_match_plain.group(1).strip() if actor_match_plain else None

                char_match = re.search(char_pattern, line)
                character = char_match.group(1).strip() if char_match else None

                if actor_name or character:
                    result.append({'actor_name': actor_name, 'character': character})
    result_filtered = [obj for obj in result if is_vn_person_wikilink(obj["actor_name"])]
    return result_filtered
    

                
        
    # # Tìm tất cả các dòng bắt đầu bằng '*'
    # lines = [str(node).strip() for node in wikicode.nodes if str(node).strip().startswith('*')]

    # result = []
    # for line in lines:
    #     line = line.lstrip('*').strip()

    #     print(line)

    # return result


p1 = "Cổng mặt trời (phim truyền hình)"
print(extract_actors_from_list((extract_actors_section(get_wikitext(p1)))))

# %%
#chung
def is_wikitable(text):
    code = mwparserfromhell.parse(text)
    tables = code.filter_tags(matches=lambda node: node.tag == "table")
    wikitable_syntax = any(str(node).startswith("{|") for node in code.nodes)
    return bool(tables) or wikitable_syntax

#test
#chung
def is_list(text):
    code = mwparserfromhell.parse(text)
    tables = code.filter_tags(matches=lambda node: node.tag == "list")
    wikitable_syntax = any(str(node).startswith("{|") for node in code.nodes)
    # Template kiểu {{cast list|...}}, {{Plainlist|...}}, {{ubl|...}}, v.v.
    templates = code.filter_templates(matches=lambda t: "list" in t.name.strip().lower() or t.name.strip().lower() in {"ubl", "unbulleted list", "plainlist"})
    return bool(tables or wikitable_syntax or templates)

print(is_wikitable(extract_actors_section(get_wikitext("Mùi ngò gai"))))
p1 = "Cổng mặt trời (phim truyền hình)"
is_list(extract_actors_section(get_wikitext(p1)))

# %%
def extract_actors_from_film_wikitext(film_wikitext):
    
    section_wikitext = extract_actors_section(film_wikitext)
    # print(repr(section_wikitext[:300]))
    # print(is_wikitable(section_wikitext))
    res = []
    if is_wikitable(section_wikitext):
        actors = extract_actors_from_wikitable(section_wikitext)
        if actors: res.extend(actors) # có r thì nối list 
    elif is_list(section_wikitext):
        actors = extract_actors_from_list(section_wikitext)
        if actors: res.extend(actors) # có r thì nối list 
    else:
        actors = extract_actors_from_text(section_wikitext)
        if actors: res.extend(actors)
    
    return res

#test

print('mùi ngò gai',extract_actors_from_film_wikitext((get_wikitext("Mùi ngò gai"))))
print('mắt biếc',extract_actors_from_film_wikitext((get_wikitext("Mắt biếc (phim)"))))


# %% [markdown]
# ## test 1

# %%
# test director của mùi ngò gai ? 

# print(extract_directors_from_film(get_wikitext("Mùi ngò gai"))) # đạo diễn không có wikilink
t1 = "Chuyện tình mùa thu"
# print(extract_directors_from_film(get_wikitext(t1))) #đạo diễn k có wikilink



# %%

p1 = "Lựa chọn số phận"
print(p1,extract_actors_from_film_wikitext((get_wikitext(p1))))
# Out:
# ['Trấn Thành', 'Ninh Dương Lan Ngọc', 'Ngô Thanh Vân', 'Hồng Đào', 'Kiều Minh Tuấn', 'Victor Vũ', 'Charlie Nguyễn', 'Vũ Ngọc Đãng', 'Kaity Nguyễn', 'Jun Vũ', 'Mạnh Trường', 'Phương Oanh']
# {{for|tiểu thuyết cùng tên|Mắt biếc (tiểu thuyết)}}
# {{Thông tin phim
# | tên = Mắt biếc
# | hình = Áp phích phim Mắt biếc.jpg
# | caption = Áp phích chiếu rạp của phim tại Việt Nam
# | đạo diễn = [[Victor Vũ]]
# | sản xuất = {{Liệt kê|
# * Nguyễn Quốc Công
# * Kay Nguyễn
# }}
# | kịch bản = {{Liệt kê|
# * Victor Vũ
# * A Type Machine
# }}
# | dựa trên = ''[[Mắt biếc (tiểu thuyết)|Mắt biếc]]'' của [[Nguyễn Nhật Ánh]]
# | diễn viên = {{Liệt kê|
# * [[Trần Nghĩa (diễn viên)|Trần Nghĩa]]
# * [[Trúc Anh]]
# * Trần Phong
# * Khánh Vân
# * Thảo Tâm
# }}
# | âm nhạc = [[Christopher Wong]]<br>[[Phan Mạnh Quỳnh]]
# | quay phim = [[Dominic Pereira]]<ref>{{chú thích web|url=https://danviet.vn/nhung-guong-mat-nuoc-ngoai-thanh-cong-voi-dien-anh-viet-20220916084332568.htm|title=Những gương mặt nước ngoài thành công với điện ảnh Việt|author=Thủy Vũ|date=2022-09-16|publisher=[[Dân Việt (báo)|Dân Việt]]|access-date=2024-05-19}}</ref>
# | dựng phim = Vũ Hoàng Anh
# | studio = [[Galaxy EE|Galaxy M&E]]<br>November Films
# | phát hành = [[Galaxy Studio]]
# | công chiếu = 20 tháng 12 năm 2019 (Việt Nam)
# | thời lượng = 117 phút
# | quốc gia = {{VIE}}
# | ngôn ngữ = [[Tiếng Việt]]
# | kinh phí =
# | doanh thu = 180 tỷ VND<ref>https://news.zing.vn/mat-biec-tai-xuat-rap-chieu-dung-dip-83-post1055200.html{{Liên kết hỏng|date=2023-09-15 |bot=InternetArchiveBot }}</ref>
# | website =
# | imdb_id = 10622410
# | amg_id =
# | preceded_by =
# | followed_by =
# }}
# '''''Mắt biếc''''' (tựa tiếng Anh: '''''Dreamy Eyes''''') là [[phim điện ảnh]] [[Phim chính kịch|chính kịch]] [[Phim lãng mạn|lãng mạn]] của [[Việt Nam]] năm 2019 do [[Victor Vũ]] đạo diễn, kiêm đảm nhiệm phần kịch bản cùng với nhóm biên kịch A Type Machine. Đây là phiên bản chuyển thể điện ảnh từ [[Mắt biếc (tiểu thuyết)|tiểu thuyết cùng tên]] phát hành năm 1990 của nhà văn [[Nguyễn Nhật Ánh]],<ref>{{Chú thích web|url=https://news.zing.vn/victor-vu-chuyen-the-mat-biec-cua-nha-van-nguyen-nhat-anh-post889827.html|tiêu đề=Victor Vũ chuyển thể 'Mắt biếc' của nhà văn Nguyễn Nhật Ánh|website=Zing News|ngày tháng=05/11/2018}}{{Liên kết hỏng|date=2023-09-15 |bot=InternetArchiveBot }}</ref> đồng thời cũng là phim điện ảnh thứ hai của Victor Vũ chuyển thể dựa trên tác phẩm của nhà văn sau thành công của ''[[Tôi thấy hoa vàng trên cỏ xanh (phim)|Tôi thấy hoa vàng trên cỏ xanh]]'' (2015). Tác phẩm do hai hãng [[Galaxy EE|Galaxy Media & Entertainment]] và November Films hợp tác sản xuất, với sự tham gia của dàn diễn viên gồm [[Trần Nghĩa (diễn viên)|Trần Nghĩa]], [[Trúc Anh]], Trần Phong, Khánh Vân và Thảo Tâm. Nội dung của phim đi qua từng bước trưởng thành của Ngạn cùng mối tình đơn phương của cậu với Hà Lan – cô bạn thân xinh đẹp sở hữu đôi "mắt biếc".
#
# Victor Vũ bắt đầu quá trình tuyển chọn diễn viên cho dự án từ tháng 11 năm 2018. Phim bắt đầu được khởi quay vào giữa tháng 3 năm 2019 và đóng máy vào cuối tháng 5 tại [[Quảng Nam]] và [[Thừa Thiên Huế]]. ''Mắt biếc'' được khởi chiếu tại rạp vào ngày 20 tháng 12 năm 2019. Giới chuyên môn đưa ra nhiều lời khen ngợi cho tác phẩm, đặc biệt nhấn mạnh vào phần diễn xuất, kỹ thuật sản xuất, hình ảnh, âm nhạc và sự trung thành với tinh thần của nguyên tác gốc. Phim đạt thành công lớn về mặt doanh thu khi đem về 180 tỷ VND. ''Mắt biếc'' là phim điện ảnh đại diện Việt Nam được gửi đi dự sơ tuyển cho hạng mục [[Giải Oscar cho phim ngoại ngữ hay nhất|Phim ngoại ngữ hay nhất]] tại [[Giải Oscar lần thứ 93]] nhưng bị loại khỏi danh sách đề cử rút gọn.
#
# == Nội dung ==
# ''Mắt biếc'' xoay quanh mối tình đơn phương của Ngạn với Hà Lan, cô bạn gái có cặp mắt hút hồn nhưng cá tính bướng bỉnh. Một chuyện tình nhiều cung bậc, từ ngộ nghĩnh trẻ con, rồi tình yêu thuở học trò trong sáng, trải qua bao biến cố, trở thành một cuộc "đuổi hình bắt bóng" buồn da diết nhưng không nguôi hi vọng. Câu chuyện càng trở nên éo le hơn khi Trà Long - con gái của Hà Lan lớn lên lại nhen nhóm một tình yêu như thế với Ngạn.
#
# Phim lấy bối cảnh ở thập niên 1960 và 1970. Nhân vật chính là Ngạn, cậu bé sinh ra và lớn lên tại ngôi làng Đo Đo, tỉnh [[Quảng Nam]] (cũng là nguyên quán của tác giả [[Nguyễn Nhật Ánh]]). Cậu yêu mến cô bạn tên Hà Lan, người có đôi mắt đẹp tuyệt trần mà Ngạn tự gọi là "mắt biếc". Cả hai cùng trải qua biết bao nhiêu kỷ niệm tại làng quê nghèo này, dần dần trong Ngạn nảy sinh một tình yêu thầm lặng dành cho Hà Lan. Khi lớn lên, cả hai đều đi học trên thành phố [[Huế]]. Hà Lan ở chung nhà với người cô trong khi Ngạn ở chung nhà với cậu Huấn.
#
# Cậu Huấn có một người con trai tên Dũng, là anh họ của Ngạn. Tuy là con nhà giàu, sành điệu và giỏi võ, nhưng Dũng không phải là người đàng hoàng. Một lần Hà Lan qua tìm Ngạn để mượn sách, Dũng đã để ý Hà Lan và từ đó tìm cách tán tỉnh cô, điều này làm Ngạn thấy khó chịu. Không thể cưỡng lại sức hấp dẫn của chốn thành thị xa hoa nên Hà Lan đã ngã vào vòng tay Dũng. Mỗi khi Dũng làm Hà Lan đau khổ, Hà Lan tìm đến tâm sự với Ngạn. Hà Lan như vậy càng khiến Ngạn đau lòng hơn vì điều anh cần chỉ là thấy cô được hạnh phúc. Có lần Ngạn xảy ra ẩu đả với Dũng để rồi bị đánh tơi tả.
#
# Hà Lan [[Thai nghén|mang thai]] nên phải nghỉ học và dọn đến khu phố khác. Ngạn biết chuyện nên thường đến chăm sóc cô.&nbsp;Trong khi Ngạn luôn bên cạnh chăm sóc Hà Lan thì Dũng đã cưới một cô gái khác tên Bích Hoàng. Hà Lan sinh ra một đứa con gái, đặt tên là Trà Long và gửi về quê cho bà ngoại nuôi. Cuối cùng Ngạn cũng tốt nghiệp, anh trở thành thầy giáo và trở về làng Đo Đo dạy học. Còn Hà Lan mở một tiệm may trên thành phố, cô luôn bận rộn với công việc, hiếm khi có thời gian về thăm. Một cô gái tên Hồng đem lòng yêu Ngạn từ thời đi học, cô cũng về làng Đo Đo dạy học để được ở gần bên anh, tuy nhiên Ngạn chỉ một lòng yêu Hà Lan.
#
# Ngạn đã chăm lo cho Trà Long suốt mười mấy năm, từ lúc cô bé còn nhỏ cho đến khi trở thành thiếu nữ đi học trên thành phố Huế. Trà Long như một bản sao của Hà Lan, làm&nbsp;Ngạn cảm thấy như được sống lại một thời ký ức ngày xưa.&nbsp;Biết rằng Ngạn sẽ không bao giờ yêu mình, Hồng đau khổ dọn vào Sài Gòn sống. Trà Long bắt đầu yêu Ngạn, điều này làm anh bất ngờ. Để tránh mọi chuyện tồi tệ hơn, Ngạn quyết định bỏ đi thật xa. Hai mẹ con Hà Lan đều sốc khi biết Ngạn ra đi.&nbsp;Sau một hồi tâm sự với Trà Long, Hà Lan hiểu rằng cô không nên bỏ lỡ một người yêu mình thật lòng.&nbsp;Hà Lan chạy ra nhà ga để giữ Ngạn lại, nhưng cô không đuổi kịp chiếc xe lửa. Hà Lan đã khóc, và ở trên xe lửa, Ngạn cũng khóc.
#
# == Diễn viên ==
# [[Tập tin:Mắt biếc – Behind the scenes (2).png|nhỏ|Dàn diễn viên phim ''Mắt biếc'']]
# *[[Trần Nghĩa (diễn viên)|Trần Nghĩa]] vai Ngạn:<ref>{{Chú thích web|url=http://baodatviet.vn/van-hoa/tin-tuc-giai-tri/victor-vu-truy-lung-nang-mat-biec-va-chang-si-tinh-3368589/|title=Victor Vũ truy lùng nàng Mắt Biếc và chàng si tình|last=|first=|date=5 tháng 11 năm 2018|website=Báo Đất Việt|archive-url=https://web.archive.org/web/20190716065358/http://baodatviet.vn/van-hoa/tin-tuc-giai-tri/victor-vu-truy-lung-nang-mat-biec-va-chang-si-tinh-3368589/|archive-date=2019-07-16|url-status=dead|access-date=20 tháng 1 năm 2019}}</ref><ref>{{chú thích web|url=https://ione.vnexpress.net/tin-tuc/phim/vietnam/vuot-qua-hon-1-400-ung-vien-mat-biec-cua-victor-vu-da-lo-dien-3886413.html|website=IONE.VNEXPRESS.NET|tiêu đề=Vượt qua hơn 1.400 ứng viên, 'Mắt Biếc' của Victor Vũ đã lộ diện|ngày truy cập=2019-02-27|ngày=2019-02-26|ngôn ngữ=vi}}</ref> Chàng trai sinh ra và lớn lên ở làng Đo Đo, mang dáng vẻ thư sinh cùng tâm hồn nghệ sĩ. Ngạn yêu nhất hai điều trong đời mình: ngôi làng Đo Đo và Hà Lan. Tình yêu Ngạn dành cho Hà Lan gần như vĩnh cửu, không hề phai nhòa sau 30 năm dù Hà Lan đã đem lòng yêu Dũng và hình bóng của Dũng. Phạm Đình Thái Ngân lồng tiếng cho phần hát của nhân vật.<ref>{{chú thích web|url=https://vnexpress.net/giai-tri/thai-ngan-toi-khong-luy-tinh-nhu-ngan-mat-biec-4032451.html|tiêu đề=Thái Ngân: 'Tôi không lụy tình như Ngạn Mắt biếc'|website=Báo điện tử [[VnExpress]]|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191226235344/https://vnexpress.net/giai-tri/thai-ngan-toi-khong-luy-tinh-nhu-ngan-mat-biec-4032451.html|ngày lưu trữ=2019-12-26|ngày truy cập=2020-01-01|url-status=dead}}</ref>
# *[[Trúc Anh]] vai Hà Lan:<ref>{{chú thích web|url=https://vnexpress.net/giai-tri/nguoi-dep-9x-dong-chinh-phim-mat-biec-3886431.html|website=Báo điện tử VnExpress|tiêu đề=Người đẹp 9x đóng chính phim 'Mắt biếc'|ngày truy cập=2019-02-27|ngày=2019-02-26|ngôn ngữ=vi}}</ref><ref>{{chú thích web|url=https://tuoitre.vn/ha-lan-va-ngan-cua-mat-biec-da-lo-dien-20190226101122437.htm|website=Tuổi Trẻ Online|tiêu đề=Hà Lan và Ngạn của 'Mắt Biếc' đã 'lộ diện'|ngày truy cập=2019-02-27|ngày=2019-02-26|ngôn ngữ=vi}}</ref> Cô gái mà Ngạn phải lòng cô từ thuở nhỏ, nhưng khác với Ngạn, Hà Lan luôn muốn thoát khỏi ngôi làng nhỏ bé, lạc hậu của cô để theo đuổi khát khao đối với thế giới hiện đại, nhộn nhịp của thành phố.
# *Trần Phong vai Dũng: Người mà Hà Lan phải lòng khi lên thành phố đi học
# *Khánh Vân vai Trà Long: Con gái của Hà Lan và Dũng. Phải xa Hà Lan từ nhỏ, Trà Long lớn lên trong vòng tay che chở của Ngạn nên khác với mẹ mình, cô luôn cảm mến và ngưỡng mộ Ngạn.
# *Thảo Tâm vai Hồng: Bạn của Ngạn và Hà Lan lúc nhỏ, đơn phương yêu Ngạn dù biết Ngạn yêu Hà Lan và luôn trở thành "bình phong" trong những tình huống Ngạn đi theo dõi Hà Lan. Đây là nhân vật duy nhất được thêm vào phim và không có trong nguyên tác của truyện
# Ngoài ra, phim còn có sự tham gia diễn xuất của dàn diễn viên phụ gồm Hữu Luân trong vai Cậu Huấn, [[Khánh Huyền]] vai Cô của Hà Lan, Huỳnh Mai Cát Tiên vai Bích Hoàng, Ngọc Thảo vai Ba của Ngạn, [[Thanh Hiền]] vai Bà nội của Ngạn, Xuân Phúc vai Linh, và Phan Bảo Tiên vai Trà Long lúc nhỏ.
#
# == Sản xuất ==
# [[Tập tin:Mắt biếc – Behind the scenes (1).png|thumb|phải|350px|Trúc Anh và Trần Phong trong hậu trường phim ''Mắt biếc''.]]
# Theo đạo diễn Victor Vũ, dự án điện ảnh ''Mắt biếc'' mất hơn ba năm để thực hiện, từ lúc mua bản quyền nguyên tác năm 2016, phát triển kịch bản, ghi hình, cuối cùng là công chiếu vào tháng 12 năm 2019.<ref name=":0">{{chú thích web|url=https://vnexpress.net/giai-tri/phim-mat-biec-tung-trailer-chinh-4022325.html|tiêu đề=Phim 'Mắt biếc' tung trailer chính|website=Báo điện tử [[VnExpress]]|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191205134635/https://vnexpress.net/giai-tri/phim-mat-biec-tung-trailer-chinh-4022325.html|ngày lưu trữ=2019-12-05|url-status=dead|ngày truy cập=2020-01-01}}</ref>
#
# Thông tin về dự án chuyển thể ''Mắt biếc'' bắt đầu xuất hiện từ ngày 5 tháng 11 năm 2018 khi Galaxy Media & Entertainment và November Films đăng tải hình ảnh tìm kiếm các ứng viên tiềm năng phù hợp với vai diễn các nhân vật trong tiểu thuyết nguyên tác.<ref>{{Chú thích web|url=https://giaitri.vnexpress.net/tin-tuc/phim/sau-man-anh/victor-vu-khoi-dong-du-an-mat-biec-3834235.html|tiêu đề=Victor Vũ khởi động dự án 'Mắt biếc'|tác giả=Ân Nguyễn|ngày tháng=2018-11-05|website=VnExpress Giải trí|url-status=live|ngày truy cập=2021-08-07}}</ref><ref name=":1">{{Chú thích web|url=https://znews.vn/victor-vu-chuyen-the-mat-biec-cua-nha-van-nguyen-nhat-anh-post889827.html|tựa đề=Victor Vũ chuyển thể 'Mắt biếc' của nhà văn Nguyễn Nhật Ánh|tác giả=Tuấn Lương|ngày=2018-11-05|website=Zing News|url-status=live|ngày truy cập=2021-08-07}}</ref> Các vai diễn được tìm kiếm bao gồm vai Ngạn, Hà Lan, Dũng và Trà Long, với độ tuổi 16-22, ngoại hình sáng cùng các yêu cầu riêng biệt đối với từng nhân vật.<ref name=":1" />
#
# Bộ phim bắt đầu được khởi quay vào ngày 18 tháng 3 năm 2019.<ref>{{Chú thích web|url=https://vtv.vn/dien-anh/phim-dien-anh-mat-biec-chinh-thuc-bam-may-20190318101605684.htm|tựa đề=Phim điện ảnh "Mắt biếc" chính thức bấm máy|tác giả=PV|ngày=2019-03-18|website=[[VTV]]|url-status=live|ngày truy cập=2021-08-07}}</ref> Phim quay liên tục trong 44 ngày và đóng máy vào ngày 27 tháng 5 năm 2019.<ref>{{chú thích web|url=https://plo.vn/giai-tri/mat-biec-tung-hinh-anh-phim-sau-44-ngay-quay-836215.html|website=Báo điện tử Pháp Luật thành phố Hồ Chí Minh|tiêu đề='Mắt Biếc' tung hình ảnh phim sau 44 ngày quay|ngày truy cập=2019-05-28|ngôn ngữ=vi}}</ref> Các cảnh phim chủ yếu được thực hiện ở [[Thăng Bình]], Quảng Nam – bối cảnh quê hương nhân vật – và [[Huế]], [[Thừa Thiên Huế]] – bối cảnh thành phố trong phim.<ref>{{Chú thích web|url=https://dantri.com.vn/du-lich/gioi-tre-san-lung-dia-diem-tai-quang-nam-xuat-hien-trong-phim-mat-biec-20191223071000723.htm|tựa đề=Giới trẻ săn lùng địa điểm tại Quảng Nam xuất hiện trong phim Mắt Biếc|tác giả=Công Bính|tác giả 2=Ngô Linh|ngày=2019-12-23|website=Dân Trí|url-status=live|ngày truy cập=2021-08-07}}</ref><ref>{{chú thích web|url=https://vnexpress.net/giai-tri/canh-cho-dem-duong-pho-hue-xua-trong-phim-mat-biec-3929563.html|website=Báo điện tử [[VnExpress]]|tiêu đề=Cảnh chợ đêm, đường phố Huế xưa trong phim 'Mắt biếc'|ngày truy cập=2019-05-28|ngôn ngữ=vi}}</ref>
#
# Để tái hiện được không gian và thời gian của thập niên 1960 – 1970 khi câu chuyện diễn ra, nhà sản xuất đã đầu tư cho các bối cảnh chính như trường học nữ sinh, làng Đo Đo, hội chợ dân gian, rừng sim, đường phố, nhà ga xe lửa. Khoảng 1000 diễn viên quần chúng đã tham gia trong quá trình quay. Nhiều con phố như Bạch Đằng, Kim Long, Huỳnh Thúc Kháng cũng như các đạo cụ, thiết kế và trang phục đều được phục dựng sao cho giống với nguyên tác nhất.<ref>{{chú thích web|url=https://anninhthudo.vn/giai-tri/phim-mat-biec-tai-hien-boi-canh-thap-nien-nhung-nam-60-va-70/812022.antd|website=Báo điện tử An Ninh Thủ Đô|tiêu đề=Phim "Mắt biếc" tái hiện bối cảnh thập niên những năm 60 và 70|ngày truy cập=2019-05-28}}</ref><ref>{{chú thích web|url=https://voh.com.vn/van-hoa-giai-tri/mat-biec-tung-teaser-hinh-anh-dau-tien-sau-44-ngay-quay-lien-bi-soi-vi-nhung-dieu-nay-319346.html|website=Báo điện tử [[Đài Tiếng nói Nhân dân Thành phố Hồ Chí Minh]]|tiêu đề='Mắt biếc' tung teaser hình ảnh đầu tiên sau 44 ngày quay liền bị 'soi' vì những điều này|ngày truy cập=2019-05-28}}</ref><ref>{{chú thích web|url=https://nld.com.vn/van-nghe/mat-biec-gay-chu-y-voi-loat-anh-dau-tien-20190527145247347.htm|website=Báo điện tử Người Lao Động|tiêu đề="Mắt biếc" gây chú ý với loạt ảnh đầu tiên|ngày truy cập=2019-05-28|ngôn ngữ=vi}}</ref><ref>{{chú thích web|url=https://vtv.vn/van-hoa-giai-tri/sau-khi-dong-may-mat-biec-chinh-thuc-he-lo-nhung-hinh-anh-dau-tien-20190527102826593.htm|website=Báo điện tử [[Đài Truyền hình Việt Nam]]|tiêu đề=Sau khi đóng máy "Mắt biếc" chính thức hé lộ những hình ảnh đầu tiên|ngày truy cập=2019-05-28|ngôn ngữ=vi}}</ref><ref>{{chú thích web|url=https://thethaovanhoa.vn/giai-tri/phim-mat-biec-cua-victor-vu-dong-may-he-lo-nhung-hinh-anh-dau-tien-n20190527164000850.htm|website=Báo điện tử [[Thể thao & Văn hóa]]|tiêu đề=Phim 'Mắt biếc' của Victor Vũ đóng máy, hé lộ những hình ảnh đầu tiên|ngày truy cập=2019-05-28|ngôn ngữ=vi}}</ref>
#
# === Âm nhạc ===
# ''Mắt biếc'' có 4 bài hát do [[Phan Mạnh Quỳnh]] sáng tác, bao gồm ''Có chàng trai viết lên cây'', ''Từ đó'', ''Tôi chỉ muốn nói'' và ''Hà Lan''. Đáng chú ý, ''Có chàng trai viết lên cây'' vốn đã được sáng tác từ năm 2016, và bài hát đã được đổi lời cho phù hợp với bộ phim.<ref>{{chú thích web|url=https://news.zing.vn/co-chang-trai-viet-len-cay-thay-doi-ra-sao-khi-dua-vao-mat-biec-post1024578.html|tiêu đề='Có chàng trai viết lên cây' thay đổi ra sao khi đưa vào 'Mắt biếc'?|website=Báo điện tử Zing.vn|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191212133309/https://news.zing.vn/co-chang-trai-viet-len-cay-thay-doi-ra-sao-khi-dua-vao-mat-biec-post1024578.html|ngày lưu trữ=2019-12-12|url-status=dead|ngày truy cập=2020-01-01}}</ref> Ngoài ra, bộ phim có sáu bài hát thập niên 60, 70, được dùng lại. Nhà soạn nhạc [[Christopher Wong]] trực tiếp sáng tác mười trong tổng số 20 bản nhạc nền của phim. Ông và đạo diễn Victor Vũ đã mời dàn nhạc giao hưởng Bulgaria thu âm phần nhạc nền này.<ref>{{chú thích web|url=https://news.zing.vn/nhac-phim-mat-biec-co-lam-dung-phan-manh-quynh-qua-khong-post1029482.html|tiêu đề=Nhạc phim 'Mắt biếc' có lạm dụng Phan Mạnh Quỳnh quá không?|website=Báo điện tử Zing.vn|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191226153516/https://news.zing.vn/nhac-phim-mat-biec-co-lam-dung-phan-manh-quynh-qua-khong-post1029482.html|ngày lưu trữ=2019-12-26|url-status=dead|ngày truy cập=2020-01-01}}</ref>
# {{Danh sách ca khúc
# | collapsed = extra11
# | headline &nbsp; &nbsp; &nbsp; = Danh sách các bài nhạc phim (OST)
# | title1 = Có chàng trai viết lên cây
# | note1 =
# | writer1 = Phan Mạnh Quỳnh
# | lyrics1 = a
# | music1 = b
# | extra1 = Phan Mạnh Quỳnh
# | length1 = 5:05
# | title2 = Từ đó
# | writer2 = Phan Mạnh Quỳnh
# | lyrics2 =
# | music2 =
# | extra2 = Phan Mạnh Quỳnh
# | length2 = 3:01
# | title3 = Tôi chỉ muốn nói
# | note3 =
# | writer3 = Phan Mạnh Quỳnh
# | lyrics3 =
# | music3 =
# | extra3 = Phan Mạnh Quỳnh
# | length3 = 3:12
# | title4 = Hà Lan
# | note4 =
# | writer4 = Phan Mạnh Quỳnh
# | lyrics4 =
# | music4 =
# | extra4 = Phan Mạnh Quỳnh
# | length4 = 5:14
# | writer5 = Lê Hựu Hà
# | writer9 = Y Vân
# | writer8 = Phạm Duy
# | writer7 = Lê Hựu Hà
# | writer6 = Lê Hựu Hà
# | title6 = Sống cho qua hôm nay
# | title10 = Mộng chiều xuân
# | title9 = Đêm huyền diệu
# | title8 = Tóc mai sợi vắn sợi dài
# | title7 = Huyền thoại người con gái
# | title5 = Tôi muốn
# | writer10 = Ngọc Bích
# | length5 = 2:31
# | length6 = 4:27
# | length7 = 4:38
# | length8 = 4:37
# | length9 = 4:39
# | length10 = 3:31
# | extra5 = Phượng Hoàng Band & Elvis Phương
# | extra6 = Phượng Hoàng Band & Elvis Phương
# | extra7 = Elvis Phương
# | extra8 = Thành Mái
# | extra9 = Phương Tâm
# | extra10 = Lệ Thu
# | title11 = Những giấc mơ ở lại
# | writer11 = Ngô Minh Tài
# | extra11 = Nguyễn Kiều Oanh
# | length11 = 4:17
# | extra_column = Thể hiện
# }}
#
# == Phát hành ==
# ''Mắt biếc'' chính thức được phát hành vào ngày 20 tháng 12 năm 2019.<ref>{{chú thích báo|url=https://thanhnien.vn/van-hoa/mat-biec-can-moc-doanh-thu-50-ti-dong-nhanh-nhat-lich-su-phim-viet-1162808.html|tiêu đề='Mắt biếc' cán mốc doanh thu 50 tỉ đồng nhanh nhất lịch sử phim Việt|ngày truy cập=2021-01-07|ngày=2019-12-24T09:24:13+07:00|ngôn ngữ=vi|tác giả=Phùng Hạo|url lưu trữ=https://web.archive.org/web/20191225084406/https://thanhnien.vn/van-hoa/mat-biec-can-moc-doanh-thu-50-ti-dong-nhanh-nhat-lich-su-phim-viet-1162808.html|ngày lưu trữ=2019-12-25|url-status=live|website=Báo Thanh Niên|url-status=live}}</ref> Từ tối ngày 21 đến ngày 22 tháng 12, hàng trăm người hâm mộ tại Hà Nội đã xếp hàng để mua vé xem suất chiếu phim vào cuối tuần. Vào những ngày tiếp theo, để đáp ứng nhu cầu, các rạp chiếu đã xếp tăng suất chiếu của bộ phim lên trên 20 suất mỗi ngày.<ref>{{chú thích web|url=http://kinhtedothi.vn/mat-biec-chay-ve-tai-cac-rap-chieu-360766.html|tiêu đề="Mắt biếc" - "cháy vé" tại các rạp chiếu|website=Báo Kinh tế đô thị|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20200224122104/http://kinhtedothi.vn/mat-biec-chay-ve-tai-cac-rap-chieu-360766.html|ngày lưu trữ=2020-02-24|url-status=live|ngày truy cập=2021-01-07}}</ref> Bộ phim cũng được phát hành độc quyền trên ứng dụng Galaxy Play từ ngày 19 tháng 4 năm 2020.<ref>{{Chú thích web|url=https://galaxyplay.vn/title/dreamy-eyes|tựa đề=Mắt Biếc (2019)|website=Galaxy Play|ngày truy cập=2021-01-07}}</ref><ref>{{chú thích báo|url=https://tuoitre.vn/tin-vui-danh-cho-fan-mat-biec-tang-phim-khi-kich-hoat-galaxy-play-20200422143443152.htm|tiêu đề=Tin vui dành cho fan Mắt Biếc, tặng phim khi kích hoạt Galaxy Play|ngày truy cập=2021-01-07|ngày=2020-04-22T16:00:00+07:00|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20200926062701/https://tuoitre.vn/tin-vui-danh-cho-fan-mat-biec-tang-phim-khi-kich-hoat-galaxy-play-20200422143443152.htm|ngày lưu trữ=2020-09-26|url-status=live|website=Báo điện tử Tuổi Trẻ|url-status=live}}</ref> Bộ phim tranh cử ở vòng sơ tuyển, hạng mục "Phim truyện quốc tế" tại giải Oscar 2021.<ref>{{chú thích báo|url=https://laodong.vn/giai-tri/mat-biec-dai-dien-dien-anh-viet-nam-du-oscar-2021-861568.ldo|tiêu đề="Mắt biếc" đại diện điện ảnh Việt Nam dự Oscar 2021|ngày truy cập=2021-01-07|ngày=2020-12-11T11:51:22+07:00|ngôn ngữ=vi|website=Báo điện tử Lao Động}}</ref>
#
# === Quảng bá ===
# <abbr>Ngày 8 tháng 8 năm 2018</abbr><ref>{{Chú thích web|url=https://www.facebook.com/photo.php?fbid=10156461809987310|title=Victor Vu – Tôi cảm thấy...|last=|first=|date=8 tháng 8 năm 2018|website=Facebook|via=Facebook|archive-url=|archive-date=|url-status=|access-date=20 tháng 1 năm 2018}}</ref><abbr>, đạo diễn Victor Vũ đã đăng tải một dòng trạng thái trên [[Facebook]] có hình bìa cuốn sách ''Mắt biếc'' và dòng chữ "tôi cảm thấy..." ngụ ý rằng đây sẽ là tác phẩm tiếp theo được anh chuyển thể thành phim.</abbr><ref>{{Chú thích web|url=http://hoahoctro.vn/tin-tuc/victor-vu-se-som-dua-mot-tac-pham-moi-cua-nha-van-nguyen-nhat-anh-len-man-anh|title=Victor Vũ sẽ sớm đưa một tác phẩm mới của nhà văn Nguyễn Nhật Ánh lên màn ảnh?|last=|first=|date=10 tháng 8 năm 2018|website=Tạp chí Hoa Học Trò Online|archive-url=|archive-date=|url-status=|access-date=20 tháng 1 năm 2019}}</ref> Ngày 11 tháng 7 năm 2019, đoạn phim giới thiệu ban đầu (teaser trailer) của bộ phim được đăng tải trên YouTube.<ref>{{chú thích web|url=https://www.youtube.com/watch?v=KvRRO1EvWI0|title=MẮT BIẾC - TEASER TRAILER - KC: 12.2019|last=|first=|date=|website=YouTube|ngôn ngữ=vi|archive-url=|archive-date=|url-status=|ngày truy cập=2019-07-17|access-date=}}</ref> Video dài 1 phút 30 giây hé lộ một số cảnh quay của bộ phim trên nền bài hát ''Có chàng trai viết lên cây'' của [[Phan Mạnh Quỳnh]].<ref>{{chú thích web|url=https://vtv.vn/van-hoa-giai-tri/mat-biec-ra-mat-teaser-khan-gia-ban-loan-nhan-ra-hit-cua-phan-manh-quynh-20190712103207921.htm|tiêu đề="Mắt Biếc" ra mắt teaser, khán giả "bấn loạn" nhận ra hit của Phan Mạnh Quỳnh|website=Báo điện tử [[Đài Truyền hình Việt Nam]]|ngôn ngữ=vi|ngày truy cập=2019-07-17}}</ref><ref>{{chú thích web|url=http://toquoc.vn/mat-biec-dot-ngot-ham-nong-ca-khuc-co-chang-trai-viet-len-cay-20190713095144249.htm|title=|tiêu đề=Mắt biếc "đột ngột hâm nóng" ca khúc Có chàng trai viết lên cây|last=|first=|date=|website=Báo điện tử Tổ Quốc|ngôn ngữ=vi|archive-url=|archive-date=|url-status=|ngày truy cập=2019-07-17|access-date=}}</ref> Ngày 4 tháng 12 năm 2019, đoạn phim giới thiệu chính đã được đưa ra, tiết lộ những biến cố, thử thách trong bộ phim.<ref name=":0" /><ref>{{chú thích web|url=https://vtv.vn/van-hoa-giai-tri/mat-biec-tung-trailer-chinh-thuc-he-lo-nhung-bien-co-moi-20191205101243812.htm|tiêu đề="Mắt biếc" tung trailer chính thức, hé lộ những biến cố mới|website=Báo điện tử [[Đài Truyền hình Việt Nam]]|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191206152309/https://vtv.vn/van-hoa-giai-tri/mat-biec-tung-trailer-chinh-thuc-he-lo-nhung-bien-co-moi-20191205101243812.htm|ngày lưu trữ=2019-12-06|ngày truy cập=2020-01-01|url-status=dead}}</ref><ref>{{chú thích web|url=https://www.youtube.com/watch?v=ITlQ0oU7tDA|tiêu đề=MẮT BIẾC - OFFICIAL TRAILER|website=YouTube|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191209081126/https://www.youtube.com/watch?v=ITlQ0oU7tDA|ngày lưu trữ=2019-12-09|ngày truy cập=2020-01-01|url-status=dead}}</ref>
#
# Buổi họp báo giới thiệu phim ''Mắt biếc'' đã được diễn ra vào chiều ngày 4 tháng 12 năm 2019 tại [[Thành phố Hồ Chí Minh]].<ref>{{chú thích web|url=https://tuoitre.vn/mat-biec-tren-man-anh-se-la-tinh-yeu-vi-dai-cua-ngan-danh-cho-ha-lan-2019120417024009.htm|tiêu đề=Mắt biếc trên màn ảnh sẽ là tình yêu vĩ đại của Ngạn dành cho Hà Lan|website=Tuổi Trẻ Online|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20191205135829/https://tuoitre.vn/mat-biec-tren-man-anh-se-la-tinh-yeu-vi-dai-cua-ngan-danh-cho-ha-lan-2019120417024009.htm|ngày lưu trữ=2019-12-05|ngày truy cập=2019-12-31|url-status=dead}}</ref>
#
# == Đón nhận ==
# ===Doanh thu phòng vé===
# ''Mắt biếc'' trở thành hiện tượng phòng vé cuối năm 2019 khi thu khoảng 50 tỷ đồng chỉ sau ba ngày phát hành.<ref>{{chú thích web|url=https://vietnamnet.vn/vn/giai-tri/phim/mat-biec-thu-50-ty-lap-ky-luc-phong-ve-phim-viet-602596.html|tiêu đề='Mắt biếc' thu 50 tỷ, lập kỷ lục phòng vé phim Việt|website=Báo điện tử VietNamNet|ngôn ngữ=vi|ngày truy cập=2019-12-31}}</ref> Sau 10 ngày, hay đến ngày 28 tháng 12 năm 2019, bộ phim đã đạt doanh thu 100 tỷ đồng.<ref name=":12">{{chú thích web|url=https://thanhnien.vn/van-hoa/mat-biec-dat-doanh-thu-115-ti-dong-sau-10-ngay-chieu-1166061.html|tiêu đề='Mắt biếc' đạt doanh thu 115 tỉ đồng sau 10 ngày chiếu|website=Báo Thanh Niên|ngôn ngữ=vi|ngày truy cập=2019-12-31}}</ref> Đến ngày 22 tháng 1 năm 2020, ''Mắt biếc'' vượt mặt ''[[Em chưa 18]]'' với doanh thu 172 tỉ đồng <ref>{{Chú thích web|url=https://www.msn.com/vi-vn/news/other/m%E1%BA%AFt-bi%E1%BA%BFc-v%C6%B0%E1%BB%A3t-170-t%E1%BB%B7-%C4%91%E1%BB%93ng/ar-BBZeXhr|tựa đề=Mắt Biếc vượt 170 tỷ đồng}}</ref>
#
# Dù bộ phim được dán nhãn C16<ref>{{chú thích web|url=https://www.bhdstar.vn/movie/HO00001686/|tiêu đề=MẮT BIẾC - BHD Star Cineplex -|website=BHD Star Cineplex -|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20190824164617/https://www.bhdstar.vn/movie/HO00001686/|ngày lưu trữ=2019-08-24|url-status=dead|ngày truy cập=2020-01-01}}</ref> (chỉ dành cho khán giả từ 16 tuổi trở lên) nhưng lượng người xem vẫn rất phong phú. Bộ phim đạt tỷ lệ lấp đầy các phòng chiếu trung bình là 50% cho các suất buổi sáng và 90% cho các suất chiếu buổi tối.<ref name=":12"/>
#
# == Ảnh hưởng ==
#
# === Du lịch ===
# Nhiều bối cảnh trong bộ phim đã trở thành những điểm thu hút nhiều người tham quan.<ref>{{chú thích web|url=https://www.tienphong.vn/van-hoa/sau-len-phim-mat-biec-phim-truong-truong-tieu-hoc-cong-dong-do-do-ra-sao-1503608.tpo|tiêu đề=Sau lên phim 'Mắt biếc', phim trường 'Trường Tiểu học Cộng đồng Đo Đo' ra sao?|website=Báo điện tử Tiền Phong|ngôn ngữ=vi|ngày truy cập=2019-12-31}}</ref> Theo đó, sau khi ''Mắt biếc'' được phát hành, lượng khách đổ về thôn Hà Cảng (xã [[Quảng Phú, Quảng Điền|Quảng Phú]], tỉnh [[Thừa Thiên Huế]]) ngày càng đông, nhất là khách du lịch nội địa. Cây cổ thụ – nơi nhân vật Ngạn đánh đàn cho Hà Lan nghe trong phim – nhận được nhiều lượt ghé thăm nhất, sau đó được đổi tên thành "cây Mắt Biếc".<ref>{{chú thích web|url=https://www.tienphong.vn/van-hoa/do-xo-ve-hue-san-tim-cay-co-don-xuat-hien-trong-mat-biec-1500720.tpo|tiêu đề=Đổ xô về Huế săn tìm 'cây cô đơn' xuất hiện trong 'Mắt biếc'|website=Báo điện tử Tiền Phong|ngôn ngữ=vi|ngày truy cập=2020-01-01}}</ref><ref>{{chú thích web|url=https://thanhnien.vn/van-hoa/cu-hich-du-lich-hau-phim-khung-1166459.html|tiêu đề=Cú hích du lịch hậu phim 'khủng'|website=Báo Thanh Niên|ngôn ngữ=vi|ngày truy cập=2019-12-31}}</ref> Những địa điểm khác, chẳng hạn như Trường tiểu học cộng đồng Đo Đo, chợ làng Đo Đo, cũng trở thành điểm đến check-in của nhiều khán giả.<ref>{{chú thích web|url=https://news.zing.vn/du-khach-do-xo-den-hue-sau-khi-xem-mat-biec-post1031209.html|tiêu đề=Du khách đổ xô đến Huế sau khi xem 'Mắt biếc'|website=Báo điện tử Zing.vn|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20200101050258/https://news.zing.vn/du-khach-do-xo-den-hue-sau-khi-xem-mat-biec-post1031209.html|ngày lưu trữ=2020-01-01|url-status=dead|ngày truy cập=2020-01-01}}</ref>
#
# == Giải thưởng và thành tựu ==
# [[Tập tin:Dominic Pereira.png|nhỏ|170x170px|nhà quay phim '''Dominic Pereira''']]
# {| class="wikitable"
# !Năm
# !Giải thưởng
# !Hạng mục
# !Đề cử
# !Kết quả
# |-
# | rowspan="3" |2021
# | rowspan="3" |[[Liên hoan phim Việt Nam lần thứ 22]]<ref>{{Chú thích web|url=https://vnexpress.net/mat-biec-doat-giai-bong-sen-vang-4391612.html|tựa đề='Mắt biếc' đoạt giải Bông Sen Vàng|website=Báo điện tử VnExpress|ngôn ngữ=vi|ngày truy cập=2021-11-20}}</ref>
# |[[Giải Bông Sen cho phim truyện điện ảnh|Bông Sen Vàng]]
# |''Mắt biếc''
# |{{won}}
# |-
# |Âm nhạc xuất sắc
# |[[Christopher Wong]]
# |{{won}}
# |-
# |[[Giải Bông Sen cho quay phim xuất sắc|Quay phim xuất sắc]]
# |[[Dominic Pereira]]
# |{{won}}
# |-
# |2020
# |[[Giải Cánh diều 2019]]<ref>{{Chú thích web|url=https://vtv.vn/news-20200512105106156.htm|tựa đề=Giải thưởng Cánh diều 2019: VTV thắng lớn|tác giả=P.V|họ=|tên=|ngày=2020-05-12|website=Thời báo VTV|ngôn ngữ=vi|archive-url=https://web.archive.org/web/20210606075638/https://vtv.vn/news-20200512105106156.htm|archive-date=2021-06-06|url-status=live|ngày truy cập=2024-05-26}}</ref>
# |[[Giải Cánh diều cho âm thanh xuất sắc|Âm thanh xuất sắc]]
# |Vũ Thành Long
# |{{Won}}
# |}
#
# == Xem thêm ==
# *[[Danh sách phim Việt Nam có doanh thu cao nhất]]
# *[[Danh sách phim của Việt Nam được đệ trình lên Giải Oscar cho Phim ngoại ngữ hay nhất]]
#
# == Tham khảo ==
# {{Tham khảo|30em}}
#
# == Liên kết ngoài ==
# *[https://galaxyplay.vn/title/dreamy-eyes Mắt biếc] tại [[Galaxy Play]]
# *[[imdbtitle:10622410|Mắt biếc]] tại [[Internet Movie Database]]
#
# {{Victor Vũ}}
# {{Nguyễn Nhật Ánh}}
# {{Giải Bông sen vàng cho Phim truyện điện ảnh}}
# {{Phim Việt Nam được gửi tranh Giải Oscar cho phim quốc tế hay nhất}}
#
# [[Thể loại:Phim năm 2019]]
# [[Thể loại:Phim Việt Nam]]
# [[Thể loại:Phim tiếng Việt]]
# [[Thể loại:Phim lãng mạn Việt Nam]]
# [[Thể loại:Phim tâm lý Việt Nam]]
# [[Thể loại:Phim ca nhạc Việt Nam]]
# [[Thể loại:Phim do Victor Vũ đạo diễn]]
# [[Thể loại:Phim của Galaxy Studio]]
# [[Thể loại:Phim chuyển thể từ tác phẩm của Nguyễn Nhật Ánh]]
# [[Thể loại:Phim dựa theo tác phẩm của nhà văn]]
# [[Thể loại:Phim tường thuật phi tuyến tính]]
# [[Thể loại:Phim về mang thai]]
# [[Thể loại:Phim lấy bối cảnh ở trường học]]
# [[Thể loại:Phim lấy bối cảnh ở Việt Nam]]
# [[Thể loại:Phim lấy bối cảnh ở Huế]]
# [[Thể loại:Phim quay tại Việt Nam]]
# [[Thể loại:Phim Việt Nam thập niên 2010]]
# [[Thể loại:Phim lãng mạn thập niên 2010]]
# [[Thể loại:Phim chính kịch thập niên 2010]]
# [[Thể loại:Phim chính kịch lãng mạn thập niên 2010]]
# [[Thể loại:Phim lấy bối cảnh ở thập niên 1960]]
# [[Thể loại:Phim lấy bối cảnh ở thập niên 1970]]
# [[Thể loại:Phim giành giải Bông sen vàng]]
# [[Thể loại:Phim chính kịch Việt Nam]]
# type mat biec infobox <class 'dict'>
# True
# True
# False
# True
# True
# True
# True
# False
#
# {'bgcolor': 'Wheat', 'show_name': 'Cô nàng bướng bỉnh<br>Крепкий орешек', 'image': '[[Tập tin:Cô nàng bướng bỉnh.jpg|222px]]', 'genre': 'Phiêu lưu, hành động, hài hước', 'format': '[[phim màu]]', 'writer': '[[Efim Sevela]]', 'director': '[[Teodor Vulfovich]]', 'country': '{{URS}}', 'language': '[[Tiếng Nga]]', 'supervising_producer': '[[Samuil Rubashkin]]', 'editor': 'N.Bystrova', 'runtime': '78 [[phút]]', 'company': '[[Mosfilm]]', 'channel_vn': '[[VTV3]]', 'first_run': '{{URS}}<br>{{VIE}}<br>{{flag|Indonesia}}', 'first_aired': '1967', 'imdb_id': '0179925'}
# True
# True
# Hồng Thy ko rõ quốc tịch, nhưng mô tả là người vn
# True
# person
# ['Trấn Thành', 'Ngô Thanh Vân']
# {'level': 2, 'title': 'Danh sách phim'}
# {'level': 3, 'title': 'Điện ảnh'}
# {'level': 4, 'title': 'Truyền hình'}
# Victor Vũ --> actor: False --> director True
# Trấn Thành --> actor: True --> director True
# Ngô Thanh Vân --> actor: True --> director True
# Charlie Nguyễn --> actor: False --> director True
# Lý Hải --> actor: True --> director True
# Jun Vũ --> actor: True --> director False
# ================================
# === Phim điện ảnh ===
# {| class="wikitable"
# !Năm
# ! Tựa đề
# ! Vai diễn
# ! Loại vai
# |-
# |2015
# |''[[12 chòm sao: Vẽ đường cho yêu chạy]]''
# | My
# | rowspan="2" |Vai chính
# |-
# |2016
# |''Cho em gần anh thêm chút nữa''
# | Rin
# |-
# | rowspan="2" |2018
# |''[[Tháng năm rực rỡ]]''
# | Tuyết Anh
# | rowspan="4" | Vai thứ
# |-
# |''Người bất tử''
# |Liên
# |-
# |2019
# |''Ngốc ơi tuổi 17''
# |Trân Châu
# |-
# |2020
# |''[[Gái già lắm chiêu 3]]''
# |Khánh My
# |-
# |2021
# |''[[Gái già lắm chiêu V: Những cuộc đời vương giả|Gái già lắm chiêu V]]''
# |Lý Lệ Hà (lúc trẻ)
# |Khách mời
# |-
# |2022
# |''[[Chìa khóa trăm tỷ]]''
# |Hồ Phương
# |Vai thứ
# |-
# |2024
# |''B4S – Trước giờ "Yêu"''
# |Su
# |Vai chính
# |}
#
# === Phim dài tập / phim ngắn ===
# {| class="wikitable"
# |+
# !Năm
# !Tựa đề
# !Kênh / định dạng
# !Vai diễn
# !Loại vai
# |-
# |2014
# |''Mùa hè tuổi 17''
# |[[Phim ngắn]]
# |Giấc Mơ
# | rowspan="5" |Vai chính
# |-
# | rowspan="2" |2017
# |''Xuân Cười: Món quà đầu năm''
# |[[HTV2]]
# |Cô Hai
# |-
# |''Đôi bạn trời ban''
# |[[Chương trình chiếu mạng|Web drama]]
# |Lan Chi
# |-
# | rowspan="2" |2018
# |''Chuyến đi của thanh xuân''
# | rowspan="2" |[[Phim ngắn]]
# |An
# |-
# |''Tình yêu của tôi''
# |Hoàng Phương
# |-
# |2019
# |''[[Wolf (phim truyền hình Thái Lan)|Wolf]]''
# |[[One 31]]
# |Hải Anh
# |Vai khách mời (tập 4,5)
# |-
# |2021
# |''Mẹ ác ma, cha thiên sứ''
# |[[K+|K+CINE]]
# |Gia Hân
# |Vai phụ
# |-
# |2024
# |''7 năm chưa cưới sẽ chia tay''
# |[[VieON]]
# |Quỳnh Châu
# |Vai khách mời (tập 1,2,3)
# |-
# |2025
# |''Tứ hải phát tài''
# |[[VieON]]
# |Lady Đào
# |Vai phụ
# |}
# [
#     {
#         "title": "Phim điện ảnh",
#         "subsection_wikitext": "{| class=\"wikitable\"\n!Năm\n! Tựa đề\n! Vai diễn\n! Loại vai\n|-\n|2015\n|''[[12 chòm sao: Vẽ đường cho yêu chạy]]''\n| My \n| rowspan=\"2\" |Vai chính\n|-\n|2016\n|''Cho em gần anh thêm chút nữa''\n| Rin\n|-\n| rowspan=\"2\" |2018\n|''[[Tháng năm rực rỡ]]''\n| Tuyết Anh\n| rowspan=\"4\" | Vai thứ\n|-\n|''Người bất tử''\n|Liên\n|-\n|2019\n|''Ngốc ơi tuổi 17''\n|Trân Châu\n|-\n|2020\n|''[[Gái già lắm chiêu 3]]''\n|Khánh My\n|-\n|2021\n|''[[Gái già lắm chiêu V: Những cuộc đời vương giả|Gái già lắm chiêu V]]''\n|Lý Lệ Hà (lúc trẻ)\n|Khách mời\n|-\n|2022\n|''[[Chìa khóa trăm tỷ]]'' \n|Hồ Phương\n|Vai thứ\n|-\n|2024\n|''B4S – Trước giờ \"Yêu\"''\n|Su\n|Vai chính\n|}"
#     },
#     {
#         "title": "Phim dài tập / phim ngắn",
#         "subsection_wikitext": "{| class=\"wikitable\"\n|+\n!Năm\n!Tựa đề\n!Kênh / định dạng\n!Vai diễn\n!Loại vai\n|-\n|2014\n|''Mùa hè tuổi 17''\n|[[Phim ngắn]]\n|Giấc Mơ\n| rowspan=\"5\" |Vai chính\n|-\n| rowspan=\"2\" |2017\n|''Xuân Cười: Món quà đầu năm''\n|[[HTV2]]\n|Cô Hai\n|-\n|''Đôi bạn trời ban''\n|[[Chương trình chiếu mạng|Web drama]]\n|Lan Chi\n|-\n| rowspan=\"2\" |2018\n|''Chuyến đi của thanh xuân''\n| rowspan=\"2\" |[[Phim ngắn]]\n|An\n|-\n|''Tình yêu của tôi''\n|Hoàng Phương\n|-\n|2019\n|''[[Wolf (phim truyền hình Thái Lan)|Wolf]]'' \n|[[One 31]] \n|Hải Anh\n|Vai khách mời (tập 4,5)\n|-\n|2021\n|''Mẹ ác ma, cha thiên sứ''\n|[[K+|K+CINE]]\n|Gia Hân \n|Vai phụ\n|-\n|2024\n|''7 năm chưa cưới sẽ chia tay''\n|[[VieON]]\n|Quỳnh Châu\n|Vai khách mời (tập 1,2,3)\n|-\n|2025\n|''Tứ hải phát tài''\n|[[VieON]]\n|Lady Đào\n|Vai phụ\n|}"
#     }
# ]
# ['Năm', 'Tựa đề', 'Đạo diễn', 'Sản xuất', 'Vai diễn', 'Ghi chú']
# ['Năm', 'Tựa phim', 'Vai diễn', 'Ghi chú']
# ['Năm', ' Tựa đề', ' Vai diễn', ' Loại vai']
# Ngô Thanh Vân
# Ninh Dương Lan Ngọc
# Không
# ABC
# 1 1 2001
# 1 1 ''Hương dẻ''
# 1 1 {{Không}}
# 1 1 {{Không}}
# 1 1 Na lớn
# 2 1 phim truyền hình
# 1 1 2004
# 1 1 ''Rouge''
# ['[[abc||cvd]]', 'abc', 'efd|b']
# Headers: ['Năm', 'Tựa đề', 'Đạo diễn', 'Sản xuất', 'Vai diễn', 'Ghi chú']
#      Năm                                  Tựa đề Đạo diễn Sản xuất  \
# 0   2001                                Hương dẻ    Không    Không
# 1   2004                                   Rouge    Không    Không
# 2   2006                          Ngôi nhà bí ẩn    Không    Không
# 3   2006                               2 trong 1    Không    Không
# 4   2006                     Chuyện tình Sài Gòn    Không    Không
# 5   2007                       Dòng máu anh hùng    Không    Không
# 6   2009                                Bẫy rồng    Không    Không
# 7   2010                       Biệt đội ưng biển    Không    Không
# 8   2011                      Khao khát đỉnh cao    Không       Có
# 9   2012                          Ngọc viễn đông    Không    Không
# 10  2012                      Ngôi nhà trong hẻm    Không    Không
# 11  2012                              Hành trình    Không    Không
# 12  2013                                Lửa Phật    Không    Không
# 13  2015                       Ngày nảy ngày nay    Không       Có
# 14  2016                        Siêu trộm (phim)    Không    Không
# 15  2016                     Ngọa hổ tàng long 2    Không    Không
# 16  2016                 Tấm Cám: Chuyện chưa kể       Có       Có
# 17  2017                            Blade & Soul    Không    Không
# 18  2017                           Cô Ba Sài Gòn    Không       Có
# 19  2017               Star Wars: Jedi cuối cùng    Không    Không
# 20  2017                    Chiếc đũa quyền năng    Không    Không
# 21  2018                           Về quê ăn Tết    Không       Có
# 22  2018                        Song lang (phim)    Không       Có
# 23  2019                              Hai Phượng    Không       Có
# 24  2020                            Chim ưng đen    Không       Có
# 25  2020                           Năm chiến hữu    Không    Không
# 26  2020  The Old Guard: Những chiến binh bất tử    Không    Không
# 27  2021                   Trạng Tí phiêu lưu ký    Không       Có
# 28  2022                            The Princess    không    không
# 29  2022           Thanh Sói – Cúc dại trong đêm       Có       Có
# 30  2023                             Kẻ kiến tạo    Không    Không
# 31  2025                         The Old Guard 2    Không    Không
#
#                          Vai diễn                Ghi chú
# 0                          Na lớn       phim truyền hình
# 1                            Thủy       phim truyền hình
# 2                   Đạo diễn Trúc
# 3                         Như Lan
# 4                             Tâm  2008 chiếu ở Việt Nam
# 5                   Võ Thanh Thúy
# 6            Trinh / Phượng hoàng
# 7   Nữ cảnh sát đa quốc gia Tú Mi
# 8                   Ngô Thanh Vân              365daband
# 9                           Huyên
# 10                           Thảo                   None
# 11                      Người chị              Phim ngắn
# 12                            Ánh
# 13                      Đan Nương
# 14                             Kỳ     Vai diễn khách mời
# 15                         Mantis
# 16                         Dì ghẻ
# 17                        Sát thủ              Phim ngắn
# 18                   Bà Thanh Mai
# 19                     Paige Tico
# 20                           Tien
# 21                       Đậu Xanh
# 22
# 23                     Hai Phượng
# 24                  Điệp vụ Hương              Phim ngắn
# 25                   Hanoi Hannah
# 26                          Quỳnh
# 27
# 28                           Linh
# 29            Dì Lin "Jacqueline"
# 30                           Kami
# 31                          Quỳnh
# {
#     "Phim truyền hình": [
#         {
#             "Năm": "2006",
#             "Tựa": "Mùi ngò gai",
#             "Vai": "MC",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2010",
#             "Tựa": "Cổng mặt trời (phim truyền hình)",
#             "Vai": "Bạn của Quốc",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2010",
#             "Tựa": "Chuyện tình mùa thu",
#             "Vai": "Bảo",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2011",
#             "Tựa": "Một thời ta đuổi bóng",
#             "Vai": "Trí trề",
#             "Chú thích": ""
#         }
#     ],
#     "Phim điện ảnh": [
#         {
#             "Năm": "2010",
#             "Tựa phim": "Công chúa teen và ngũ hổ tướng",
#             "Vai diễn": "MC Trấn Thành",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2012",
#             "Tựa phim": "Gia sư nữ quái",
#             "Vai diễn": "Lê Thắng Trí",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2019",
#             "Tựa phim": "Cua lại vợ bầu",
#             "Vai diễn": "Hồ Trọng Thoại",
#             "Chú thích": "Chú thích web"
#         },
#         {
#             "Năm": "2021",
#             "Tựa phim": "Bố già (phim 2021)",
#             "Vai diễn": "Ông Ba Sang",
#             "Chú thích": "Chú thích web"
#         },
#         {
#             "Năm": "2023",
#             "Tựa phim": "Nhà bà Nữ",
#             "Vai diễn": "Phú Nhuận",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2023",
#             "Tựa phim": "Đất rừng phương Nam (phim)",
#             "Vai diễn": "Bác Ba Phi",
#             "Chú thích": "VnExpress"
#         },
#         {
#             "Năm": "2024",
#             "Tựa phim": "Mai (phim)",
#             "Vai diễn": "Ông Hoàng",
#             "Chú thích": ""
#         },
#         {
#             "Năm": "2025",
#             "Tựa phim": "Bộ tứ báo thủ",
#             "Vai diễn": "Cậu Mười Một",
#             "Chú thích": ""
#         }
#     ],
#     "Phim chiếu mạng": [],
#     "Phim hoạt hình": []
# }
# {'Năm': '2009', 'Tựa phim': 'Gia đình phép thuật', 'Vai diễn': 'Phương', 'Kênh': 'HTV7', 'Type_film': 'Truyền hình'}
# {'Năm': '2010', 'Tựa phim': 'Mệnh lệnh Hoa hồng', 'Vai diễn': 'Bích Thủy', 'Kênh': 'HTV7', 'Type_film': 'Truyền hình'}
# {'Năm': '2014', 'Tựa phim': 'Vừa đi vừa khóc', 'Vai diễn': 'Lụa', 'Kênh': 'VTV3', 'Type_film': 'Truyền hình'}
# {'Năm': '2016', 'Tựa phim': 'Nhân tình lạc lối', 'Vai diễn': 'Mai', 'Kênh': 'VTV6', 'Type_film': 'Truyền hình'}
# {'Năm': '2016', 'Tựa phim': 'Nguyệt thực (phim truyền hình)', 'Vai diễn': 'Mỹ Khanh', 'Kênh': 'VTV3', 'Type_film': 'Truyền hình'}
# {'Năm': '2010', 'Tựa phim': 'Cánh đồng bất tận (phim)', 'Vai diễn': 'Nương', 'Ghi chú': 'Phim dựa trên tập truyện ngắn cùng tên của nhà văn Nguyễn Ngọc Tư.', 'Type_film': 'Điện ảnh'}
# {'Năm': '2011', 'Tựa phim': 'Long Ruồi', 'Vai diễn': 'Xuân', 'Ghi chú': '', 'Type_film': 'Điện ảnh'}
# {'Năm': '2013', 'Tựa phim': 'Tèo em', 'Vai diễn': 'Minh Minh', 'Ghi chú': 'Là bộ phim đầu tiên của Việt Nam thuộc thể loại "Road Trip Comedy".', 'Type_film': 'Điện ảnh'}
# {'Năm': '2015', 'Tựa phim': 'Trúng số (phim 2015)', 'Vai diễn': 'Thơm', 'Ghi chú': 'Phim đại diện cho Việt Nam ở hạng mục Phim ngoại ngữ hay nhất của Giải Oscar lần thứ 88.', 'Type_film': 'Điện ảnh'}
# {'Năm': '2016', 'Tựa phim': 'Tấm Cám: Chuyện chưa kể', 'Vai diễn': 'Cám', 'Ghi chú': 'Phim được lấy cốt truyện từ truyện cổ tích Tấm Cám.', 'Type_film': 'Điện ảnh'}
# {'Năm': '2017', 'Tựa phim': 'Cô Ba Sài Gòn', 'Vai diễn': 'Như Ý', 'Ghi chú': 'Phim được công chiếu trên toàn thế giới vào ngày 14/10/2017 tại Liên hoan phim quốc tế Busan lần thứ 22 ở Hàn Quốc.', 'Type_film': 'Điện ảnh'}
# {'Năm': '2019', 'Tựa phim': 'Cua lại vợ bầu', 'Vai diễn': 'Nhã Linh', 'Ghi chú': '', 'Type_film': 'Điện ảnh'}
# {'Năm': '2020', 'Tựa phim': 'Gái già lắm chiêu 3', 'Vai diễn': 'Ms. Q', 'Ghi chú': '', 'Type_film': 'Điện ảnh'}
# {'Năm': '2021', 'Tựa phim': 'Gái già lắm chiêu V: Những cuộc đời vương giả', 'Vai diễn': 'Khách mua hàng', 'Ghi chú': 'Cameo', 'Type_film': 'Điện ảnh'}
# {'Năm': '2022', 'Tựa phim': 'Cô gái từ quá khứ', 'Vai diễn': 'Hoàng Quyên / Ms. Q', 'Ghi chú': '', 'Type_film': 'Điện ảnh'}
# Victor Vũ
# ['Trấn Thành', 'Ninh Dương Lan Ngọc', 'Ngô Thanh Vân', 'Hồng Đào', 'Kiều Minh Tuấn', 'Victor Vũ', 'Charlie Nguyễn', 'Vũ Ngọc Đãng', 'Kaity Nguyễn', 'Jun Vũ', 'Mạnh Trường', 'Phương Oanh']
# Ngô Thanh Vân là đạo diễn
# Phim do Ngô Thanh Vân đạo diễn
# A và B là C
# Đại học Assumption
# Hà Nội, Việt Nam
# Hà Nội, Việt Nam
# Bỏ qua 'Chương trình truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Diễn xuất trong MV' (không phải bảng wikitable)
# Ngô Thanh Vân [{'Năm': '2007', 'Tựa đề': 'Dòng máu anh hùng', 'Đạo diễn': 'Không', 'Sản xuất': 'Không', 'Vai diễn': 'Võ Thanh Thúy', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2009', 'Tựa đề': 'Bẫy rồng', 'Đạo diễn': 'Không', 'Sản xuất': 'Không', 'Vai diễn': 'Trinh / Phượng hoàng', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2012', 'Tựa đề': 'Ngôi nhà trong hẻm', 'Đạo diễn': 'Không', 'Sản xuất': 'Không', 'Vai diễn': 'Thảo', 'Ghi chú': None, 'Type_film': 'Phim điện ảnh'}, {'Năm': '2013', 'Tựa đề': 'Lửa Phật', 'Đạo diễn': 'Không', 'Sản xuất': 'Không', 'Vai diễn': 'Ánh', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2016', 'Tựa đề': 'Siêu trộm (phim)', 'Đạo diễn': 'Không', 'Sản xuất': 'Không', 'Vai diễn': 'Kỳ', 'Ghi chú': 'Vai diễn khách mời', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2016', 'Tựa đề': 'Tấm Cám: Chuyện chưa kể', 'Đạo diễn': 'Có', 'Sản xuất': 'Có', 'Vai diễn': 'Dì ghẻ', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2017', 'Tựa đề': 'Cô Ba Sài Gòn', 'Đạo diễn': 'Không', 'Sản xuất': 'Có', 'Vai diễn': 'Bà Thanh Mai', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2018', 'Tựa đề': 'Về quê ăn Tết', 'Đạo diễn': 'Không', 'Sản xuất': 'Có', 'Vai diễn': 'Đậu Xanh', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2018', 'Tựa đề': 'Song lang (phim)', 'Đạo diễn': 'Không', 'Sản xuất': 'Có', 'Vai diễn': '', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2019', 'Tựa đề': 'Hai Phượng', 'Đạo diễn': 'Không', 'Sản xuất': 'Có', 'Vai diễn': 'Hai Phượng', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2021', 'Tựa đề': 'Trạng Tí phiêu lưu ký', 'Đạo diễn': 'Không', 'Sản xuất': 'Có', 'Vai diễn': '', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2022', 'Tựa đề': 'Thanh Sói – Cúc dại trong đêm', 'Đạo diễn': 'Có', 'Sản xuất': 'Có', 'Vai diễn': 'Dì Lin "Jacqueline"', 'Ghi chú': '', 'Type_film': 'Phim điện ảnh'}]
# =========================================================
# Bỏ qua 'Diễn xuất' (không phải bảng wikitable)
# Lý Hải [{'Năm': '2015', 'Phim': 'Lật mặt (phim)', 'width=65| Đạo diễn': 'yes', 'width=65| Kịch bản': 'yes', 'width=65| Sản xuất': 'yes', 'Ghi chú': '', 'Type_film': 'Sản xuất'}, {'Năm': '2016', 'Phim': 'Lật mặt 2: Phim trường', 'width=65| Đạo diễn': 'yes', 'width=65| Kịch bản': 'yes', 'width=65| Sản xuất': 'yes', 'Ghi chú': '', 'Type_film': 'Sản xuất'}, {'Năm': '2021', 'Phim': 'Lật mặt: 48h', 'width=65| Đạo diễn': 'yes', 'width=65| Kịch bản': 'yes', 'width=65| Sản xuất': 'yes', 'Ghi chú': '', 'Type_film': 'Sản xuất'}, {'Năm': '2023', 'Phim': 'Lật mặt 6: Tấm vé định mệnh', 'width=65| Đạo diễn': 'yes', 'width=65| Kịch bản': 'yes', 'width=65| Sản xuất': 'yes', 'Ghi chú': '', 'Type_film': 'Sản xuất'}, {'Năm': '2024', 'Phim': 'Lật mặt 7: Một điều ước', 'width=65| Đạo diễn': 'yes', 'width=65| Kịch bản': 'yes', 'width=65| Sản xuất': 'yes', 'Ghi chú': '', 'Type_film': 'Sản xuất'}]
# =========================================================
# Bỏ qua 'Biên kịch' (không phải bảng wikitable)
# Bỏ qua 'Sản xuất phim' (không phải bảng wikitable)
# Bỏ qua 'Giải thưởng' (không phải bảng wikitable)
# Victor Vũ [{'Năm': '2009', 'Tựa phim': 'Chuyện tình xa xứ', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2010', 'Tựa phim': 'Giao lộ định mệnh', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2011', 'Tựa phim': 'Cô dâu đại chiến', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2012', 'Tựa phim': 'Thiên mệnh anh hùng', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2012', 'Tựa phim': 'Scandal: Bí mật thảm đỏ', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2014', 'Tựa phim': 'Cô dâu đại chiến 2', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2014', 'Tựa phim': 'Quả tim máu', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2015', 'Tựa phim': 'Tôi thấy hoa vàng trên cỏ xanh (phim)', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2019', 'Tựa phim': 'Mắt biếc (phim)', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2021', 'Tựa phim': 'Thiên thần hộ mệnh', 'Ghi chú': '', 'Type_film': 'Đạo diễn'}, {'Năm': '2022', 'Tựa phim': 'Trại hoa đỏ (phim)', 'Ghi chú': 'Phim truyền hình', 'Type_film': 'Đạo diễn'}]
# =========================================================
# ...
# =========================================================
# Bỏ qua 'Biên kịch hài' (không phải bảng wikitable)
# Charlie Nguyễn [{'Năm': '2001', 'Tựa đề': 'Vật đổi sao dời', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'no', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2007', 'Tựa đề': 'Dòng máu anh hùng', 'Đạo diễn': 'yes', 'Sản xuất': 'yes', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2010', 'Tựa đề': 'Để Mai tính', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'no', 'Ghi chú': 'Vai diễn: Antoine', 'Type_film': 'Phim'}, {'Năm': '2010', 'Tựa đề': 'Khát vọng Thăng Long', 'Đạo diễn': 'no', 'Sản xuất': 'no', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2011', 'Tựa đề': 'Long Ruồi', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'no', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2012', 'Tựa đề': 'Cưới ngay kẻo lỡ', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2013', 'Tựa đề': 'Bụi đời Chợ Lớn', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'yes', 'Ghi chú': 'Không phát hành', 'Type_film': 'Phim'}, {'Năm': '2013', 'Tựa đề': 'Tèo em', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2014', 'Tựa đề': 'Để Mai tính 2', 'Đạo diễn': 'yes', 'Sản xuất': 'no', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2017', 'Tựa đề': 'Em chưa 18', 'Đạo diễn': 'no', 'Sản xuất': 'yes', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}, {'Năm': '2018', 'Tựa đề': 'Hồn papa da con gái', 'Đạo diễn': 'no', 'Sản xuất': 'yes', 'Biên kịch': 'yes', 'Ghi chú': '', 'Type_film': 'Phim'}]
# =========================================================
# Jun Vũ [{'Năm': '2015', ' Tựa đề': '12 chòm sao: Vẽ đường cho yêu chạy', ' Vai diễn': 'My', ' Loại vai': 'Vai chính', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2018', ' Tựa đề': 'Tháng năm rực rỡ', ' Vai diễn': 'Tuyết Anh', ' Loại vai': 'Vai thứ', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2020', ' Tựa đề': 'Gái già lắm chiêu 3', ' Vai diễn': 'Khánh My', ' Loại vai': 'Vai thứ', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2021', ' Tựa đề': 'Gái già lắm chiêu V: Những cuộc đời vương giả', ' Vai diễn': 'Lý Lệ Hà (lúc trẻ)', ' Loại vai': 'Khách mời', 'Type_film': 'Phim điện ảnh'}, {'Năm': '2022', ' Tựa đề': 'Chìa khóa trăm tỷ', ' Vai diễn': 'Hồ Phương', ' Loại vai': 'Vai thứ', 'Type_film': 'Phim điện ảnh'}]
# {'tên': 'Ninh Dương Lan Ngọc', 'hình': 'Ninh Dương Lan Ngọc trong Mối Tình Đầu Của Tôi.png', 'ghi chú hình': 'Ninh Dương Lan Ngọc vào năm 2019', 'ngày sinh': '{{Birth date and age|1990|4|4}}', 'quốc tịch': '{{VIE}}', 'học vấn': '[[Trường Đại học Sân khấu – Điện ảnh Thành phố Hồ Chí Minh]]', 'công việc': '{{hlist|[[Diễn viên]]}}', 'năm hoạt động': '2009–nay', 'giải thưởng': '[[#Giải thưởng và đề cử|Danh sách]]', 'nơi sinh': '[[Thành phố Hồ Chí Minh]], [[Việt Nam]]', 'dân tộc': '[[Người Việt|Kinh]]', 'quê quán': '[[Nam Định]], [[Việt Nam]]', 'notable works': '[[#Danh sách phim|Danh sách]]', 'signature': 'Signature of Ninh Duong Lan Ngoc.svg'}
# {'tên': 'Ninh Dương Lan Ngọc', 'hình': 'Ninh Dương Lan Ngọc trong Mối Tình Đầu Của Tôi.png', 'ghi chú hình': 'Ninh Dương Lan Ngọc vào năm 2019', 'ngày sinh': '1990-04-04', 'quốc tịch': 'Việt Nam', 'học vấn': 'Trường Đại học Sân khấu – Điện ảnh Thành phố Hồ Chí Minh', 'công việc': '{{hlist|Diễn viên}}', 'năm hoạt động': '2009–nay', 'giải thưởng': 'Danh sách', 'nơi sinh': 'Thành phố Hồ Chí Minh, Việt Nam', 'dân tộc': 'Kinh', 'quê quán': 'Nam Định, Việt Nam', 'notable works': 'Danh sách', 'signature': 'Signature of Ninh Duong Lan Ngoc.svg'}
# =>is_film_infobox: là infobox actor/director, ko là film
# ndln --> False
# Mùi ngò gai --> True
# Mắt biếc (phim) --> True
# Gia sư nữ quái --> True
# Cổng mặt trời (phim truyền hình) --> True
# *[[Khương Ngọc]] trong vai ''Thiếu Giang''<ref>{{Chú thích web|url=https://znews.vn/chuyen-tinh-mua-thu-cua-khuong-ngoc-thanh-truc-post85171.html|tựa đề='Chuyện tình mùa thu' của Khương Ngọc - Thanh Trúc|tác giả=Phạm Lữ|ngày=2010-05-29|website=Zing News|nhà xuất bản=Bưu điện Việt Nam|url-status=live|ngày truy cập=2022-03-12}}</ref>
# *[[Thanh Trúc]] trong vai ''Thiên Hương''<ref>{{Chú thích web|url=https://plo.vn/van-hoa/thanh-truc-lai-vao-phim-tinh-cam-196351.html|tựa đề=Thanh Trúc lại vào phim tình cảm|tác giả=H.Bình|ngày=2010-05-15|website=[[Pháp Luật Thành phố Hồ Chí Minh (báo)|Pháp Luật Thành phố Hồ Chí Minh]]|url-status=live|ngày truy cập=2022-03-12}}</ref>
# *[[Kim Xuân|NSND Kim Xuân]] trong vai ''Bà Ngọc''
# *Trọng Nhân trong vai ''Ninh''
# *[[Công Ninh|NSƯT Công Ninh]] trong vai ''Ông Phước Đà Lạt''
# *[[Huỳnh Anh Tuấn]] trong vai ''Ông Quý''
# *Kim Phượng trong vai ''Tuyết''
# *Diệu Đức trong vai ''Bà An''
# *Mã Trung trong vai ''Ông An''
# *Quốc Hùng trong vai ''Ông Hoàng''
# *Hải Lý trong vai ''Bà Hân''
# *Huy Cường trong vai ''Bình''
# *Lục Diệp trong vai ''Hoa''
# *Lập Xuân trong vai ''Vy''
# *[[Trấn Thành]] trong vai ''Bảo''
# *Lộc Uyển trong vai ''Diễm''
# *Quách Hữu Lộc trong vai ''Thiện''
# Cùng một số diễn viên khác....
# --- Row 15 ---
# |''thiện''
# | style="text-align:center;" | -
# | colspan="2" |[[lương thế thành]]<ref name=":2" />
# Sanaly
# ['[[Lương Thế Thành]]', '[[ninh dương lan ngọc]]']
# [{'actor_name': 'Angela Phương Trinh', 'character': 'Vy'}, {'actor_name': 'Phạm Thị Ngọc Trinh', 'character': 'Vy'}, {'actor_name': 'Hồng Ánh', 'character': 'Vy'}]
# [{'actor_name': 'Angela Phương Trinh', 'character': 'Vy'}, {'actor_name': 'Phạm Thị Ngọc Trinh', 'character': 'Vy'}, {'actor_name': 'Hồng Ánh', 'character': 'Vy'}]
# [{'actor_name': 'Lương Thế Thành', 'character': 'thiện'}]
# Thanh Niên (báo) check_type_of_infobox không là person
# Dân trí (báo) check_type_of_infobox không là person
# Người lao động (báo) check_type_of_infobox không là person
# Tường Vy ko có wikitext
# Thanh Thủy (diễn viên) check_type_of_infobox không là person
# 21
# Thanh Niên (báo) check_type_of_infobox không là person
# Dân trí (báo) check_type_of_infobox không là person
# Người lao động (báo) check_type_of_infobox không là person
# Tường Vy ko có wikitext
# Thanh Thủy (diễn viên) check_type_of_infobox không là person
# [[{'actor_name': 'Angela Phương Trinh', 'character': 'Vy'}, {'actor_name': 'Phạm Thị Ngọc Trinh', 'character': 'Vy'}, {'actor_name': 'Hồng Ánh', 'character': 'Vy'}], [{'actor_name': 'Thành Lộc', 'character': 'Hoàng'}], [{'actor_name': 'Kim Xuân', 'character': 'Bà Thanh'}], [{'actor_name': 'Việt Anh (nghệ sĩ)', 'character': 'Ông Mạnh'}], [{'actor_name': 'Tấn Beo', 'character': 'Hùng'}], [{'actor_name': 'Mỹ Duyên', 'character': 'Hiền'}], [{'actor_name': 'Lý Thanh Thảo', 'character': 'Thủy'}], [{'actor_name': 'Hòa Hiệp (diễn viên)', 'character': 'Khanh'}], [{'actor_name': 'Yeye Nhật Hạ', 'character': 'Phương'}, {'actor_name': 'Kim Hiền (diễn viên)', 'character': 'Phương'}], [{'actor_name': 'Đình Toàn', 'character': 'Bảo'}], [{'actor_name': 'Lê Khánh', 'character': 'Sanaly'}], [{'actor_name': 'Lương Thế Thành', 'character': 'Thiện'}], [{'actor_name': 'Cao Minh Đạt', 'character': 'Trường'}, {'actor_name': 'Cao Minh Đạt', 'character': 'Trường'}], [{'actor_name': 'Hương Giang (diễn viên)', 'character': 'Oanh'}], [{'actor_name': 'Tiết Cương', 'character': 'Tùng'}], [{'actor_name': 'Ngọc Lan (diễn viên sinh năm 1985)', 'character': 'Nương'}], [{'actor_name': 'Thanh Phương (diễn viên)', 'character': 'Luân'}], [{'actor_name': 'Hoàng Trinh (diễn viên)', 'character': 'Bà Lan'}], [{'actor_name': 'Mai Thành', 'character': 'Ông Sang'}], [{'actor_name': 'Hạnh Thúy', 'character': 'Cô giáo tiểu học'}], [{'actor_name': 'Thiên Kim (diễn viên)', 'character': 'Bà nội Hoàng'}]]
# {'caption': 'Diễn viên Kim Hiền', 'image': 'Kim Hiền MCV 2020.jpg', 'name': 'Kim Hiền', 'religion': '[[Công giáo tại Việt Nam|Công giáo]]', 'quốc tịch': '{{VIE}}<br>{{USA}}', 'nghề nghiệp': '{{hlist|[[Diễn viên]]|[[Người dẫn chương trình]]|[[Ca sĩ]]|Người mẫu ảnh}}', 'spouse': '{{marriage|Hoàng Phong|2010|2010|end=div}}<br/>{{marriage|Andy|2014}}', 'children': '2', 'website': '[https://www.facebook.com/Kim-Hien-177419805644885/ Facebook]<br>[http://www.kimhien.info/ Kim Hien Official]', 'years_active': '1994 – 2018 (diễn viên)', 'birth_name': 'Nguyễn Thị Kim Hiền', 'birth_date': '{{ngày sinh và tuổi|1982|1|6}}', 'birth_place': '[[Thành phố Hồ Chí Minh]], [[Việt Nam]]', 'other_name': 'Út Ráng'}
# [{'actor_name': 'Trần Nghĩa diễn viên', 'character': 'Ngạn'}, {'actor_name': 'Trúc Anh', 'character': 'Hà Lan'}, {'actor_name': 'Trần Phong', 'character': 'Dũng'}, {'actor_name': 'Khánh Vân', 'character': 'Trà Long'}, {'actor_name': 'Khánh Huyền', 'character': 'Cô của Hà Lan'}]
# 5
# [{'actor_name': 'Khương Ngọc', 'character': 'Thiếu Giang'}, {'actor_name': 'Thanh Trúc', 'character': 'Thiên Hương'}, {'actor_name': 'Kim Xuân', 'character': 'Bà Ngọc'}, {'actor_name': 'Trọng Nhân', 'character': 'Ninh'}, {'actor_name': 'Công Ninh', 'character': 'Ông Phước Đà Lạt'}, {'actor_name': 'Huỳnh Anh Tuấn', 'character': 'Ông Quý'}, {'actor_name': 'Kim Phượng', 'character': 'Tuyết'}, {'actor_name': 'Diệu Đức', 'character': 'Bà An'}, {'actor_name': 'Mã Trung', 'character': 'Ông An'}, {'actor_name': 'Quốc Hùng', 'character': 'Ông Hoàng'}, {'actor_name': 'Hải Lý', 'character': 'Bà Hân'}, {'actor_name': 'Huy Cường', 'character': 'Bình'}, {'actor_name': 'Lục Diệp', 'character': 'Hoa'}, {'actor_name': 'Lập Xuân', 'character': 'Vy'}, {'actor_name': 'Trấn Thành', 'character': 'Bảo'}, {'actor_name': 'Lộc Uyển', 'character': 'Diễm'}, {'actor_name': 'Quách Hữu Lộc', 'character': 'Thiện'}]
# [{'actor_name': 'Ngọc Lan (diễn viên)', 'character': 'Thu Hồng'}, {'actor_name': 'Lê Bê La', 'character': 'Tùng'}, {'actor_name': 'Nguyệt Ánh', 'character': 'Cúc'}, {'actor_name': 'Tú Vi', 'character': 'Trà'}, {'actor_name': 'Kha Ly', 'character': 'Liên'}, {'actor_name': 'Hiền Trang', 'character': 'Mai'}, {'actor_name': 'Lương Thế Thành', 'character': 'Bình'}, {'actor_name': 'Hùng Thuận', 'character': 'Cường'}, {'actor_name': 'Hòa Hiệp (diễn viên)', 'character': 'Vỹ'}, {'actor_name': 'Đình Hiếu', 'character': 'Hoàng Giang'}, {'actor_name': 'Nguyễn Lê Bá Thắng', 'character': 'Gia Đoàn'}, {'actor_name': 'Ánh Hoa', 'character': 'Bà Hai'}, {'actor_name': 'Kim Phương', 'character': 'Bà Ba'}, {'actor_name': 'Huỳnh Anh Tuấn', 'character': 'Văn'}, {'actor_name': 'Kinh Quốc', 'character': 'Cao Dũng'}, {'actor_name': 'Công Ninh', 'character': 'Ba Thảo'}, {'actor_name': 'Văn Ruy', 'character': 'Thông'}, {'actor_name': 'Phùng Ngọc Huy', 'character': 'Quốc'}, {'actor_name': 'Mai Phương (diễn viên)', 'character': 'Thái Vân'}, {'actor_name': 'Quang Thảo', 'character': 'Khoa'}, {'actor_name': 'Thiên Kim (diễn viên)', 'character': 'Bà Ngoại Cúc'}, {'actor_name': 'Phi Điểu', 'character': 'Bà Sáu'}, {'actor_name': 'Hoàng Lan (nghệ sĩ)', 'character': 'Bà Nga'}, {'actor_name': 'Trấn Thành', 'character': 'Bạn của Quốc'}, {'actor_name': 'Hải Lý', 'character': 'Bà Gấu (chủ nhà trọ nam)'}, {'actor_name': 'Bảo Giang', 'character': 'Ông Vinh'}, {'actor_name': 'Hữu Thạch', 'character': 'Cậu Đen'}, {'actor_name': 'Huy Cường', 'character': 'Quản Lý Quán Bar'}, {'actor_name': 'Quách Khoa Nam', 'character': 'Toàn'}, {'actor_name': 'Nguyễn Sanh', 'character': 'Thầy Giáo Đoàn'}, {'actor_name': 'Bích Hằng', 'character': 'Bà Chủ Quán Đầu Hẻm'}, {'actor_name': 'Huỳnh Ngân', 'character': 'Ly'}, {'actor_name': 'Thủy Cúc', 'character': 'Mẹ Quốc'}, {'actor_name': 'Lâm Hải Sơn', 'character': 'Luân'}, {'actor_name': 'Kim Phượng', 'character': 'Quản Lý Trung Tâm Gia Sư'}, {'actor_name': 'Hoài An', 'character': 'Bà Ngọc'}, {'actor_name': 'Thái Quốc Nguyên', 'character': 'Tân'}, {'actor_name': 'Huỳnh Ngọc Lan (Lan Mập)', 'character': 'Thúy'}, {'actor_name': 'Hồng Anh', 'character': 'Mẹ Đoàn'}, {'actor_name': 'Thảo Ly', 'character': 'Loan'}, {'actor_name': 'Bảo Khương', 'character': 'Ông Định'}, {'actor_name': 'Thành Bỉ', 'character': 'Bác Sĩ Thành'}, {'actor_name': 'Minh Cường', 'character': 'Tú Nhà Văn'}, {'actor_name': 'Thanh Long Trẻ', 'character': 'Thắng'}, {'actor_name': 'Hồng Thy', 'character': 'Thảo'}, {'actor_name': 'Bảo Tâm', 'character': 'Tuyết'}, {'actor_name': 'Hồng Hạnh', 'character': 'Dì Hoa'}, {'actor_name': 'Puka', 'character': 'Nhân viên trung tâm gia sư'}]
# True
# mùi ngò gai [[{'actor_name': 'Angela Phương Trinh', 'character': 'Vy'}, {'actor_name': 'Phạm Thị Ngọc Trinh', 'character': 'Vy'}, {'actor_name': 'Hồng Ánh', 'character': 'Vy'}], [{'actor_name': 'Thành Lộc', 'character': 'Hoàng'}], [{'actor_name': 'Kim Xuân', 'character': 'Bà Thanh'}], [{'actor_name': 'Việt Anh (nghệ sĩ)', 'character': 'Ông Mạnh'}], [{'actor_name': 'Thanh Niên (báo)', 'character': 'Ông Cường'}], [{'actor_name': 'Tấn Beo', 'character': 'Hùng'}, {'actor_name': 'Dân trí (báo)', 'character': 'Hùng'}], [{'actor_name': 'Mỹ Duyên', 'character': 'Hiền'}], [{'actor_name': 'Lý Thanh Thảo', 'character': 'Thủy'}], [{'actor_name': 'Hòa Hiệp (diễn viên)', 'character': 'Khanh'}], [{'actor_name': 'Yeye Nhật Hạ', 'character': 'Phương'}, {'actor_name': 'Người lao động (báo)', 'character': 'Phương'}, {'actor_name': 'Kim Hiền (diễn viên)', 'character': 'Phương'}], [{'actor_name': 'Đình Toàn', 'character': 'Bảo'}], [{'actor_name': 'Lê Khánh', 'character': 'Sanaly'}], [{'actor_name': 'Lương Thế Thành', 'character': 'Thiện'}], [{'actor_name': 'Cao Minh Đạt', 'character': 'Trường'}, {'actor_name': 'Cao Minh Đạt', 'character': 'Trường'}], [{'actor_name': 'Tường Vy', 'character': 'Hà'}], [{'actor_name': 'Hương Giang (diễn viên)', 'character': 'Oanh'}], [{'actor_name': 'Tiết Cương', 'character': 'Tùng'}], [{'actor_name': 'Thanh Thủy (diễn viên)', 'character': 'Bà Phượng'}], [{'actor_name': 'Ngọc Lan (diễn viên sinh năm 1985)', 'character': 'Nương'}], [{'actor_name': 'Thanh Phương (diễn viên)', 'character': 'Luân'}], [{'actor_name': 'Hoàng Trinh (diễn viên)', 'character': 'Bà Lan'}], [{'actor_name': 'Mai Thành', 'character': 'Ông Sang'}], [{'actor_name': 'Hạnh Thúy', 'character': 'Cô giáo tiểu học'}], [{'actor_name': 'Thiên Kim (diễn viên)', 'character': 'Bà nội Hoàng'}]]
# mắt biếc [{'actor_name': 'Trần Nghĩa diễn viên', 'character': 'Ngạn'}, {'actor_name': 'Trúc Anh', 'character': 'Hà Lan'}, {'actor_name': 'Trần Phong', 'character': 'Dũng'}, {'actor_name': 'Khánh Vân', 'character': 'Trà Long'}, {'actor_name': 'Khánh Huyền', 'character': 'Cô của Hà Lan'}]
# Lựa chọn số phận [{'actor_name': 'Nguyễn Hữu Mười', 'character': 'Thẩm phán Trần Công Minh'}, {'actor_name': 'Nguyễn Văn Báu', 'character': 'Lê Văn Toàn'}, {'actor_name': 'Trần Nhượng', 'character': 'Ông Hinh'}, {'actor_name': 'Quế Hằng', 'character': 'Bà Hà'}, {'actor_name': 'Bình Xuyên', 'character': 'Bùi Văn Phán'}, {'actor_name': 'Hoàng Thanh Du', 'character': 'Huỳnh Đại Long (Long “đại ca”)'}, {'actor_name': 'Lê Tuấn Anh', 'character': 'Thắng “bom”'}, {'actor_name': 'Lê Hồng Liên (Liên "Tít")', 'character': 'Bồ Tình'}, {'actor_name': 'Bùi Minh Phương', 'character': 'Mẹ Tình'}, {'actor_name': 'Tùng Linh', 'character': 'Huy'}, {'actor_name': 'Hồ Uy Linh', 'character': 'Tùng'}, {'actor_name': 'Xuân Hồng', 'character': 'Luật sư Quốc Hưng'}, {'actor_name': 'Thuỳ Linh', 'character': 'Thư kí Hoàng Thanh Liên'}, {'actor_name': 'Thanh Hương (diễn viên)', 'character': 'Lê Thị Yến'}, {'actor_name': 'Trần Vân', 'character': 'Thanh'}, {'actor_name': 'Lưu Duy Khánh', 'character': 'Chức'}, {'actor_name': 'Đồng Thanh Bình', 'character': 'Lê Văn Dân'}, {'actor_name': 'Trịnh Xuân Hảo', 'character': 'Lê Văn Cao'}, {'actor_name': 'Nguyễn Khánh Long', 'character': 'Bình'}]

# %%
# crawl data phim và diễn viên từ danh sách seed
def crawl_data(seed_list):
    films_data = {}
    persons_data = {}
    for person in seed_list:
        wikitext = get_wikitext(person)
        print(f"Crawling data for person: {person}")
        person_info = extract_infobox_from_wikitext(wikitext)
        print(f"Person info: {person_info}")
        film_dict = extract_films_from_person_wikitext(wikitext)
        film_info = get_all_films_from_films_dict(film_dict)
        film_list = []
        for film in film_info:
            # Ưu tiên các trường phổ biến
            
            title = film.get('Tựa đề') or film.get('Tên phim')
                             
            # Nếu chưa có, thử tìm key có chứa từ "Tựa"
            if not title:
                for key in film.keys():
                    if "Tựa" in key or "Tên" in key or "Phim" in key:
                        title = film[key]
                        break  # dừng lại khi tìm thấy key đầu tiên
            if not title:
                continue

           

            film_list.append(title)
        print(f"Film info: {film_list}")
        persons_data[person] = {
            'films': film_list,
            'info': person_info
        }
        
        for film in film_list:
            if film not in films_data:
                film_wikitext = get_wikitext(film)
                film_infobox = extract_infobox_from_wikitext(film_wikitext)
                print(f"Film infobox for {film}: {film_infobox}")
                film_actors = extract_actors_from_film_wikitext(film_wikitext)
                print(f"Film actors for {film}: {film_actors}")
                film_director = extract_directors_from_film(film_wikitext)
                print(f"Film director for {film}: {film_director}")
                if (film_director == [] and film_actors == []):
                    continue  # bỏ qua phim k có dv và đđ
                films_data[film] = {
                    'infobox': film_infobox,
                    'actors': film_actors,
                    'director': film_director
                }
                
    return persons_data, films_data
persons_data, films_info = crawl_data(SEED_LIST)
print(persons_data["Mạnh Trường"])
# Out:
# Crawling data for person: Trấn Thành
# Person info: {'tên': 'Trấn Thành', 'image': 'Trấn Thành 191226.png', 'caption': 'Trấn Thành vào năm 2019', 'tên khai sinh': 'Huỳnh Trấn Thành', 'ngày sinh': '{{ngày sinh và tuổi|1987|2|5}}', 'chiều cao': '{{convert|1,71|m}}', 'nơi sinh': '[[Thành phố Hồ Chí Minh]], [[Việt Nam]]', 'tên khác': 'A Xìn', 'công việc': '{{hlist|[[Diễn viên]]|[[Nghệ sĩ hài]]|[[Người dẫn chương trình]]|[[Doanh nhân]]|[[Nhà làm phim]]}}', 'năm hoạt động': '2006–nay', 'giải thưởng': '[[Danh sách giải thưởng và đề cử của Trấn Thành|Danh sách]]', 'quốc tịch': '{{VIE}}', 'dân tộc': '[[Người Việt|Kinh]]<br>[[Dân tộc Trung Hoa|Hoa]]', 'notable_works': '[[Sự nghiệp điện ảnh của Trấn Thành|Danh sách]]', 'quê quán': '[[Quảng Đông]], [[Trung Quốc]]', 'spouse': '{{marriage|[[Hari Won]]|2016}}', 'cha': 'Huỳnh Chấn Liêm', 'mẹ': 'Phạm Thị Hạnh Dung', 'người thân': '{{plainlist|\n* Huỳnh Trinh Mi {{small|(em gái)}}\n* [[Huỳnh Uyển Ân]] {{small|(em gái)}}\n}}', 'học vấn': '[[Trường Đại học Sân khấu – Điện ảnh Thành phố Hồ Chí Minh]]', 'signature': 'Signature of Tran Thanh.svg'}
# Film info: ['Mùi ngò gai', 'Cổng mặt trời (phim truyền hình)', 'Chuyện tình mùa thu', 'Một thời ta đuổi bóng', 'Công chúa teen và ngũ hổ tướng', 'Gia sư nữ quái', 'Cua lại vợ bầu', 'Bố già (phim 2021)', 'Nhà bà Nữ', 'Đất rừng phương Nam (phim)', 'Mai (phim)', 'Bộ tứ báo thủ']
# Film infobox for Mùi ngò gai: {'name': 'Mùi ngò gai', 'image': 'MuiNgoGai.gif', 'caption': 'Bìa đĩa phim phần 2', 'thể loại': '[[Tâm lý xã hội]]<br>[[Tình cảm]]<br>[[Gia đình]]', 'định dạng': '[[Phim truyền hình]]', 'director': 'Kim Hyo-joong<br>Han Chul-soo<br>Chu Thiện<br>Trần Hữu Phúc', 'producer': 'Kim Se-huyk', 'writer': 'Kwon In-chan<br>Kim Mi-kyung<br>Cầm Phong', 'starring': '[[Angela Phương Trinh]]<br/>[[Ngọc Trinh (diễn viên)|Ngọc Trinh]]<br/>[[Hồng Ánh]]<br/>Minh Hoàng<br/>[[Việt Anh (nghệ sĩ)|Việt Anh]]<br/>[[Kim Xuân]]<br/>[[Thành Lộc]]<br/>[[Hòa Hiệp (diễn viên)|Hòa Hiệp]]<br/>[[Kim Hiền (diễn viên)|Kim Hiền]]', 'music': 'Jang So-young<br>[[Tuấn Khanh (nhạc sĩ sinh 1968)|Tuấn Khanh]]', 'đơn vị sản xuất': 'Hãng phim Gia đình Việt<br/>[[CJ E&M]]', 'network': '[[HTV9]]', 'first_aired': '3 tháng 12 năm 2006 – 18 tháng 5 năm 2007 (phần 1, 2)<br/>28 tháng 4 năm 2008 (phần 3)', 'runtime': '45 phút/tập (không bao gồm [[quảng cáo]])', 'country': '{{VIE}}<br/>{{KOR}}', 'language': '[[tiếng Việt]]', 'kinh phí': '40 tỉ VND', 'số tập': '53 (phần 1)<br/>19 (phần 2)<br/>34 (phần 3)'}
# Film actors for Mùi ngò gai: [[{'actor_name': 'Angela Phương Trinh', 'character': 'Vy'}, {'actor_name': 'Phạm Thị Ngọc Trinh', 'character': 'Vy'}, {'actor_name': 'Hồng Ánh', 'character': 'Vy'}], [{'actor_name': 'Thành Lộc', 'character': 'Hoàng'}], [{'actor_name': 'Kim Xuân', 'character': 'Bà Thanh'}], [{'actor_name': 'Việt Anh (nghệ sĩ)', 'character': 'Ông Mạnh'}], [{'actor_name': 'Thanh Niên (báo)', 'character': 'Ông Cường'}], [{'actor_name': 'Tấn Beo', 'character': 'Hùng'}, {'actor_name': 'Dân trí (báo)', 'character': 'Hùng'}], [{'actor_name': 'Mỹ Duyên', 'character': 'Hiền'}], [{'actor_name': 'Lý Thanh Thảo', 'character': 'Thủy'}], [{'actor_name': 'Hòa Hiệp (diễn viên)', 'character': 'Khanh'}], [{'actor_name': 'Yeye Nhật Hạ', 'character': 'Phương'}, {'actor_name': 'Người lao động (báo)', 'character': 'Phương'}, {'actor_name': 'Kim Hiền (diễn viên)', 'character': 'Phương'}], [{'actor_name': 'Đình Toàn', 'character': 'Bảo'}], [{'actor_name': 'Lê Khánh', 'character': 'Sanaly'}], [{'actor_name': 'Lương Thế Thành', 'character': 'Thiện'}], [{'actor_name': 'Cao Minh Đạt', 'character': 'Trường'}, {'actor_name': 'Cao Minh Đạt', 'character': 'Trường'}], [{'actor_name': 'Tường Vy', 'character': 'Hà'}], [{'actor_name': 'Hương Giang (diễn viên)', 'character': 'Oanh'}], [{'actor_name': 'Tiết Cương', 'character': 'Tùng'}], [{'actor_name': 'Thanh Thủy (diễn viên)', 'character': 'Bà Phượng'}], [{'actor_name': 'Ngọc Lan (diễn viên sinh năm 1985)', 'character': 'Nương'}], [{'actor_name': 'Thanh Phương (diễn viên)', 'character': 'Luân'}], [{'actor_name': 'Hoàng Trinh (diễn viên)', 'character': 'Bà Lan'}], [{'actor_name': 'Mai Thành', 'character': 'Ông Sang'}], [{'actor_name': 'Hạnh Thúy', 'character': 'Cô giáo tiểu học'}], [{'actor_name': 'Thiên Kim (diễn viên)', 'character': 'Bà nội Hoàng'}]]
# Film director for Mùi ngò gai: đạo diễn không có wikilink
# Film infobox for Cổng mặt trời (phim truyền hình): {'tên': 'Cổng mặt trời', 'hình': 'Áp phích phim Cổng mặt trời.jpg', 'kích thước hình': '230px', 'thể loại': '[[Tâm lý xã hội]]<br>[[Tình cảm]]<br>[[Hài hước]]', 'định dạng': '[[Phim truyền hình]]', 'kịch bản': 'Hoàng Anh<br>Cát Minh<br>Nhật Đăng San', 'đạo diễn': '[[Nguyễn Dương]]', 'diễn viên': '[[Lương Thế Thành]]<br>[[Hòa Hiệp (diễn viên)|Hòa Hiệp]]<br>Bá Thắng<br>[[Hùng Thuận]]<br>[[Trấn Thành]]<br>[[Đình Hiếu]]<br>[[Ngọc Lan (diễn viên)|Ngọc Lan]]<br>[[Nguyệt Ánh]]<br>[[Kha Ly]]<br>[[Tú Vi]]<br>Hiền Trang<br>[[Lê Bê La]]', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[tiếng Việt]]', 'số tập': '67', 'thời lượng': '45 - 50 phút/tập (không bao gồm [[quảng cáo]])', 'đơn vị sản xuất': '[[Đài Truyền hình Thành phố Hồ Chí Minh]]<br/>Công ty cổ phần truyền thông đa phương tiện Lasta', 'kênh': '[[HTV7]]', 'phát sóng đầu': '22 tháng 1 năm 2010', 'phát sóng cuối': '27 tháng 3 năm 2010'}
# Film actors for Cổng mặt trời (phim truyền hình): [{'actor_name': 'Ngọc Lan (diễn viên)', 'character': 'Thu Hồng'}, {'actor_name': 'Lê Bê La', 'character': 'Tùng'}, {'actor_name': 'Nguyệt Ánh', 'character': 'Cúc'}, {'actor_name': 'Tú Vi', 'character': 'Trà'}, {'actor_name': 'Kha Ly', 'character': 'Liên'}, {'actor_name': 'Hiền Trang', 'character': 'Mai'}, {'actor_name': 'Lương Thế Thành', 'character': 'Bình'}, {'actor_name': 'Hùng Thuận', 'character': 'Cường'}, {'actor_name': 'Hòa Hiệp (diễn viên)', 'character': 'Vỹ'}, {'actor_name': 'Đình Hiếu', 'character': 'Hoàng Giang'}, {'actor_name': 'Nguyễn Lê Bá Thắng', 'character': 'Gia Đoàn'}, {'actor_name': 'Ánh Hoa', 'character': 'Bà Hai'}, {'actor_name': 'Kim Phương', 'character': 'Bà Ba'}, {'actor_name': 'Huỳnh Anh Tuấn', 'character': 'Văn'}, {'actor_name': 'Kinh Quốc', 'character': 'Cao Dũng'}, {'actor_name': 'Công Ninh', 'character': 'Ba Thảo'}, {'actor_name': 'Văn Ruy', 'character': 'Thông'}, {'actor_name': 'Phùng Ngọc Huy', 'character': 'Quốc'}, {'actor_name': 'Mai Phương (diễn viên)', 'character': 'Thái Vân'}, {'actor_name': 'Quang Thảo', 'character': 'Khoa'}, {'actor_name': 'Thiên Kim (diễn viên)', 'character': 'Bà Ngoại Cúc'}, {'actor_name': 'Phi Điểu', 'character': 'Bà Sáu'}, {'actor_name': 'Hoàng Lan (nghệ sĩ)', 'character': 'Bà Nga'}, {'actor_name': 'Trấn Thành', 'character': 'Bạn của Quốc'}, {'actor_name': 'Hải Lý', 'character': 'Bà Gấu (chủ nhà trọ nam)'}, {'actor_name': 'Bảo Giang', 'character': 'Ông Vinh'}, {'actor_name': 'Hữu Thạch', 'character': 'Cậu Đen'}, {'actor_name': 'Huy Cường', 'character': 'Quản Lý Quán Bar'}, {'actor_name': 'Quách Khoa Nam', 'character': 'Toàn'}, {'actor_name': 'Nguyễn Sanh', 'character': 'Thầy Giáo Đoàn'}, {'actor_name': 'Bích Hằng', 'character': 'Bà Chủ Quán Đầu Hẻm'}, {'actor_name': 'Huỳnh Ngân', 'character': 'Ly'}, {'actor_name': 'Thủy Cúc', 'character': 'Mẹ Quốc'}, {'actor_name': 'Lâm Hải Sơn', 'character': 'Luân'}, {'actor_name': 'Kim Phượng', 'character': 'Quản Lý Trung Tâm Gia Sư'}, {'actor_name': 'Hoài An', 'character': 'Bà Ngọc'}, {'actor_name': 'Thái Quốc Nguyên', 'character': 'Tân'}, {'actor_name': 'Huỳnh Ngọc Lan (Lan Mập)', 'character': 'Thúy'}, {'actor_name': 'Hồng Anh', 'character': 'Mẹ Đoàn'}, {'actor_name': 'Thảo Ly', 'character': 'Loan'}, {'actor_name': 'Bảo Khương', 'character': 'Ông Định'}, {'actor_name': 'Thành Bỉ', 'character': 'Bác Sĩ Thành'}, {'actor_name': 'Minh Cường', 'character': 'Tú Nhà Văn'}, {'actor_name': 'Thanh Long Trẻ', 'character': 'Thắng'}, {'actor_name': 'Hồng Thy', 'character': 'Thảo'}, {'actor_name': 'Bảo Tâm', 'character': 'Tuyết'}, {'actor_name': 'Hồng Hạnh', 'character': 'Dì Hoa'}, {'actor_name': 'Puka', 'character': 'Nhân viên trung tâm gia sư'}]
# Film director for Cổng mặt trời (phim truyền hình): Nguyễn Dương
# Film infobox for Chuyện tình mùa thu: {'show_name': 'Chuyện tình mùa thu', 'genre': '[[Tình cảm]]<br>[[Tâm lý]]', 'format': '[[Phim truyền hình]]', 'based_on': '"Mùa thu hoa tím" của Hoàng Thu Dung', 'writer': 'Hoàng Thu Dung', 'director': 'Trương Dũng', 'starring': '[[Khương Ngọc]]<br>[[Thanh Trúc]]<br>[[Kim Xuân|NSND Kim Xuân]]<br>Trọng Nhân<br>[[Công Ninh|NSƯT Công Ninh]]<br>[[Huỳnh Anh Tuấn]]', 'country': '{{VIE}}', 'language': '[[tiếng Việt]]', 'num_episodes': '33', 'runtime': '45 phút/tập (không bao gồm [[quảng cáo]])', 'company': 'Công ty Sóng Vàng', 'channel': '[[HTV7]]', 'first_run': '{{VIE}}', 'first_aired': '27 tháng 5 năm 2010', 'last_aired': '24 tháng 6 năm 2010'}
# Film actors for Chuyện tình mùa thu: [{'actor_name': 'Khương Ngọc', 'character': 'Thiếu Giang'}, {'actor_name': 'Thanh Trúc', 'character': 'Thiên Hương'}, {'actor_name': 'Kim Xuân', 'character': 'Bà Ngọc'}, {'actor_name': 'Trọng Nhân', 'character': 'Ninh'}, {'actor_name': 'Công Ninh', 'character': 'Ông Phước Đà Lạt'}, {'actor_name': 'Huỳnh Anh Tuấn', 'character': 'Ông Quý'}, {'actor_name': 'Kim Phượng', 'character': 'Tuyết'}, {'actor_name': 'Diệu Đức', 'character': 'Bà An'}, {'actor_name': 'Mã Trung', 'character': 'Ông An'}, {'actor_name': 'Quốc Hùng', 'character': 'Ông Hoàng'}, {'actor_name': 'Hải Lý', 'character': 'Bà Hân'}, {'actor_name': 'Huy Cường', 'character': 'Bình'}, {'actor_name': 'Lục Diệp', 'character': 'Hoa'}, {'actor_name': 'Lập Xuân', 'character': 'Vy'}, {'actor_name': 'Trấn Thành', 'character': 'Bảo'}, {'actor_name': 'Lộc Uyển', 'character': 'Diễm'}, {'actor_name': 'Quách Hữu Lộc', 'character': 'Thiện'}]
# Film director for Chuyện tình mùa thu: đạo diễn không có wikilink
# Film infobox for Một thời ta đuổi bóng: {'show_name': 'Một thời ta đuổi bóng', 'genre': '[[Tâm lý xã hội]]<br>[[Tình cảm]]', 'format': '[[Phim truyền hình]]', 'writer': 'Hoàng Thu Dung', 'director': 'Trương Dũng', 'starring': '[[Vân Trang]]<br>Khương Thịnh<br>[[Tú Vi]]', 'country': '{{VIE}}', 'language': '[[tiếng Việt]]', 'num_episodes': '32', 'runtime': '45 phút/tập (không bao gồm [[quảng cáo]])', 'company': 'Công ty Sóng Vàng', 'channel': '[[HTV7]]', 'first_aired': '7 tháng 5 năm 2011', 'last_aired': '28 tháng 5 năm 2011'}
# Film actors for Một thời ta đuổi bóng: [{'actor_name': 'Vân Trang', 'character': 'Quý Phi'}, {'actor_name': 'Khương Thịnh', 'character': 'Trần Nghiêm'}, {'actor_name': 'Tú Vi', 'character': 'Trúc'}, {'actor_name': 'Quách Hữu Lộc', 'character': 'Thiên Vũ'}, {'actor_name': 'Kim Xuân', 'character': 'Bà Chi'}, {'actor_name': 'Mai Huỳnh', 'character': 'Ông Quý'}, {'actor_name': 'Thiên Hương', 'character': 'Bà Quý'}, {'actor_name': 'Huỳnh Anh Tuấn', 'character': 'Ông Trực'}, {'actor_name': 'Huy Cường', 'character': 'Sang'}, {'actor_name': 'Lộc Uyển', 'character': 'Lan'}]
# Film director for Một thời ta đuổi bóng: đạo diễn không có wikilink
# Film infobox for Công chúa teen và ngũ hổ tướng: {'name': 'Công chúa teen và ngũ hổ tướng', 'image': 'ccteen.jpg', 'image_size': '260px', 'caption': 'Áp phích của phim.', 'director': 'Lê Lộc', 'producer': '[[Phước Sang|Lưu Phước Sang]]', 'writer': 'Thạch Tuyền', 'narrator': '[[Bảo Thy]]', 'starring': '[[Bảo Thy]]<br />[[Yến Trang]]<br />[[Hoài Linh|NSƯT Hoài Linh]]<br />[[Chí Tài]]<br />[[Tấn Beo]]<br />[[Hiếu Hiền]]<br />[[Mạnh Tràng|NSƯT Mạnh Tràng]]<br />[[Khổng Tú Quỳnh]]<br />[[Hoàng Sơn (diễn viên)|Hoàng Sơn]]<br />Kim Thư', 'music': '[[Bảo Thy]]<br>Tân Rock', 'cinematography': 'Lê Trung Toàn<br>Dương Văn Lễ<br>Nguyễn Thành Út', 'editing': 'Trịnh Quốc Hùng', 'studio': '[[Hãng phim Phước Sang]]', 'distributor': '[[Hãng phim Phước Sang]]', 'released': '4 tháng 2 năm 2010', 'runtime': "'''Phiên bản điện ảnh''': 98 phút<br>'''Phiên bản truyền hình''': 45 phút / tập (4 tập)", 'country': '{{VIE}}', 'language': '[[Tiếng Việt]]', 'gross': "Hơn 25 tỷ VND<ref>[http://news.zing.vn/Nhung-con-so-khung-cua-doanh-thu-phim-Viet-chieu-Tet-post302928.html Những con số 'khủng' của doanh thu phim Việt chiếu Tết], Zing News.</ref>"}
# Film actors for Công chúa teen và ngũ hổ tướng: [{'actor_name': 'Bảo Thy', 'character': 'ca sĩ Britney Bích'}, {'actor_name': 'Yến Trang', 'character': 'ca sĩ Janet Thu'}, {'actor_name': 'Hoài Linh', 'character': 'Kim'}, {'actor_name': 'Tấn Beo', 'character': 'Mộc'}, {'actor_name': 'Chí Tài', 'character': 'Thủy (†)'}, {'actor_name': 'Mạnh Tràng', 'character': 'Hỏa (†)'}, {'actor_name': 'Hiếu Hiền', 'character': 'Thổ'}, {'actor_name': 'Khổng Tú Quỳnh', 'character': 'Dâu Teen'}, {'actor_name': 'Kim Thư', 'character': 'Hoa'}, {'actor_name': 'Hoàng Sơn diễn viên', 'character': 'Đại nổ'}, {'actor_name': 'Chí Thiện ca sĩ', 'character': 'Tâm'}, {'actor_name': 'Ưng Hoàng Phúc', 'character': 'Lãng Tử Phiêu Bồng'}, {'actor_name': 'Đông Nhi', 'character': 'Nhi'}, {'actor_name': 'Noo Phước Thịnh', 'character': 'Bạn trai mới của Nhi'}, {'actor_name': 'Ngô Kiến Huy', 'character': 'Vũ công'}, {'actor_name': 'Phước Sang', 'character': 'Giám đốc công ty vệ sĩ Phong Ba'}, {'actor_name': 'Trấn Thành', 'character': 'MC Trấn Thành'}, {'actor_name': 'Việt Anh nghệ sĩ', 'character': 'Cha của Britney Bích'}, {'actor_name': 'Tuyết Thu', 'character': 'Mẹ của Britney Bích'}, {'actor_name': 'Bảo Quốc', 'character': 'Ông Bảy'}, {'actor_name': 'Khánh Nam', 'character': 'Người đi taxi (†)'}, {'actor_name': 'Cát Phượng', 'character': 'Người đi taxi'}, {'actor_name': 'Mai Thanh Dung', 'character': 'Ngũ Long Công Chúa'}, {'actor_name': 'Tuyền Mập', 'character': 'Khách sửa ống nước'}, {'actor_name': 'Bé Hòa Bình', 'character': 'Em trai của Hỏa'}, {'actor_name': 'Phương Bình', 'character': 'Người đi đường'}, {'actor_name': 'Phi Phụng', 'character': 'Người đi đường'}, {'actor_name': 'Phương Trinh Jolie', 'character': 'Cô gái váy đỏ'}, {'actor_name': 'Kelly Nguyễn', 'character': 'Người tình của cha Bích'}, {'actor_name': 'Vương Khang', 'character': 'Jackie Hoop'}, {'actor_name': 'Tam Thanh', 'character': 'Đệ tử'}, {'actor_name': 'Tấn Bo', 'character': 'Người bán báo'}, {'actor_name': 'Tấn Hoàng', 'character': 'Người say rượu'}, {'actor_name': 'Kim Ngọc nghệ sĩ', 'character': 'Bà cụ (†)'}, {'actor_name': 'Thành Nam', 'character': 'Giám đốc 1'}, {'actor_name': 'Hữu Thạch', 'character': 'Giám đốc 2'}, {'actor_name': 'Thành Chiến', 'character': 'Giám đốc 3'}, {'actor_name': 'Bảo Trí', 'character': 'Bầu sô'}, {'actor_name': 'Lê Kim Long', 'character': 'Bé bán kẹo kéo'}, {'actor_name': 'Kiều Lan', 'character': 'Thím Tư'}, {'actor_name': 'Hứa Minh Đạt', 'character': 'Khán giả'}, {'actor_name': 'Đại Ngọc Trâm', 'character': 'Khán giả'}, {'actor_name': 'Huỳnh Mến', 'character': 'Nữ vũ công'}, {'actor_name': 'Minh Dũng', 'character': 'Anh chàng đồng tính'}, {'actor_name': 'Trần Thanh Hoa', 'character': 'Nữ tay sai của Lãng Tử Phiêu Bồng (†){{Div col end}}'}]
# Film director for Công chúa teen và ngũ hổ tướng: đạo diễn không có wikilink
# Film infobox for Gia sư nữ quái: {'name': 'Gia sư nữ quái', 'image': 'Gia su nu quai.jpg', 'caption': 'Áp phích của bộ phim.', 'director': 'Lê Bảo Trung', 'producer': '[[Mai Thu Huyền]]<br/>Lâm Cẩm Vinh<br/>Lê Bảo Trung', 'screenplay': 'Lê Bảo Trung<br />Bùi Đăng Quốc Thiều', 'story': 'Lê Bảo Trung', 'starring': '[[Isaac (ca sĩ)|Isaac]]<br />[[Bảo Thy]]<br />[[Trấn Thành]]<br />[[Dương Cẩm Lynh]]<br />[[Chí Tài]]<br />[[Hoài Linh]]<br />Hoàng Sơn', 'music': 'Nguyễn Hồng Thuận', 'cinematography': 'Joel David Spezeski', 'editing': 'Phương Thảo', 'studio': 'LBT Entertainment<br />Tincom Media', 'distributor': '[[Galaxy Studio]]', 'released': '{{film date|2012|6|1}}', 'runtime': '89 phút', 'country': '{{VIE}}', 'language': '[[Tiếng Việt]]', '1': '2012', '2': '6', '3': '1'}
# Film actors for Gia sư nữ quái: [{'actor_name': 'Isaac ca sĩ', 'character': 'Lưu Hùng Minh'}, {'actor_name': 'Bảo Thy', 'character': 'Huỳnh Mai'}, {'actor_name': 'Trấn Thành', 'character': 'Lê Thắng Trí'}, {'actor_name': 'Dương Cẩm Lynh', 'character': 'Thanh Thủy'}, {'actor_name': 'Chí Tài', 'character': 'Huỳnh Tài (†)'}, {'actor_name': 'Hoài Linh', 'character': 'Tàu Hũ'}, {'actor_name': 'Hoàng Sơn', 'character': 'Bánh Lọt ===Nhận vật phụ và quần chúng=== {{div col}}'}, {'actor_name': 'Lê Hoàng D1', 'character': 'Hoàng Hotboy'}, {'actor_name': 'Thanh Ngọc', 'character': 'Má Mập'}, {'actor_name': 'Maika', 'character': 'bạn Mai'}, {'actor_name': 'Jennie', 'character': 'bạn Mai'}, {'actor_name': 'Nho', 'character': 'bạn Mai'}, {'actor_name': 'Thu Thảo', 'character': 'bạn Mai'}, {'actor_name': 'Ngọc Anh', 'character': 'bạn Mai'}, {'actor_name': 'Nguyên Lộc', 'character': 'Tám Say'}, {'actor_name': 'Minh Hà', 'character': 'bé Mồi'}, {'actor_name': 'Anh Đức', 'character': 'Tư Bạo'}, {'actor_name': 'Kim Dung', 'character': 'chị Hành'}, {'actor_name': 'Bảo My', 'character': 'vợ Huỳnh Tài'}, {'actor_name': 'Hoàng Chiến', 'character': 'Huỳnh Tài trẻ'}, {'actor_name': 'Đình Hiếu', 'character': 'Huỳnh Tài 12 tuổi'}, {'actor_name': 'Minh Hy', 'character': 'Huỳnh Mai nhỏ'}, {'actor_name': 'D1 Team', 'character': 'drifting'}, {'actor_name': 'Tony Vinh Hiển', 'character': 'trẻ bụi đời'}, {'actor_name': 'Trung Hiệp', 'character': 'trẻ bụi đời'}, {'actor_name': 'Hữu Nghiệp', 'character': 'trẻ bụi đời'}, {'actor_name': 'Minh Cường', 'character': 'trẻ bụi đời'}, {'actor_name': 'Lê Minh Thắng', 'character': 'học sinh tiểu học'}, {'actor_name': 'Lê Minh Trí', 'character': 'học sinh tiểu học'}, {'actor_name': 'Lý Duy Phong', 'character': 'giang hồ'}, {'actor_name': 'Phùng Nhựt Tân', 'character': 'giang hồ'}, {'actor_name': 'Hồ Cát Trắng', 'character': 'giang hồ'}, {'actor_name': 'Sơn Master', 'character': 'giang hồ'}, {'actor_name': 'Châu Xuân Dưỡng', 'character': 'giang hồ'}, {'actor_name': 'Diệp Quốc Tuấn', 'character': 'giang hồ'}, {'actor_name': 'Hồ Hiếu', 'character': 'giang hồ'}, {'actor_name': 'Lê Bảo Long', 'character': 'giang hồ'}, {'actor_name': 'Phù Lợi', 'character': 'giang hồ'}, {'actor_name': 'Hoàng Dung', 'character': 'mẹ Lưu Hùng Minh'}, {'actor_name': 'Chí Thành', 'character': 'ba Lưu Hùng Minh'}, {'actor_name': 'Phi Hùng', 'character': 'bé trai đá banh'}, {'actor_name': 'Anh Tuấn', 'character': 'bé trai đá banh'}, {'actor_name': 'Duy Lực', 'character': 'bé trai đá banh'}, {'actor_name': 'Thành Long', 'character': 'bé trai đá banh'}, {'actor_name': 'Nguyễn Minh Giang', 'character': 'nam sinh'}, {'actor_name': 'Trúc Như', 'character': 'nữ sinh'}, {'actor_name': 'Thanh Bình', 'character': 'chủ quán cà phê'}, {'actor_name': 'Minh Đài', 'character': 'tiếp tân'}, {'actor_name': 'Hoàng Phong Vỹ', 'character': 'lơ xe đò'}, {'actor_name': 'Thế Minh', 'character': 'lái xe trâu'}, {'actor_name': 'Minh Huy', 'character': 'trẻ làng'}, {'actor_name': 'Chiến Công', 'character': 'trẻ làng'}, {'actor_name': 'Thành Công', 'character': 'trẻ làng'}, {'actor_name': 'Tôt Ty', 'character': 'trẻ làng'}, {'actor_name': 'Thanh Phương', 'character': 'trẻ làng'}, {'actor_name': 'Quang Trường', 'character': 'trẻ làng'}, {'actor_name': 'Thùy Trang', 'character': 'thôn nữ'}, {'actor_name': 'Kim Ngân', 'character': 'thôn nữ'}, {'actor_name': 'Thiên Ngân', 'character': 'thôn nữ'}, {'actor_name': 'Ngọc Loan', 'character': 'thôn nữ'}, {'actor_name': 'Tuyết Loan', 'character': 'thôn nữ'}, {'actor_name': 'Đinh Thủy', 'character': 'thôn nữ'}, {'actor_name': 'Ngọc Hương', 'character': 'cung nữ'}, {'actor_name': 'Mỹ Vân', 'character': 'cung nữ'}, {'actor_name': 'Thu Hiền', 'character': 'cung nữ'}, {'actor_name': 'Mỹ Huyền', 'character': 'cung nữ'}, {'actor_name': 'Nguyễn Thị Tuyết', 'character': 'cung nữ'}, {'actor_name': 'Thùy Trang', 'character': 'cung nữ'}, {'actor_name': 'Thùy An', 'character': 'cung nữ'}, {'actor_name': 'Như Ý', 'character': 'cung nữ'}, {'actor_name ...
# Film director for Gia sư nữ quái: đạo diễn không có wikilink
# Film infobox for Cua lại vợ bầu: {'tên': 'Cua lại vợ bầu', 'hình': 'Cua lai vo bau.jpg', 'ghi chú': 'Áp phích của phim.', 'đạo diễn': '[[Nhất Trung (đạo diễn)|Nhất Trung]]', 'sản xuất': 'Quyền ĐH', 'tác giả': '[[Nhất Trung (đạo diễn)|Nhất Trung]]', 'dẫn phim': '[[Trấn Thành]]<br>[[Ninh Dương Lan Ngọc]]', 'diễn viên': '{{Plain list|\n* [[Trấn Thành]]\n* [[Ninh Dương Lan Ngọc]]\n* [[Anh Tú (sinh 1993)|Anh Tú Atus]]\n* [[Hữu Châu|NSƯT Hữu Châu]]\n* [[Đặng Trà Xuân Minh]]\n* [[Hoàng Thanh Mai]]\n* [[Thuận Hoàng]]\n* [[Mạc Văn Khoa]]\n* [[Khả Như]]\n}}', 'âm nhạc': 'Trấn Thành', 'quay phim': 'Lê Đình Tiến', 'dựng phim': 'Nguyễn Định', 'hãng sản xuất': 'ABC Pictures<br>NT Studio<br>NHV Entertainment', 'phát hành': 'Galaxy Distribution', 'công chiếu': '{{Film date|2019|02|05|Việt Nam}}', 'thời lượng': '100 phút', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[Tiếng Việt]]', 'doanh thu': '191,8 tỷ VND<ref>{{Chú thích web|url=https://thanhnien.vn/van-hoa/cua-lai-vo-bau-cong-bo-doanh-thu-1918-ti-dong-1067564.html|tựa đề=Cua lại vợ bầu công bố doanh thu 191,8 tỉ đồng|tác giả=|họ=|tên=|ngày=|website=|url lưu trữ=|ngày lưu trữ=|ngày truy cập=}}</ref><ref>{{Chú thích web|url=https://boxofficevietnam.com/movie/cua-lai-vo-bau/|tựa đề=Doanh số phòng vé phim Cua Lại Vợ Bầu|website=Box Office Vietnam|ngôn ngữ=vi|ngày truy cập=2024-04-13}}</ref>', '1': '2019', '2': '02', '3': '05', '4': 'Việt Nam'}
# Film actors for Cua lại vợ bầu: [{'actor_name': 'Trấn Thành', 'character': 'Trọng Thoại'}, {'actor_name': 'Ninh Dương Lan Ngọc', 'character': 'Nhã Linh'}, {'actor_name': 'Anh Tú sinh 1993', 'character': 'Quý Khánh'}, {'actor_name': 'Mạc Văn Khoa', 'character': 'Tuấn'}, {'actor_name': 'Khả Như', 'character': 'Như'}, {'actor_name': 'Hữu Châu', 'character': 'ông Hữu - ba Nhã Linh'}, {'actor_name': 'Lê Giang nghệ sĩ', 'character': 'bà Lê - mẹ Nhã Linh'}, {'actor_name': 'Quang Minh - Hồng Đào', 'character': 'bà Tài'}, {'actor_name': 'Trung Dân', 'character': 'ông Trung'}, {'actor_name': 'Hari Won', 'character': 'bác sĩ Hằng'}, {'actor_name': 'Thuận Hoàng', 'character': 'Tân'}, {'actor_name': 'Hoàng Thanh Mai', 'character': 'huy'}, {'actor_name': 'Thùy Dương', 'character': 'y tá'}, {'actor_name': 'Thanh Tân', 'character': 'Tân'}, {'actor_name': 'Hữu Thạch', 'character': 'người đi đường'}]
# Film director for Cua lại vợ bầu: Nhất Trung (đạo diễn)
# Film infobox for Bố già (phim 2021): {'tên': 'Bố già', 'hình': 'Bo gia 2021 ap phich.jpg', 'caption': 'Áp phích chiếu rạp của phim tại Việt Nam', 'đạo diễn': '{{Liệt kê|\n* [[Trấn Thành]]\n* [[Vũ Ngọc Đãng]]\n}}', 'sản xuất': 'Nguyễn Phương Thảo', 'kịch bản': '{{Liệt kê|\n* Trấn Thành\n* Bùi An Nhi\n* Lương Nghiêm Huy\n* Hồ Thúc An\n}}', 'cốt truyện': 'Trấn Thành', 'diễn viên': '{{Liệt kê|\n* Trấn Thành\n* [[Tuấn Trần]]\n* [[Ngân Chi]]\n* [[Ngọc Giàu]]\n* [[Lê Giang (nghệ sĩ)|Lê Giang]]\n* Hoàng Mèo\n* [[Lan Phương]]\n* La Thành\n* Quốc Khánh\n}}', 'âm nhạc': '{{Liệt kê|\n* [[Phan Mạnh Quỳnh]]\n* Ngô Minh Hoàng\n}}', 'quay phim': 'Diệp Thế Vinh', 'dựng phim': '{{Liệt kê|\n* Trấn Thành\n* Vũ Khắc Tuận\n* Lê Minh Đức\n}}', 'hãng sản xuất': '{{Liệt kê|\n* [[Trấn Thành Town]]\n* [[Galaxy Studio]]\n* [[HKFilm]]\n}}', 'phát hành': '[[Galaxy Studio]]', 'công chiếu': '{{Filmdate|2021|3|12|[[Việt Nam]]|2021|4|22|[[Malaysia]] & [[Singapore]]|2021|5|22|[[Úc]]|2021|5|28|[[Hoa Kỳ]]}}', 'thời lượng': '128 phút', 'quốc gia': '{{flag|Việt Nam}}', 'ngôn ngữ': '[[Tiếng Việt]]', 'kinh phí': '23 tỷ [[Đồng (đơn vị tiền tệ)|VND]] (954 nghìn USD)', 'doanh thu': '420 tỷ [[Đồng (đơn vị tiền tệ)|VND]] (17.4 triệu USD) <small>([[Việt Nam]])</small><ref name="VN">{{Chú thích web|url=https://laodong.vn/giai-tri/bo-gia-cua-tran-thanh-thu-600-ti-dong-ban-56-trieu-ve-va-se-chieu-o-my-913245.ldo|title="Bố già" của Trấn Thành thu 420 tỉ đồng, bán 5,6 triệu vé và sẽ chiếu ở Mỹ|author=DI PY|website=Báo Lao Động|date = ngày 26 tháng 5 năm 2021 |access-date =ngày 16 tháng 6 năm 2021}}</ref><br/>26 tỷ [[Đồng (đơn vị tiền tệ)|VND]] (1.08 triệu USD) <small>([[Hoa Kỳ]])</small><ref name="US">{{Chú thích web|url=https://m.thanhnien.vn/van-hoa/bo-gia-vuot-moc-1-trieu-usd-doanh-thu-phong-ve-o-my-1399707.html|title=\'Bố già\' vượt mốc 1 triệu USD doanh thu phòng vé ở Mỹ|date = ngày 16 tháng 6 năm 2021 |author=Đỗ Tuấn|website=Báo Thanh Niên|access-date =ngày 16 tháng 6 năm 2021}}</ref>', '1': '2021', '2': '3', '3': '12', '4': '[[Việt Nam]]', '5': '2021', '6': '4', '7': '22', '8': '[[Malaysia]] & [[Singapore]]', '9': '2021', '10': '5', '11': '22', '12': '[[Úc]]', '13': '2021', '14': '5', '15': '28', '16': '[[Hoa Kỳ]]'}
# Film actors for Bố già (phim 2021): [{'actor_name': 'Trấn Thành', 'character': 'Ba Sang'}, {'actor_name': 'Trấn Thành', 'character': 'ông Ba Sang'}, {'actor_name': 'Tuấn Trần', 'character': 'Quắn'}, {'actor_name': 'Ngân Chi', 'character': 'Bù Tọt'}, {'actor_name': 'Ngọc Giàu', 'character': 'bà Hai Giàu'}, {'actor_name': 'Lê Giang nghệ sĩ', 'character': 'bà Cẩm Lệ'}, {'actor_name': 'Hoàng Mèo', 'character': 'Tư Phú'}, {'actor_name': 'Lan Phương', 'character': 'thím Ánh'}, {'actor_name': 'La Thành', 'character': 'Út Quý'}, {'actor_name': 'Quốc Khánh', 'character': 'Bình Lợi'}, {'actor_name': 'Nguyễn Thành Phát', 'character': 'A Sỉn'}, {'actor_name': 'Lê Trang', 'character': 'vợ A Sỉn'}, {'actor_name': 'Nguyễn Minh Tú', 'character': 'Trúc Nhàn'}]
# Film director for Bố già (phim 2021): ['Trấn Thành', 'Vũ Ngọc Đãng']
# Film infobox for Nhà bà Nữ: {'tên': 'Nhà bà Nữ', 'hình': 'Áp phích phim Nhà bà Nữ.jpg', 'ghi chú': 'Áp phích chiếu rạp của phim', 'đạo diễn': '[[Trấn Thành]]', 'sản xuất': '{{plainlist|\n* Trấn Thành\n* Đỗ Hoàng Vũ}}', 'biên kịch': 'Nguyễn Ngọc Huyền Trân', 'cốt truyện': '{{plainlist|\n* Trấn Thành\n* Tạ Anh Đức\n* Lương Nghiêm Huy}}', 'diễn viên': '{{plainlist|\n* [[Lê Giang]]\n* [[Uyển Ân]]\n* [[Song Luân]]\n* [[Trấn Thành]]\n* [[Khả Như]]\n* Quỳnh Lý\n* Phương Lan\n* [[Lê Dương Bảo Lâm|Dương Lâm]]\n* [[Ngọc Giàu]]\n* [[Việt Anh (nghệ sĩ)|Việt Anh]]}}', 'âm nhạc': '{{plainlist|\n* Ngô Minh Hoàng\n* Nguyễn Hoàng Anh}}', 'quay phim': 'Trần Minh Huy', 'dựng phim': '{{plainlist|\n* Vũ Khắc Tuận\n* Phạm Hoàng Nhân}}', 'hãng sản xuất': '{{plainlist|\n* [[CJ HK Entertainment]]\n* KIM Entertainment\n* [[Trấn Thành Town]]}}', 'phát hành': '[[CJ CGV]]', 'công chiếu': '{{Film date|2023|1|22|[[Việt Nam]]|2023|3|3|[[Hoa Kỳ]]|2023|3|9|[[Úc]], [[Singapore]]|2023|3|10|[[Canada]]}}', 'thời lượng': '103 phút', 'quốc gia': '{{VNM}}', 'ngôn ngữ': '[[Tiếng Việt]]', 'budget': '30–35 tỷ [[VND]] (1,2–1,4 triệu USD)', 'doanh thu': '475 tỷ [[Đồng (đơn vị tiền tệ)|VND]] (19,6 triệu USD){{efn|Theo [[Box Office Việt Nam]], \'\'Nhà bà Nữ\'\' thu về 458 tỷ đồng.<ref>{{Chú thích web|url=https://boxofficevietnam.com/movie/nha-ba-nu/|tựa đề=Doanh số phòng vé phim Nhà Bà Nữ|website=Box Office Vietnam|ngôn ngữ=vi|ngày truy cập=2023-02-09|archive-date=2023-01-20|archive-url=https://web.archive.org/web/20230120215748/https://boxofficevietnam.com/movie/nha-ba-nu/|url-status=live}}</ref> Theo ê-kíp sản xuất thì bộ phim có doanh thu là 475 tỷ đồng.<ref name="doanhthu">{{Chú thích web|url=https://giaoducthoidai.vn/post-633487.html|tựa đề=Nhà Bà Nữ trở thành phim có doanh thu cao nhất điện ảnh Việt Nam|ngày=2023-04-07|website=Báo Giáo dục và Thời đại|tác giả=Tuệ An|ngôn ngữ=vi|ngày truy cập=2023-04-07|archive-date=2023-04-07|archive-url=https://web.archive.org/web/20230407152813/https://giaoducthoidai.vn/post-633487.html|url-status=live}}</ref>}} <small>([[Việt Nam]])</small><br/>\n24 tỷ [[Đồng (đơn vị tiền tệ)|VND]] (1 triệu USD) <small>([[Hoa Kỳ]])</small>', '1': '2023', '2': '1', '3': '22', '4': '[[Việt Nam]]', '5': '2023', '6': '3', '7': '3', '8': '[[Hoa Kỳ]]', '9': '2023', '10': '3', '11': '9', '12': '[[Úc]], [[Singapore]]', '13': '2023', '14': '3', '15': '10', '16': '[[Canada]]'}
# Film actors for Nhà bà Nữ: [{'actor_name': 'Uyển Ân', 'character': 'Ngọc Nhi và Ngọc Nữ'}, {'actor_name': 'Lê Giang', 'character': 'Ngọc Nữ'}, {'actor_name': 'Uyển Ân', 'character': 'Ngọc Nhi'}, {'actor_name': 'Song Luân', 'character': 'John'}, {'actor_name': 'Trấn Thành', 'character': 'Phú Nhuận'}, {'actor_name': 'Khả Như', 'character': 'Ngọc Như'}, {'actor_name': 'Ngọc Giàu', 'character': 'Ngọc Ngà'}, {'actor_name': 'Quỳnh Lý', 'character': 'Quỳnh Lý'}, {'actor_name': 'Phương Lan', 'character': 'Lan'}, {'actor_name': 'Lê Dương Bảo Lâm', 'character': 'Lê Minh Hổ'}, {'actor_name': 'Việt Anh nghệ sĩ', 'character': 'ông Liêm'}, {'actor_name': 'Công Ninh', 'character': 'bố của John'}, {'actor_name': 'Ngân Quỳnh', 'character': 'mẹ của John và một số diễn viên phụ khác'}]
# Film director for Nhà bà Nữ: Trấn Thành
# Film infobox for Đất rừng phương Nam (phim): {'tên': 'Đất rừng phương Nam', 'hình': 'Đất rừng phương Nam - Official poster.jpg', 'ghi chú': 'Áp phích chiếu rạp của phim', 'đạo diễn': '[[Nguyễn Quang Dũng (đạo diễn)|Nguyễn Quang Dũng]]', 'sản xuất': '{{plainlist|\n* Nguyễn Trí Viễn\n* Nguyễn Quang Dũng}}', 'biên kịch': 'Trần Khánh Hoàng', 'dựa trên': "{{plainlist|\n* {{dựa trên|''[[Đất rừng phương Nam]]''|[[Đoàn Giỏi]]}}\n* {{dựa trên|''[[Đất phương Nam]]''|[[Nguyễn Vinh Sơn]]}}\n}}", 'diễn viên': '{{plainlist|\n* Huỳnh Hạo Khang\n* Bùi Lý Bảo Ngọc\n* Đỗ Kỳ Phong\n* [[Tuấn Trần]]\n* Tiến Luật\n* [[Băng Di]]\n* [[Trấn Thành]]\n* [[Hứa Vĩ Văn]] \n* Tuyền Mập\n* [[Mai Tài Phến]]\n* [[Huỳnh Đông]]\n* Bích Ngọc\n* [[Công Ninh]]\n* [[Hồng Ánh]]\n}}', 'âm nhạc': '[[Đức Trí]]<ref name="film crew">{{Chú thích web|url=https://laodong.vn/giai-tri/dat-rung-phuong-nam-duoc-nguyen-quang-dung-lam-lai-sau-25-nam-co-gi-moi-991477.ldo|tựa đề="Đất rừng Phương Nam" được Nguyễn Quang Dũng làm lại sau 25 năm có gì mới?|tác giả=Di Py|ngày=2022-01-04|website=[[Báo Lao động]]|ngôn ngữ=vi|url lưu trữ=https://web.archive.org/web/20221221141213/https://laodong.vn/giai-tri/dat-rung-phuong-nam-duoc-nguyen-quang-dung-lam-lai-sau-25-nam-co-gi-moi-991477.ldo|ngày lưu trữ=2022-12-21|url-status=live|ngày truy cập=2022-12-21}}</ref>', 'quay phim': '[[Diệp Thế Vinh]]<ref name="film crew"/>', 'dựng phim': '{{plainlist|\n* Quyền Ngô\n* Trấn Thành\n}}', 'hãng sản xuất': '{{plainlist|\n* [[HKFilm]]\n* [[Galaxy Play]]\n* [[Trấn Thành Town]]\n* KIM Entertainment\n* Hana Entertainment\n}}', 'phát hành': '[[Galaxy Studio]]', 'công chiếu': '{{ngày công chiếu|2023|10|16}}', 'thời lượng': '110 phút', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '{{plainlist|\n* [[Tiếng Việt]]\n* [[Tiếng Pháp]]\n}}', 'kinh phí': '40 tỷ [[VND]]<ref name="budget">{{chú thích web|url=https://vietnamnet.vn/phim-dat-rung-phuong-nam-dau-tu-40-ty-he-lo-canh-hoanh-trang-2141342.html|title=Phim \'Đất rừng phương Nam\' đầu tư 40 tỷ, hé lộ cảnh hoành tráng|author=Tuấn Chiêu|date = ngày 10 tháng 5 năm 2023 |access-date = ngày 10 tháng 5 năm 2023|website=[[VietNamNet]]|url-status=live|archive-date=2023-06-03|archive-url=https://web.archive.org/web/20230603102415/https://vietnamnet.vn/phim-dat-rung-phuong-nam-dau-tu-40-ty-he-lo-canh-hoanh-trang-2141342.html}}</ref>', 'doanh thu': '140,4 tỷ [[VND]]'}
# Film actors for Đất rừng phương Nam (phim): [{'actor_name': 'Huỳnh Hạo Khang', 'character': 'An'}, {'actor_name': 'Huỳnh Đông', 'character': 'Hai Thành'}, {'actor_name': 'Bích Ngọc', 'character': 'Út Trong'}, {'actor_name': 'Công Ninh', 'character': 'ông Ba bắt rắn'}, {'actor_name': 'Hồng Ánh', 'character': 'mẹ của An'}]
# Film director for Đất rừng phương Nam (phim): Nguyễn Quang Dũng (đạo diễn)
# Film infobox for Mai (phim): {'tên': 'MɅI', 'hình': 'Mai 2024 poster.jpg', 'ghi chú': 'Áp phích chiếu rạp của phim', 'đạo diễn': '[[Trấn Thành]]', 'sản xuất': '{{plainlist|\n* Trấn Thành\n* Nguyễn Phương Thảo\n* Nguyễn Hữu Tường Vi\n}}', 'biên kịch': 'Nguyễn Thanh Bình{{efn|Bút danh của Nguyễn Thanh Bình là Bình Bồng Bột, hay Trần Minh.}}', 'cốt truyện': '{{plainlist|\n* Trấn Thành\n* Lương Nghiêm Huy\n* Tạ Anh Đức\n* [[Diệp Thế Vinh]]\n}}', 'diễn viên': '{{plainlist|\n* [[Phương Anh Đào]]\n* [[Tuấn Trần]]\n* [[Trấn Thành]]\n* [[Ngọc Giàu]]\n* [[Khả Như]]\n* [[Uyển Ân]]\n* Anh Đức\n* [[Việt Anh (nghệ sĩ)|Việt Anh]]\n* [[Hồng Đào (diễn viên)|Hồng Đào]]\n}}', 'âm nhạc': 'Nguyễn Hoàng Anh{{efn|name="score"|Nguyễn Hoàng Anh là người soạn tất cả bản nhạc nền cho bộ phim, với phần nhạc bổ sung do Khuất Duy Minh và Ngô Minh Hoàng đồng phụ trách.}}', 'quay phim': '[[Diệp Thế Vinh]]', 'dựng phim': 'Phạm Hoàng Nhân{{efn|name="editing"|Phạm Hoàng Nhân là người đảm nhận vị trí dựng phim chính, với sự hỗ trợ của Vũ Khắc Tuận và Trấn Thành.}}', 'hãng sản xuất': '{{plainlist|\n* [[Trấn Thành Town]]\n* [[CJ HK Entertainment]]\n* [[HKFilm]]\n}}', 'phát hành': '[[CJ CGV]]', 'công chiếu': '{{Ngày công chiếu|2024|2|10|[[Việt Nam]]|2024|2|14|[[Úc]]|2024|3|22|[[Hoa Kỳ]], [[Canada]], [[Châu Âu]]|2024|4|12|[[Đài Loan]]}}', 'thời lượng': '131 phút', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[Tiếng Việt]]', 'kinh phí': '50 tỷ [[VND]]<ref>{{Chú thích web|url=https://www.quochoitv.vn/phim-mai-cong-bo-kinh-phi-dau-tu-50-ty-dong-206466.htm|tựa đề=Phim Mai công bố kinh phí đầu tư 50 tỷ|website=Quốc Hội TV|ngôn ngữ=vi|ngày truy cập=2024-01-10|archive-date=2024-02-13|archive-url=https://web.archive.org/web/20240213110936/https://www.quochoitv.vn/phim-mai-cong-bo-kinh-phi-dau-tu-50-ty-dong-206466.htm|url-status=live}}</ref>', 'doanh thu': '520 tỷ [[VND]]<ref>{{Chú thích web|url=https://boxofficevietnam.com/movie/mai/|tựa đề=Doanh số phòng vé phim Mai|website=Box Office Vietnam|ngôn ngữ=vi|ngày truy cập=2024-03-23}}</ref><ref>{{Chú thích web|url=https://tuoitre.vn/doanh-thu-dao-pho-va-piano-co-the-sai-90-doanh-thu-mai-cao-hon-thuc-te-20240222151904649.htm|tựa đề=Doanh thu Đào, Phở và Piano có thể sai 90%, doanh thu Mai cao hơn thực tế ? |website=Tuổi Trẻ Online|ngôn ngữ=vi|ngày truy cập=2024-02-22}}</ref>{{efn|name="Special-notes"|Theo\xa0[[Box Office Việt Nam]],\xa0MɅI\xa0thu về 550 tỷ đồng.\xa0Theo ê-kíp sản xuất thì bộ phim có doanh thu là 520 tỷ đồng.}}<ref>{{cite web |url=https://www.boxofficemojo.com/releasegroup/gr3949220613/ |title=\'\'Mai\'\' |website=[[Box Office Mojo]] |publisher=[[IMDb]] |accessdate=2025-08-19}}</ref>'}
# Film actors for Mai (phim): [{'actor_name': 'Phương Anh Đào', 'character': 'Mai'}, {'actor_name': 'Phương Anh Đào', 'character': 'Mai'}, {'actor_name': 'Tuấn Trần', 'character': 'Dương (Sâu)'}, {'actor_name': 'Trấn Thành', 'character': 'ông Hoàng'}, {'actor_name': 'Hồng Đào diễn viên', 'character': 'bà Đào'}, {'actor_name': 'Uyển Ân', 'character': 'Bình Minh'}, {'actor_name': 'Ngọc Giàu', 'character': 'Má Mi'}, {'actor_name': 'Khả Như', 'character': 'Trinh'}, {'actor_name': 'Sầu Anh Thư', 'character': 'Lành'}, {'actor_name': 'Anh Phạm', 'character': 'Diễm'}, {'actor_name': 'Trần Tiểu Vy', 'character': 'vợ Dương'}, {'actor_name': 'Việt Anh nghệ sĩ', 'character': 'chú Út'}, {'actor_name': 'Vũ Quốc Khánh', 'character': 'Bobby'}, {'actor_name': 'Lý Hạo Mạnh Quỳnh Quỳnh Lý', 'character': 'Tú quản lý spa'}, {'actor_name': 'Kim Phương', 'character': 'Tú Bà'}, {'actor_name': 'Thanh Hằng nghệ sĩ cải lương', 'character': 'bà Nguyệt'}, {'actor_name': 'Kiều Linh', 'character': 'bà Kiều'}, {'actor_name': 'Ngọc Nga', 'character': 'bà Nga'}, {'actor_name': 'Anh Đức', 'character': 'A Tỷ'}, {'actor_name': 'Lộ Lộ', 'character': 'bà Phụng'}, {'actor_name': 'Ngọc Nguyễn', 'character': 'bà Ngọc hàng xóm'}, {'actor_name': 'Hoàng Mèo', 'character': 'Giang hồ'}, {'actor_name': 'Lê Nam', 'character': 'Công an'}, {'actor_name': 'Nhà bà Nữ', 'character': 'tuyến nhân vật phụ và tập trung làm phim'}]
# Film director for Mai (phim): Trấn Thành
# Film infobox for Bộ tứ báo thủ: {'tên': 'Bộ tứ báo thủ', 'hình': 'Bo tu bao thu poster.jpg', 'ghi chú': 'Áp phích chiếu rạp của phim', 'đạo diễn': '[[Trấn Thành]]', 'sản xuất': '{{plainlist|\n* Trấn Thành\n* Nguyễn Phương Thảo\n}}', 'biên kịch': '{{plainlist|\n* Trấn Thành\n* Phan Minh Mẫn\n}}', 'cốt truyện': '{{plainlist|\n* Trấn Thành\n* Lương Nghiêm Huy\n* Nguyễn Phương Thảo\n}}', 'diễn viên': '{{plainlist|\n* [[Trần Tiểu Vy]]\n* Trần Quốc Anh\n* [[Nguyễn Cao Kỳ Duyên (người mẫu)|Nguyễn Cao Kỳ Duyên]]\n* [[Lê Dương Bảo Lâm]]\n* [[Lê Giang]]\n* [[Uyển Ân]]\n* [[Trấn Thành]]\n}}', 'quay phim': '[[Nguyễn Phan Linh Đan]]', 'dựng phim': 'Phạm Hoàng Nhân', 'âm nhạc': 'Nguyễn Hoàng Anh', 'hãng sản xuất': '{{plainlist|\n* [[Galaxy Studio]]\n* [[HKFilm]]\n* [[Trấn Thành Town]]}}', 'phát hành': '[[Galaxy Studio]]', 'công chiếu': '{{plainlist|\n{{Film date|2025|1|29|[[Việt Nam]]|2025|3|14|[[Châu Âu]]|2025|03|27|[[Úc]]|2025|03|28|[[New Zealand]]|2025|04|18|[[Pháp]], [[Romania]]}}\n{{Film date|2025|5|2|[[Nhật Bản]]|2025|5|11|[[Bulgaria]]|2025|5|21|[[Hàn Quốc]]|2025|05|29|[[Thái Lan]]}}\n}}', 'thời lượng': '132 phút', 'quốc gia': '{{VNM}}', 'ngôn ngữ': '[[Tiếng Việt]]', 'doanh thu': "332,1 tỷ [[VND]]<ref>{{Chú thích web|url=https://boxofficevietnam.com/movie/bo-tu-bao-thu/|tựa đề=Doanh số phòng vé phim Bộ Tứ Báo Thủ|website=Box Office Vietnam|ngôn ngữ=vi|ngày truy cập=2025-07-27}}</ref><ref>{{cite web |url=https://www.boxofficemojo.com/releasegroup/gr3949220613/ |title=''The 4 Rascals'' |website=[[Box Office Mojo]] |publisher=[[IMDb]] |accessdate=2025-08-15}}</ref>", '1': '2025', '2': '5', '3': '2', '4': '[[Nhật Bản]]', '5': '2025', '6': '5', '7': '11', '8': '[[Bulgaria]]', '9': '2025', '10': '5', '11': '21', '12': '[[Hàn Quốc]]', '13': '2025', '14': '05', '15': '29', '16': '[[Thái Lan]]', '17': '2025', '18': '04', '19': '18', '20': '[[Pháp]], [[Romania]]'}
# Film actors for Bộ tứ báo thủ: [{'actor_name': 'Trần Tiểu Vy', 'character': 'Quỳnh Anh'}, {'actor_name': 'Trần Tiểu Vy', 'character': 'Quỳnh Anh'}, {'actor_name': 'Nguyễn Cao Kỳ Duyên người mẫu', 'character': 'Karen'}, {'actor_name': 'Trần Quốc Anh', 'character': 'Quốc Anh'}, {'actor_name': 'Trấn Thành', 'character': 'cậu Mười Một'}, {'actor_name': 'Lê Dương Bảo Lâm', 'character': 'Jessica (Chét-Xi-Cà)'}, {'actor_name': 'Lê Giang', 'character': 'dì Bốn'}, {'actor_name': 'Uyển Ân', 'character': 'Kiều'}, {'actor_name': 'Ngọc Giàu', 'character': 'trong chủ phòng trọ Jessica (Chét-Xi-Cà)'}, {'actor_name': 'Việt Anh nghệ sĩ', 'character': 'sếp Quốc Anh'}, {'actor_name': 'AQuay', 'character': 'Steven'}, {'actor_name': 'Thái Công', 'character': 'Thái Phong'}, {'actor_name': 'Huy Phan', 'character': 'Đình Duy'}, {'actor_name': 'Negav', 'character': 'chồng Kiều'}, {'actor_name': 'Hùng Huỳnh', 'character': 'bạn trai của bạn trai Kiều'}, {'actor_name': 'Quân AP', 'character': 'chàng trai của Quỳnh Anh'}, {'actor_name': 'Vinh Râu', 'character': 'bạn trai Kiều'}, {'actor_name': 'Phạm Anh Duy', 'character': 'nhân viên quán ăn'}, {'actor_name': 'Ali Hoàng Dương', 'character': 'quản lý nhà hàng buffet'}, {'actor_name': 'Lộ Lộ', 'character': 'chủ nhà trọ của Kiều và Quỳnh Anh'}, {'actor_name': 'Lê Nam', 'character': 'dượng Bốn'}, {'actor_name': 'Hoàng Mèo', 'character': 'bạn của dượng Bốn'}, {'actor_name': 'Chị Ca Nô', 'character': 'dì Mười'}, {'actor_name': 'Hải Vót', 'character': 'tiếp tân khách sạn'}, {'actor_name': 'Gia Linh', 'character': 'Thúy Liễu'}, {'actor_name': 'Nhâm Phương Nam', 'character': 'chồng Thúy Liễu'}, {'actor_name': 'Bé Rio', 'character': 'con Thúy Liễu'}, {'actor_name': 'Võ Lan Hương', 'character': 'bà vú'}, {'actor_name': 'Thu Hoài', 'character': 'nữ đại gia'}, {'actor_name': 'Ngọc Hoa', 'character': 'nữ đầu gấu'}, {'actor_name': 'Năm Chà', 'character': 'nữ sinh bị nắm nhằm tay'}, {'actor_name': 'Trinh Hoan & Như Khuê', 'character': 'khách ăn quán bún'}, {'actor_name': 'Lệ Quyên ca sĩ sinh 1981', 'character': 'cặp đôi mua nhà và một số diễn viên phụ khác Cũng giống như dự án [[Nhà bà Nữ]] và [[Mai (phim)|Mai]]'}]
# Film director for Bộ tứ báo thủ: Trấn Thành
# Crawling data for person: Ninh Dương Lan Ngọc
# Person info: {'tên': 'Ninh Dương Lan Ngọc', 'hình': 'Ninh Dương Lan Ngọc trong Mối Tình Đầu Của Tôi.png', 'ghi chú hình': 'Ninh Dương Lan Ngọc vào năm 2019', 'ngày sinh': '{{Birth date and age|1990|4|4}}', 'quốc tịch': '{{VIE}}', 'học vấn': '[[Trường Đại học Sân khấu – Điện ảnh Thành phố Hồ Chí Minh]]', 'công việc': '{{hlist|[[Diễn viên]]}}', 'năm hoạt động': '2009–nay', 'giải thưởng': '[[#Giải thưởng và đề cử|Danh sách]]', 'nơi sinh': '[[Thành phố Hồ Chí Minh]], [[Việt Nam]]', 'dân tộc': '[[Người Việt|Kinh]]', 'quê quán': '[[Nam Định]], [[Việt Nam]]', 'notable works': '[[#Danh sách phim|Danh sách]]', 'signature': 'Signature of Ninh Duong Lan Ngoc.svg'}
# Film info: ['Gia đình phép thuật', 'Mệnh lệnh Hoa hồng', 'Vừa đi vừa khóc', 'Nhân tình lạc lối', 'Nguyệt thực (phim truyền hình)', 'Cánh đồng bất tận (phim)', 'Long Ruồi', 'Tèo em', 'Trúng số (phim 2015)', 'Tấm Cám: Chuyện chưa kể', 'Cô Ba Sài Gòn', 'Cua lại vợ bầu', 'Gái già lắm chiêu 3', 'Gái già lắm chiêu V: Những cuộc đời vương giả', 'Cô gái từ quá khứ']
# Film infobox for Gia đình phép thuật: {'show_name': 'Gia đình phép thuật', 'image': 'Áp phích phim Gia đình phép thuật.gif', 'caption': 'Các nhân vật trái–phải, trên–dưới: YeYe, SuRi, BaRam, PungUn, ChiNi, Châu Tuấn, Hoàng Lan, Tấn Trung, Ngọc Yến, bà Sương và Mai Phương.', 'show_name_2': 'Vườn ảo thuật', 'genre': 'Thiếu nhi<br>Siêu nhiên<br>Hài hước', 'format': '[[Phim truyền hình|Phim truyền hình dài tập]]', 'creator': 'CJ Media {{small|([[Hàn Quốc]])}}', 'developer': 'Công ty VIFA <br> Công ty Chu Thị', 'writer': 'Kwon In-chan', 'director': 'Chu Thiện {{small|(phần 1)}}<br>Sun Oh {{small|(phần 2)}}', 'starring': '[[Việt Anh (nghệ sĩ)|NSND Việt Anh]] <br> [[Hòa Hiệp (diễn viên)|Hòa Hiệp]] <br> [[Đình Toàn]] <br> [[Lý Thanh Thảo]] <br> [[Hương Giang (diễn viên)|Hương Giang]]<br> [[Yeye Nhật Hạ|Nhật Hạ]] <br> [[Gia Kỳ]] <br> [[Kim Xuân|NSND Kim Xuân]] <br> [[Đại Nghĩa (diễn viên)|Đại Nghĩa]] <br> [[Vân Trang]] <br> [[Anh Thư (diễn viên)|Anh Thư]]<br>[[Kim Hiền (diễn viên)|Kim Hiền]] <br> [[Xuân Nghi]] <br> [[Văn Ruy]] <br> [[Tường Vy]] <br> [[Băng Di]] <br> [[Đặng Trà Xuân Minh]]', 'country': '{{VIE}}', 'language': 'Tiếng Việt', 'num_seasons': 'Phần 1: Tập 1 - 250<br>Phần 2: Tập 251 - 340', 'num_episodes': '340 {{small|(tính đến tháng 7 năm 2011)}}', 'executive_producer': 'Võ Thanh Phong {{small|(phần 1-2)}} <br> Phan Thị Thuyết {{small|(phần 1)}} <br> Trương Quốc Khánh {{small|(phần 2)}}', 'producer': 'Công ty VIFA <br> Công ty Chu Thị <br> [[Đài Truyền hình Thành phố Hồ Chí Minh]]', 'editor': 'Huỳnh Thanh Diệu {{small|(phần 1)}} <br> Phạm Ngọc Vân {{small|(phần 2)}}', 'location': '{{VIE}}', 'cinematography': 'Oh Seung-yuep {{small|(phần 1)}} <br> Nguyễn Chánh Minh Luân {{small|(phần 1)}}', 'runtime': '~ 25 phút / tập', 'channel': '[[HTV7]]', 'first_run': '{{VIE}}', 'first_aired': '{{start date|2009|02|22}}', 'last_aired': '{{start date|2011|07|31}}', 'website': 'https://www.youtube.com/playlist?list=PLFk1RtAQGTYXKS5Lg_zLFzd6XfQdNWke2'}
# Film actors for Gia đình phép thuật: [{'actor_name': 'Mai Trần', 'character': 'ông chủ cho thuê nhà của gia đình phái Nguyên Lão (tập 1'}, {'actor_name': 'Ngân Quỳnh', 'character': 'con gái của dì sáu và chú Sáu'}, {'actor_name': 'đóng', 'character': 'bé Trúc Lan'}, {'actor_name': 'Phương Bình đóng', 'character': 'vệ sĩ của Minh Tuấn'}, {'actor_name': 'Phi Điểu', 'character': 'giám đốc trại trẻ'}, {'actor_name': 'Khả Như', 'character': 'cô giáo aerobic'}]
# Film director for Gia đình phép thuật: đạo diễn không có wikilink
# Film infobox for Mệnh lệnh Hoa hồng: {'bgcolor': 'Pink', 'show_name': 'Mệnh lệnh hoa hồng', 'image': 'TuquaiRose.jpg', 'genre': '[[Hài hước]]<br/>[[Hành động viễn tưởng|Hành động]]', 'format': '[[Phim truyền hình]]', 'writer': 'Thanh Hương', 'director': '[[Võ Thanh Hòa]]<ref name=":1" />', 'starring': '[[Lư Hoàng Gia Bảo]]<br>[[Ninh Dương Lan Ngọc]]<br>Đinh Ứng Phi Trường<br>Ngọc Phước<br>[[Nguyệt Ánh]]<br>[[Lương Thế Thành]]<br>[[Ngân Quỳnh]]', 'country': '{{flag|Việt Nam}}', 'language': '[[tiếng Việt]]', 'num_episodes': '60', 'runtime': '25 phút/tập (không bao gồm [[quảng cáo]])', 'company': '[[Đài Truyền hình Thành phố Hồ Chí Minh]]<br/>Hãng phim Gia Đình Việt', 'channel': '[[HTV7]]', 'first_aired': '6 tháng 10 năm 2010', 'last_aired': '25 tháng 2 năm 2011'}
# Film actors for Mệnh lệnh Hoa hồng: [{'actor_name': 'Lưu Hoàng Gia Bảo', 'character': 'Bảo'}, {'actor_name': 'Đinh Ứng Phi Trường', 'character': 'Sơn'}, {'actor_name': 'Ngọc Phước', 'character': 'Hoà Hải'}, {'actor_name': 'Lương Thế Thành', 'character': 'Thầy Nhân'}, {'actor_name': 'Ngân Quỳnh', 'character': 'Cô hiệu phó Và một số diễn viên khác'}]
# Film director for Mệnh lệnh Hoa hồng: Võ Thanh Hòa
# Film infobox for Vừa đi vừa khóc: {'show_name': 'Vừa đi vừa khóc', 'image': 'Vừa đi vừa khóc poster.jpg', 'format': '[[Phim truyền hình]]', 'genre': '[[Hài hước]]<br>[[Tâm lý xã hội]]<br>[[Tình cảm]]', 'writer': '[[Vũ Ngọc Đãng]]', 'director': '[[Vũ Ngọc Đãng]]', 'creative_director': '[[Nguyễn Nam]]<br>Nguyễn Trung', 'starring': '[[Lương Mạnh Hải]]<br>[[Minh Hằng]]<br>[[Nhã Phương (diễn viên)|Nhã Phương]]<br>[[Ninh Dương Lan Ngọc]]<br>[[Thanh Thủy (diễn viên)|Thanh Thủy]]<br>[[Bảo Anh]]<br>La Quốc Hùng', 'theme_music_composer': '[[Minh Thư (ca sĩ)|Minh Thư]]', 'opentheme': '"Vừa đi vừa khóc"', 'endtheme': '"Nắng"', 'country': '{{VNM}}', 'language': '[[Tiếng Việt]]', 'num_episodes': '36', 'cinematography': 'Nguyễn Phương<br>Thanh Phương', 'runtime': '40 - 45 phút/tập (có bao gồm [[quảng cáo]])', 'company': '[[BHD]]<br>TVPlus', 'channel': '[[VTV3]]', 'first_aired': '17 tháng 3 năm 2014', 'last_aired': '7 tháng 7 năm 2014', 'preceded_by': '[[Chỉ có thể là yêu (phim truyền hình Việt Nam)|Chỉ có thể là yêu]]', 'followed_by': '[[Dấu chân du mục]]'}
# Film actors for Vừa đi vừa khóc: [{'actor_name': 'Minh Hằng', 'character': 'Đông Dương'}, {'actor_name': 'Nhã Phương diễn viên', 'character': 'Thêu'}, {'actor_name': 'Phương Thanh', 'character': 'Chanh'}, {'actor_name': 'Văn Tùng', 'character': 'Ông Tùng'}, {'actor_name': 'La Quốc Hùng', 'character': 'Lố'}, {'actor_name': 'Bảo Anh', 'character': 'Bảo Quyên'}]
# Film director for Vừa đi vừa khóc: Vũ Ngọc Đãng
# Film infobox for Nhân tình lạc lối: {'show_name': 'Nhân tình lạc lối', 'genre': '[[Tâm lý xã hội]]<br>[[Tình cảm]]', 'writer': 'Phan Ngọc Diễm Hân', 'director': 'Lê Bảo Trung', 'starring': '[[Chi Bảo]]<br>[[Ninh Dương Lan Ngọc]]<br>[[Huỳnh Đông]]<br>[[Phùng Ngọc Huy]]<br>Đồng Thanh Phong', 'country': '{{VIE}}', 'language': '[[tiếng Việt]]', 'num_episodes': '28', 'runtime': '45 phút/tập (không bao gồm [[quảng cáo]])', 'company': 'V-Art Films', 'channel': '[[VTV9]]', 'first_aired': '7 tháng 7 năm 2016', 'last_aired': '15 tháng 8 năm 2016', 'format': '[[Phim truyền hình]]'}
# Film actors for Nhân tình lạc lối: [{'actor_name': 'Ninh Dương Lan Ngọc', 'character': 'Mai'}, {'actor_name': 'Chi Bảo', 'character': 'Vỹ'}, {'actor_name': 'Huỳnh Đông', 'character': 'Định'}, {'actor_name': 'Đào Bá Sơn', 'character': 'Ông Vinh'}, {'actor_name': 'Phùng Ngọc Huy', 'character': 'Minh'}, {'actor_name': 'Đồng Thanh Phong', 'character': 'Mẫn'}, {'actor_name': 'Tùng Haru', 'character': 'Tân'}, {'actor_name': 'Bá Trường', 'character': 'Ông Lâm'}, {'actor_name': 'Thanh Ngọc', 'character': 'Bà Xuân'}, {'actor_name': 'Hà Linh', 'character': 'Đạt'}, {'actor_name': 'Tam Thanh', 'character': 'Ông Đồng'}, {'actor_name': 'Amy Hương', 'character': 'Bà Yến'}, {'actor_name': 'Nguyễn Hiếu', 'character': 'Thế'}, {'actor_name': 'Kim Dung', 'character': 'Lai'}, {'actor_name': 'Trúc Vân', 'character': 'Thúy'}]
# Film director for Nhân tình lạc lối: đạo diễn không có wikilink
# Film infobox for Nguyệt thực (phim truyền hình): {'show_name': 'Nguyệt thực', 'genre': '[[Tâm lý xã hội]]<br>[[Tình cảm]]', 'writer': 'Chu Thu Hằng', 'director': '[[Trọng Hải|Nguyễn Trọng Hải]]', 'starring': '[[Minh Luân]]<br>Thiên Bảo<br>[[Ninh Dương Lan Ngọc]]<br>[[Tường Vi (diễn viên)|Tường Vi]]<br>[[Don Nguyễn]]', 'country': '{{VIE}}', 'language': '[[tiếng Việt]]', 'num_episodes': '45', 'runtime': '45 phút/tập (không bao gồm [[quảng cáo]])', 'company': 'Công ty cổ phần truyền thông THL', 'channel': '[[VTV3]]', 'first_aired': '13 tháng 6 năm 2016', 'last_aired': '14 tháng 11 năm 2016', 'preceded_by': 'Nữ cảnh sát tập sự', 'followed_by': 'Ngày mai ánh sáng', 'format': '[[Phim truyền hình]]'}
# ...
# Film director for Tình yêu và tham vọng: Bùi Tiến Huy
# Film infobox for Hồ sơ cá sấu: {'image': 'Hồ sơ cá sấu.jpeg', 'genre': '{{Unbulleted list|[[phim tâm lý xã hội|Tâm lý]]|[[Phim hình sự|Hình sự]]|[[Phim hành động|Hành động]]}}', 'show_name_2': "'''Không lối thoát'''", 'writer': 'Tạ Hồng Minh', 'director': '[[Nguyễn Mai Hiền]]', 'starring': '{{Unbulleted list|[[Mạnh Trường]]|[[Kiều Anh]]|[[Hoàng Hải (diễn viên)|Hoàng Hải]]|[[Hoàng Dũng]]|[[Việt Anh (diễn viên)|Việt Anh]]|[[Doãn Quốc Đam]]}}', 'country': '{{VIE}}', 'language': '[[Tiếng Việt]]', 'num_episodes': '38', 'cinematography': '[[Trần Kim Vũ]]', 'runtime': '45 phút / 1 tập<br><small>(bao gồm quảng cáo)</small>', 'company': '[[Trung tâm Phim truyền hình Việt Nam|VFC]]', 'network': '[[VTV3]]', 'first_aired': '{{start date|2020|11|13}}', 'last_aired': '<br>{{end date|2021|04|09}}', 'phần trước': '[[Cát đỏ]]', 'phần sau': "[[Hãy nói lời yêu]]<ref>{{Chú thích web|url=https://vtv.vn/news-20210322144619378.htm|tựa đề='Hãy nói lời yêu' chuẩn bị lên sóng thay thế 'Hồ sơ cá sấu'|tác giả=VTV Kết nối|họ=|tên=|ngày=2021-03-23|website=[[Báo điện tử VTV|Báo điện tử của Đài Truyền hình Việt Nam]]|ngôn ngữ=vi|url-status=live|ngày truy cập=2021-11-22|archive-date=2021-08-05|archive-url=https://web.archive.org/web/20210805184110/https://vtv.vn/news-20210322144619378.htm}}</ref>"}
# Film actors for Hồ sơ cá sấu: [{'actor_name': 'Mạnh Trường', 'character': 'Lê Anh Hải'}, {'actor_name': 'Kiều Anh', 'character': 'Trịnh An Nguyệt'}, {'actor_name': 'Hoàng Hải (diễn viên)', 'character': 'Phạm Văn Tuấn (Tuấn "mỏ")'}, {'actor_name': 'Việt Anh (diễn viên)', 'character': 'Đặng Trung'}, {'actor_name': 'Ngọc Quỳnh', 'character': 'Vũ Văn Quyết'}, {'actor_name': 'Doãn Quốc Đam', 'character': 'Trần Đình Cương (Cương "chột")'}, {'actor_name': 'Phan Minh Huyền', 'character': 'Trịnh Lệ Thu'}, {'actor_name': 'Lan Phương', 'character': 'Minh Lan'}, {'actor_name': 'Bảo Anh (diễn viên)', 'character': 'Trần Kim Vũ'}, {'actor_name': 'Trọng Lân', 'character': 'Hoàng Khắc Dũng'}, {'actor_name': 'Hoàng Dũng', 'character': 'Thứ trưởng Dương Hồng Phương'}, {'actor_name': 'Việt Thắng (diễn viên)', 'character': 'ông Phú'}, {'actor_name': 'Đỗ Kỷ', 'character': 'ông Huynh'}, {'actor_name': 'Phú Thăng', 'character': 'ông Phi'}, {'actor_name': 'Đức Hùng', 'character': 'Đỗ Duy Khánh (Khánh "ma")'}, {'actor_name': 'Bình Xuyên', 'character': 'Đinh Hoàng'}, {'actor_name': 'Vĩnh Xương (diễn viên)', 'character': 'Mạc Kiên'}, {'actor_name': 'Tuấn Cường', 'character': 'ông Hiệu'}, {'actor_name': 'Hoàng Phúc Anh', 'character': 'Huy "nổ"'}, {'actor_name': 'Duy Hưng', 'character': 'Đạo "đá"'}, {'actor_name': 'Anh Tuấn', 'character': 'Tân "cẩu"'}, {'actor_name': 'Phùng Đức Hiếu', 'character': 'Hiếu'}, {'actor_name': 'Bá Anh', 'character': 'Khoa'}, {'actor_name': 'Đào Thúy Hường', 'character': 'Hải My'}, {'actor_name': 'Lê Tuấn Anh', 'character': 'Long "nhà thổ"'}]
# Film director for Hồ sơ cá sấu: Nguyễn Mai Hiền
# Film infobox for Hương vị tình thân: {'tên': 'Hương vị tình thân', 'genre': '[[Tâm lý xã hội]]<br>[[Tình cảm]]<br>[[Gia đình]]', 'định dạng': '[[Phim truyền hình]]', 'based_on': '[[Vì con mà sống]]', 'writer': 'Trịnh Khánh Hà<br>Trịnh Cẩm Hằng<br>Trịnh Đan Phượng', 'đạo diễn': '[[Nguyễn Danh Dũng]]', 'thời lượng': '25 – 30 phút/tập (không bao gồm [[quảng cáo]])', 'kênh': '[[VTV1]]', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[tiếng Việt]]', 'phát sóng đầu': '19 tháng 4 năm 2021 – 27 tháng 7 năm 2021 (phần 1)<br/>28 tháng 7 năm 2021 – 27 tháng 10 năm 2021 (phần 2)', 'đơn vị sản xuất': '[[Trung tâm Phim truyền hình Việt Nam]], [[Đài Truyền hình Việt Nam]]', 'diễn viên': '[[Võ Hoài Nam]]<br>[[Phương Oanh (diễn viên)|Phương Oanh]]<br>[[Mạnh Trường]]<br>[[Thu Quỳnh (diễn viên)|Thu Quỳnh]]', 'preceded_by': '[[Trở về giữa yêu thương]]', 'followed_by': '[[Mátxcơva - Mùa thay lá]] (bản 25 phút/tập; phát lại)', 'số tập': '71 (phần 1)<ref>{{Chú thích web|url=https://laodong.vn/giai-tri/huong-vi-tinh-than-phan-2-cong-bo-lich-phat-song-va-nhieu-nhan-to-moi-931033.ldo|tựa đề="Hương vị tình thân" phần 2 công bố lịch phát sóng và nhiều nhân tố mới|tác giả=Di Py|ngày=2021-07-16|website=[[Lao động (báo)|Lao động]]|url-status=live|ngày truy cập=2021-09-27|archive-date=2021-07-16|archive-url=https://web.archive.org/web/20210716115811/https://laodong.vn/giai-tri/huong-vi-tinh-than-phan-2-cong-bo-lich-phat-song-va-nhieu-nhan-to-moi-931033.ldo}}</ref><br>65 (phần 2)<ref name=":1" />', 'image': 'Hương vị tình thân.jpg'}
# Film actors for Hương vị tình thân: [{'actor_name': 'Tô Dũng', 'character': 'Phi'}, {'actor_name': 'Vũ Việt Hoa', 'character': 'Thiên Nga'}, {'actor_name': 'Lê Linh Hương', 'character': 'Bà Bích lúc trẻ'}, {'actor_name': 'Trần Việt Bắc', 'character': 'Hồng'}, {'actor_name': 'Bùi Bài Bình', 'character': 'Bố Chiến "chó"'}, {'actor_name': 'Hồ Phong', 'character': 'Lão Cao Mạnh Tấn'}, {'actor_name': 'Linh Huệ', 'character': 'Bà Tâm'}, {'actor_name': 'Phạm Anh Tuấn', 'character': 'Chiến "chó"'}, {'actor_name': 'Phụng Nghi', 'character': 'Ngọc Diệp (lúc nhỏ)'}, {'actor_name': 'Nguyễn Hà Anh', 'character': 'Phương Nam (lúc nhỏ)'}, {'actor_name': 'Sơn Tùng', 'character': 'Khánh "trọc"'}, {'actor_name': 'Nam Anh', 'character': 'Kỳ Duyên'}, {'actor_name': 'Đặng Minh Cúc', 'character': 'Sâm'}, {'actor_name': 'Đào Hoàng Yến', 'character': 'Nguyệt'}, {'actor_name': 'Phùng Khánh Linh', 'character': 'Liễu'}, {'actor_name': 'Đào Hiền Thục Anh', 'character': 'Dương'}, {'actor_name': 'Võ sư Vũ Hải', 'character': 'Ông Nguyễn Văn Thắng'}, {'actor_name': 'Minh Thu', 'character': 'Bà Sa (lúc trẻ)'}, {'actor_name': 'Nguyễn Xuân Thắng', 'character': 'Lão Tấn (lúc trẻ)'}, {'actor_name': 'Lý Chí Huy', 'character': 'Hưng'}, {'actor_name': 'Trương Hoàng', 'character': 'Lâm'}, {'actor_name': 'Thùy Linh', 'character': 'Thám tử của Khánh Thy'}, {'actor_name': 'Nguyễn Ngọc An Nhiên', 'character': 'Khánh Thy (lúc nhỏ)'}, {'actor_name': 'Minh Nguyệt', 'character': 'Bà Nhàn'}, {'actor_name': 'Xuân Hiển', 'character': 'Lương'}, {'actor_name': 'Mạnh Đạt', 'character': 'Cường'}]
# Film director for Hương vị tình thân: Nguyễn Danh Dũng
# Film infobox for Đừng nói khi yêu: {'image': 'dungnoikhiyeu.jpg', 'tên': 'Đừng nói khi yêu', 'genre': '{{Unbulleted list|[[Gia đình]]|[[Lãng mạn]]|[[Tình cảm]]|[[Hài hước]]|[[Tâm lý xã hội]]}}', 'tên khác': "'''''Cô thợ bánh'''''", 'định dạng': '[[Phim truyền hình]]', 'writer': '{{Unbulleted list|Hân Như|Hà Hà|Trịnh Khánh Hà}}', 'đạo diễn': '[[Bùi Tiến Huy]]', 'cinematography': 'Vũ Trung Kiên', 'music': "{{Unbulleted list|''Hóa ra như vậy là yêu''|''[[See Tình]]''}}", 'thời lượng': '45 - 50 phút/tập (không bao gồm [[quảng cáo]])', 'company': '[[Trung tâm Phim truyền hình Việt Nam]], [[Đài Truyền hình Việt Nam]]', 'kênh': '[[VTV3]]', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[tiếng Việt]]', 'phát sóng đầu': '30 tháng 1 năm 2023', 'diễn viên': '{{Unbulleted list|[[Mạnh Trường]]|[[Thùy Anh]]|[[Đình Tú]]|Trình Mỹ Duyên|[[Tú Oanh]]|[[Đức Khuê]]|Xuân Trường|[[Quách Thu Phương]]|Lương Thanh|Nguyễn Hoàng Ngọc Huyền|Thái Dũng}}', 'số tập': '27<ref name=":7">{{Chú thích web|url=https://vtv.vn/truyen-hinh/dung-noi-khi-yeu-dong-may-thuy-anh-mong-dao-dien-lam-phan-2-20230325211615983.htm|tựa đề="Đừng nói khi yêu" đóng máy, Thuỳ Anh mong đạo diễn làm phần 2|website=Báo điện tử VTV|ngày=2023-3-26|ngày truy cập=2023-03-26|archive-date=2023-03-26|archive-url=https://web.archive.org/web/20230326113400/https://vtv.vn/truyen-hinh/dung-noi-khi-yeu-dong-may-thuy-anh-mong-dao-dien-lam-phan-2-20230325211615983.htm|url-status=live}}</ref>', 'phát sóng cuối': '29 tháng 3 năm 2023', 'followed_by': '[[Cuộc đời vẫn đẹp sao (phim truyền hình)|Cuộc đời vẫn đẹp sao]]', 'preceded_by': '[[Hành trình công lý]]'}
# Film actors for Đừng nói khi yêu: [{'actor_name': 'Mạnh Trường', 'character': 'Nguyễn Kim Quy (Leo Nguyễn)'}, {'actor_name': 'Thùy Anh', 'character': 'Trịnh Phương Ly'}, {'actor_name': 'Đình Tú', 'character': 'Trần Minh Tú'}, {'actor_name': 'Trình Mỹ Duyên', 'character': 'Nguyễn Phương Linh'}, {'actor_name': 'Tú Oanh', 'character': 'Bà Phượng'}, {'actor_name': 'Đức Khuê', 'character': 'Ông Long'}, {'actor_name': 'Xuân Trường', 'character': 'Ông Thành'}, {'actor_name': 'Quách Thu Phương', 'character': 'Bà Thúy'}, {'actor_name': 'Thái Dũng', 'character': 'Phi'}, {'actor_name': 'Lương Thanh', 'character': 'Quỳnh Trang'}, {'actor_name': 'Nguyễn Hoàng Ngọc Huyền', 'character': 'Tường San'}]
# Film director for Đừng nói khi yêu: Bùi Tiến Huy
# Film infobox for Chúng ta của 8 năm sau: {'image': 'CTC8NS.jpg', 'tên': 'Chúng ta của 8 năm sau', 'genre': '[[Lãng mạn]]<br>[[Gia đình]]<br>[[Tình cảm]]<br>[[Tuổi trẻ]]<br>[[Tâm lý xã hội]]', 'định dạng': '[[Phim truyền hình]]', 'writer': 'Trịnh Khánh Hà<br>Nguyễn Thu Thủy', 'đạo diễn': '[[Bùi Tiến Huy]]', 'cinematography': 'Trần Khánh Tùng<br>Nghiêm Bá Hoài', 'thời lượng': '40 – 45 phút/tập (không bao gồm [[quảng cáo]])', 'company': '[[Trung tâm Phim truyền hình Việt Nam]], [[Đài Truyền hình Việt Nam]]', 'kênh': '[[VTV3]]', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[tiếng Việt]]', 'phát sóng đầu': '6 tháng 11 năm 2023 - 6 tháng 3 năm 2024', 'công ty sản xuất': '[[Trung tâm Phim truyền hình Việt Nam]]', 'diễn viên': '[[Phan Minh Huyền]]<br>[[Mạnh Trường]]<br>[[Quỳnh Kool|Nguyễn Quỳnh]]<br>B Trần<br>[[Trung Anh]]', 'số tập': '15 (phần 1)<br>36 (phần 2)', 'followed_by': "''[[Trạm cứu hộ trái tim]]''", 'preceded_by': "''[[Biệt dược đen|Cảnh sát hình sự: Biệt dược đen]]''", 'tên khác': "''Ánh dương rực rỡ''"}
# Film actors for Chúng ta của 8 năm sau: [{'actor_name': 'Hoàng Hà (diễn viên)', 'character': 'Mai Dương'}, {'actor_name': 'Phan Minh Huyền', 'character': 'Mai Dương (lúc lớn)'}, {'actor_name': 'Trần Quốc Anh', 'character': 'Lâm'}, {'actor_name': 'Mạnh Trường', 'character': 'Lâm (lúc lớn)'}, {'actor_name': 'Nguyễn Hoàng Ngọc Huyền', 'character': 'Nguyệt'}, {'actor_name': 'Quỳnh Kool', 'character': 'Nguyệt (lúc lớn)'}, {'actor_name': 'Trần Nghĩa (diễn viên)', 'character': 'Tùng'}, {'actor_name': 'Trần Quốc Anh (B Trần)', 'character': 'Tùng (lúc lớn)'}, {'actor_name': 'Khôi Trần', 'character': 'Giang'}, {'actor_name': 'Phùng Đức Hiếu', 'character': 'Tuấn'}, {'actor_name': 'Thùy Anh', 'character': 'Như Ý'}, {'actor_name': 'Trung Anh', 'character': 'Ông Quảng'}, {'actor_name': 'Đức Khuê', 'character': 'Ông Lực'}, {'actor_name': 'Thúy Hà', 'character': 'Bà Hòa'}, {'actor_name': 'Chu Diệp Anh', 'character': 'Lan Nhi'}, {'actor_name': 'Nguyễn Ngọc An Nhiên', 'character': 'Bé Cam'}]
# Film director for Chúng ta của 8 năm sau: Bùi Tiến Huy
# Film infobox for Không thời gian (phim truyền hình): {'tên': 'Không thời gian', 'image': 'Khongthoigian.jpg', 'tên khác': "'''''Câu chuyện quá khứ'''''", 'music': '"[[Nối vòng tay lớn]]"', 'genre': '{{Unbulleted list|[[Chính luận]]|[[Hình sự]]|[[Chiến tranh]]|[[Tâm lý xã hội]]}}', 'writer': '{{Unbulleted list|Trịnh Khánh Hà|Lê Huyền|Phạm Ngọc Hà Lê}}', 'đạo diễn': '{{Unbulleted list|[[Nguyễn Danh Dũng]]|Nguyễn Đức Hiếu}}', 'starring': '{{Unbulleted list|[[Mạnh Trường|Nguyễn Mạnh Trường]]|Lê Xuân Anh|[[Chí Nhân|Đào Chí Nhân]]|Lưu Duy Khánh|[[Quốc Trị|Nguyễn Quốc Trị]]|[[Trung Anh|Bùi Trung Anh]]|[[Như Quỳnh (diễn viên)|Nguyễn Như Quỳnh]]|Bùi Xuân Thảo|Phùng Đức Hiếu|Trần Việt Hoàng|Nguyễn Huyền Trang|Thừa Tuấn Anh|[[Doãn Quốc Đam]]|Phạm Thị Bích Ngọc|Bùi Thạc Phong|Phạm Anh Tuấn}}', 'quốc gia': '{{VIE}}', 'ngôn ngữ': '[[Tiếng Việt]]', 'số tập': '60', 'thời lượng': '45 – 50 phút/tập (không bao gồm [[quảng cáo]])', 'company': '{{Unbulleted list|[[Trung tâm Phim truyền hình Việt Nam]], [[Đài Truyền hình Việt Nam]]|[[Tổng cục Chính trị Quân đội Nhân dân Việt Nam]]}}', 'kênh': '[[VTV1]]', 'phát sóng đầu': '25 tháng 11 năm 2024', 'phát sóng cuối': '14 tháng 3 năm 2025', 'preceded_by': '[[Hoa sữa về trong gió]]', 'followed_by': '[[Mẹ biển]]', 'định dạng': '[[Phim truyền hình]]'}
# Film actors for Không thời gian (phim truyền hình): []
# Film director for Không thời gian (phim truyền hình): Nguyễn Danh Dũng
# Film infobox for Thầu Chín ở Xiêm: {'bgcolor': 'green', 'show_name': 'Thầu Chín ở Xiêm', 'genre': '[[Lịch sử]]<br/>[[Chiến tranh]]', 'format': '[[Phim điện ảnh]]', 'writer': 'Đinh Thiên Phúc', 'director': '[[Bùi Tuấn Dũng|NSƯT Bùi Tuấn Dũng]]', 'starring': '[[Mạnh Trường|Nguyễn Mạnh Trường]]<br>[[Hoàng Hải (diễn viên)|NSƯT Hoàng Hải]]<br/>[[Trung Anh|NSND Trung Anh]]<br>[[Mạnh Hưng|Nguyễn Mạnh Hưng]]<br>[[Văn Phượng]]<br />Huyền Sâm', 'country': '{{VIE}}<br/>{{THA}}', 'language': '[[Tiếng Việt]]<br/>[[Tiếng Pháp]]<br/>[[Tiếng Thái]]', 'producer': '[[Hãng phim Hội Điện ảnh Việt Nam]]', 'runtime': '96 phút', 'first_aired': '30 tháng 1 năm 2015'}
# Film actors for Thầu Chín ở Xiêm: [{'actor_name': 'Mạnh Trường', 'character': 'Thầu Chín'}, {'actor_name': 'Trung Anh', 'character': 'Đặng Thúc Hứa'}, {'actor_name': 'Hoàng Hải diễn viên', 'character': 'Paul Hùng'}, {'actor_name': 'Huyền Sâm', 'character': 'O Nho'}, {'actor_name': 'Văn Phượng', 'character': 'O Hoàn'}, {'actor_name': 'Nông Dũng Nam', 'character': 'Võ Tùng'}, {'actor_name': 'Mạnh Hưng', 'character': 'Đặng Thái Truyền'}]
# Film director for Thầu Chín ở Xiêm: Bùi Tuấn Dũng
# Crawling data for person: Phương Oanh
# Person info: {}
# extract_films_from_subsection: Section không có heading cấp 3
# Film info: []
# {'films': ['Huyền sử thiên đô (phim)', 'Bí mật tam giác vàng', 'Hoa nở trái mùa', 'Đường lên Điện Biên', 'Zippo, mù tạt và em', 'Tuổi thanh xuân', 'Ngược chiều nước mắt', 'Cả một đời ân oán', 'Chạy trốn thanh xuân', 'Sinh tử', 'Tình yêu và tham vọng', 'Hồ sơ cá sấu', 'Hương vị tình thân', 'Đừng nói khi yêu', 'Chúng ta của 8 năm sau', 'Không thời gian (phim truyền hình)', 'Thầu Chín ở Xiêm'], 'info': {'nền': 'diễn viên', 'tên': 'Mạnh Trường', 'hình': '<--File:Mạnh Trường.jpg--!>', 'birth_name': 'Nguyễn Mạnh Trường', 'birth_date': '{{ngày sinh và tuổi|1985|9|11}}', 'nơi sinh': '[[Hà Nội]], [[Việt Nam]]', 'chiều cao': '{{height|m=1,82}}', 'vai diễn': 'Long', 'phim': '[[Hương vị tình thân]]', 'quốc tịch': '{{VIE}}', 'dân tộc': '[[Kinh]]', 'nghề nghiệp': '{{hlist|[[Diễn viên]]|[[Người mẫu]]}}', 'vợ': '{{marriage|Phạm Lan Phương|2008}}', 'children': '3', 'trường lớp': '[[Đại học Sân khấu Điện ảnh Hà Nội]]', 'giải thưởng 1': '[[Liên hoan phim Việt Nam lần thứ 15]]', 'hạng mục 1': 'Nam diễn viên phụ xuất sắc', 'giải thưởng 2': '[[Cánh Diều Vàng]] 2020', 'hạng mục 2': 'Nam diễn viên chính xuất sắc', 'năm hoạt động điện ảnh': '2001 – nay'}}

# %%
def expand_network(person_data, film_data, max_depth=3):
    
    visited_persons = set(person_data.keys())
    current_depth = 0

    while current_depth < max_depth:
        print(f"\n Đang mở rộng mức {current_depth + 1} ...")
        new_persons = {}  

        
        for film_name, film_info in film_data.items():
            if 'actors' not in film_info:
                continue  # tránh KeyError

            for cast_member in film_info['actors']:
                for film_name, film_info in film_data.items():
                    if 'actors' not in film_info:
                        continue  # tránh KeyError

                    for cast_member in film_info['actors']:
                        # Trường hợp cast_member là dict
                        if isinstance(cast_member, dict):
                            actor_name = cast_member.get('actor_name')

                        # Trường hợp cast_member là list (danh sách tên diễn viên)
                        elif isinstance(cast_member, list):
                            for sub_actor in cast_member:
                                if isinstance(sub_actor, str) and sub_actor not in visited_persons:
                                    new_persons[sub_actor] = None
                            continue

                        # Trường hợp cast_member là string (chỉ là tên)
                        elif isinstance(cast_member, str):
                            actor_name = cast_member

                        # Các trường hợp khác thì bỏ qua
                        else:
                            continue

                        if not actor_name:
                            continue

                        if actor_name not in visited_persons:
                            new_persons[actor_name] = None


                        # Nếu không còn diễn viên mới => dừng
                        if not new_persons:
                            print(" Không còn diễn viên mới để mở rộng.")
                            break

        # Crawl thông tin về các diễn viên mới
        for person in list(new_persons.keys()):
            try:
                print(f" Crawling person: {person}")
                wikitext = get_wikitext(person)
                person_info = extract_infobox_from_wikitext(wikitext)
                film_dict = extract_films_from_person_wikitext(wikitext)
                film_info = get_all_films_from_films_dict(film_dict)
                film_list = []
                for film in film_info:
                    # Ưu tiên các trường phổ biến
                    
                    title = film.get('Tựa đề') or film.get('Tên phim')
                                    
                    # Nếu chưa có tìm key có chứa từ "Tựa"
                    if not title:
                        for key in film.keys():
                            if "Tựa" in key or "Tên" in key:
                                title = film[key]
                                break  # dừng lại khi tìm thấy key đầu tiên
                    if not title:
                        continue

                    # Sau khi có tiêu đề rồi mới kiểm tra có phải phim VN không
                    if not is_vn_film_wikilink(title):
                        continue

                    film_list.append(title)

                person_data[person] = {
                    'info': person_info,
                    'films': film_list
                }

                # Crawl thông tin phim mà diễn viên này tham gia
                for film in film_list:
                    if film not in film_data:
                        print(f" Mở rộng phim mới: {film}")
                        film_wikitext = get_wikitext(film)
                        cast = extract_actors_from_film_wikitext(film_wikitext)
                        director = extract_directors_from_film(film_wikitext)
                        film_info = extract_infobox_from_wikitext(film_wikitext)

                        film_data[film] = {
                            'infobox': film_info,
                            'actors': cast,
                            'director': director
                        }

            except Exception as e:
                print(f" Lỗi khi crawl {person}: {e}")

        visited_persons.update(new_persons.keys())
        current_depth += 1

    print("Mở rộng hoàn tất.")
    return person_data, film_data
persons_data, films_info = expand_network(persons_data, films_info, max_depth=3)
# Out:
#  Đang mở rộng mức 1 ...
#  Crawling person: Ngọc Lan (diễn viên)
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Bê La
#  Mở rộng phim mới: Con đường sáng (phim video)
#  Mở rộng phim mới: Tình yêu còn lại
#  Mở rộng phim mới: Cuộc phiêu lưu của Hai Lúa
#  Mở rộng phim mới: Taxi (phim truyền hình)
#  Mở rộng phim mới: Cuộc gọi lúc 0 giờ
#  Mở rộng phim mới: Hoa nắng (phim truyền hình Việt Nam)
#  Mở rộng phim mới: Cá cược cuộc đời
#  Mở rộng phim mới: Thời gian để yêu (phim truyền hình)
#  Mở rộng phim mới: Ông trùm (phim truyền hình Việt Nam)
#  Mở rộng phim mới: Con gái bố già
#  Mở rộng phim mới: Dập tắt lửa lòng
#  Mở rộng phim mới: Tiếng sét trong mưa
#  Mở rộng phim mới: Không lối thoát (phim truyền hình)
#  Mở rộng phim mới: Anh ba khía
#  Mở rộng phim mới: Sui gia khắc khẩu
#  Mở rộng phim mới: Bão ngầm
#  Mở rộng phim mới: Có hẹn với yêu thương
#  Mở rộng phim mới: 14 ngày phép
#  Mở rộng phim mới: Chuyện ma gần nhà
#  Crawling person: Nguyệt Ánh
#  Mở rộng phim mới: Miền đất phúc
#  Mở rộng phim mới: Thứ ba học trò
#  Mở rộng phim mới: Mệnh lệnh hoa hồng
#  Mở rộng phim mới: Ám ảnh (phim truyền hình)
#  Mở rộng phim mới: Đam mê nghiệt ngã (phim truyền hình Việt Nam)
#  Mở rộng phim mới: Trần Trung kỳ án
#  Mở rộng phim mới: Muôn kiểu làm dâu
#  Mở rộng phim mới: Nghiệp sinh tử
#  Mở rộng phim mới: Dương thế bao la sầu
#  Crawling person: Tú Vi
# Bỏ qua 'Danh sách phim' (không phải bảng wikitable)
#  Mở rộng phim mới: Gọi giấc mơ về
#  Mở rộng phim mới: Cô gái xấu xí
#  Mở rộng phim mới: Bếp hát
#  Mở rộng phim mới: Glee Vietnam
#  Mở rộng phim mới: Gạo nếp gạo tẻ
#  Mở rộng phim mới: Trói buộc yêu thương
#  Mở rộng phim mới: Thử thách cuộc đời
#  Mở rộng phim mới: Mặt trời lạnh
#  Mở rộng phim mới: Cô gái đến từ hôm qua (phim)
#  Crawling person: Kha Ly
#  Mở rộng phim mới: Kiều nữ và đại gia
#  Mở rộng phim mới: Ký ức mong manh
#  Mở rộng phim mới: Thẩm mỹ viện (phim truyền hình)
#  Mở rộng phim mới: Dấu chân du mục
#  Mở rộng phim mới: Đồng tiền quỷ ám
#  Mở rộng phim mới: Dâu bể đường trần
#  Mở rộng phim mới: Vũ điệu đón xuân
#  Mở rộng phim mới: Nơi ngọn gió dừng chân
#  Crawling person: Hiền Trang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lương Thế Thành
#  Mở rộng phim mới: Giọt đắng
#  Mở rộng phim mới: Lối sống sai lầm
#  Mở rộng phim mới: Hạnh phúc của người khác
#  Mở rộng phim mới: Ải mỹ nhân
#  Mở rộng phim mới: Trận đồ bát quái
#  Mở rộng phim mới: Khúc tương tư
#  Mở rộng phim mới: Ngày ấy mình đã yêu
#  Mở rộng phim mới: Cô Thắm về làng (phim truyền hình)
#  Mở rộng phim mới: Ngũ hợi tấn hỷ
#  Mở rộng phim mới: Tình mẫu tử (phim truyền hình Việt Nam)
#  Mở rộng phim mới: Mẹ ghẻ (phim truyền hình)
#  Mở rộng phim mới: Canh bạc tình yêu
#  Mở rộng phim mới: Chống lại số phận
#  Mở rộng phim mới: Bánh mì ông Màu
#  Crawling person: Hùng Thuận
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Đất phương Nam
#  Mở rộng phim mới: Thuyền giấy
#  Mở rộng phim mới: Mật mã hoa hồng vàng
#  Crawling person: Hòa Hiệp (diễn viên)
#  Crawling person: Đình Hiếu
#  Mở rộng phim mới: Hương phù sa
#  Mở rộng phim mới: Nghề báo (phim truyền hình)
#  Mở rộng phim mới: Thề không gục ngã
#  Mở rộng phim mới: Lẩn khuất một tên người
#  Mở rộng phim mới: Mỹ nhân Sài Thành
#  Mở rộng phim mới: Nước mắt loài cỏ dại
#  Mở rộng phim mới: Thương con cá rô đồng
#  Mở rộng phim mới: Duyên kiếp
#  Mở rộng phim mới: Mẹ biển
#  Mở rộng phim mới: Giữa hai thế giới
#  Mở rộng phim mới: Nàng men chàng bóng
#  Mở rộng phim mới: Em và Trịnh
#  Crawling person: Nguyễn Lê Bá Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ánh Hoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Phương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huỳnh Anh Tuấn
#  Mở rộng phim mới: Hạ sĩ quan (phim)
#  Mở rộng phim mới: Khi đàn ông có bầu
#  Mở rộng phim mới: Hello cô Ba
#  Mở rộng phim mới: Những nẻo đường phù sa
#  Mở rộng phim mới: Ngọn nến Hoàng cung
#  Mở rộng phim mới: Lẵng hoa tình yêu
#  Mở rộng phim mới: Âm tính
#  Mở rộng phim mới: Gia tài bác sĩ
#  Mở rộng phim mới: Tình án
#  Mở rộng phim mới: Vó ngựa trời Nam
#  Mở rộng phim mới: Anh chàng vượt thời gian
#  Mở rộng phim mới: Nghiệt oan
#  Mở rộng phim mới: Sông dài (phim)
#  Mở rộng phim mới: Mùa cúc susi
#  Mở rộng phim mới: Vũ điệu giữa bầy sói
#  Mở rộng phim mới: Giã từ những đêm hoang
#  Mở rộng phim mới: Giấc mơ của mẹ
#  Crawling person: Kinh Quốc
#  Mở rộng phim mới: Người đẹp Tây Đô
#  Mở rộng phim mới: Hướng nghiệp (phim truyền hình)
#  Mở rộng phim mới: Áo cưới thiên đường
#  Mở rộng phim mới: Vật chứng mong manh
#  Mở rộng phim mới: Chạm vào quá khứ
#  Mở rộng phim mới: Bước nhảy hoàn vũ
#  Crawling person: Công Ninh
# Bỏ qua 'Các vở kịch' (không phải bảng wikitable)
# Bỏ qua 'Chương trình truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Music video' (không phải bảng wikitable)
#  Mở rộng phim mới: Ba người đàn ông
#  Mở rộng phim mới: Ai xuôi vạn lý
#  Mở rộng phim mới: Mẹ con Đậu Đũa
#  Mở rộng phim mới: Đời cát
#  Mở rộng phim mới: Tôi vào đời
#  Mở rộng phim mới: Blouse trắng
#  Mở rộng phim mới: Dưới cờ đại nghĩa
#  Mở rộng phim mới: Giải cứu thần chết
#  Mở rộng phim mới: Câu chuyện pháp đình
#  Mở rộng phim mới: Trái đắng
#  Mở rộng phim mới: Nhiệm vụ đặc biệt
#  Mở rộng phim mới: Cá Rô, em yêu anh!
#  Mở rộng phim mới: Sống trong bóng đêm
#  Mở rộng phim mới: Lạc lối
#  Mở rộng phim mới: Trà táo đỏ
#  Mở rộng phim mới: Gia đình là số 1 - Phần 2 (phim truyền hình 2019)
#  Mở rộng phim mới: Kẻ sát nhân cô độc
#  Mở rộng phim mới: Cây táo nở hoa
#  Mở rộng phim mới: Người lắng nghe: Lời thì thầm
#  Mở rộng phim mới: Bí mật nghiệt ngã
#  Mở rộng phim mới: Ăn tết miệt vườn
#  Mở rộng phim mới: Lụa (phim truyền hình)
#  Crawling person: Văn Ruy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phùng Ngọc Huy
#  Mở rộng phim mới: Nữ sinh (phim truyền hình)
#  Mở rộng phim mới: Trả giá (phim truyền hình năm 2014)
#  Crawling person: Mai Phương (diễn viên)
#  Mở rộng phim mới: Đường về nhà
#  Mở rộng phim mới: Những thiên thần áo trắng
#  Mở rộng phim mới: Bên kia sông
#  Crawling person: Quang Thảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thiên Kim (diễn viên)
#  Crawling person: Phi Điểu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Lan (nghệ sĩ)
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hải Lý
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Giang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hữu Thạch
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huy Cường
# Bỏ qua 'Sân khấu Kịch' (không phải bảng wikitable)
# Bỏ qua 'Điện ảnh và Truyền hình' (không phải bảng wikitable)
#  Crawling person: Quách Khoa Nam
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Sanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bích Hằng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huỳnh Ngân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thủy Cúc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lâm Hải Sơn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Phượng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoài An
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thái Quốc Nguyên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huỳnh Ngọc Lan (Lan Mập)
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thảo Ly
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Khương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thành Bỉ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Cường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Long Trẻ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Thy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Tâm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Hạnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Puka
# Bỏ qua '2008–2013: Bắt đầu sự nghiệp' (không phải bảng wikitable)
# Bỏ qua '2013–nay: Phát triển sự nghiệp và đón nhận' (không phải bảng wikitable)
#  Crawling person: Khương Ngọc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Trúc
#  Mở rộng phim mới: Giấc mơ biển
#  Mở rộng phim mới: Lời nguyền lúc 0 giờ
#  Mở rộng phim mới: Rồi 30 năm sau
#  Mở rộng phim mới: Năm sau con lại về
#  Crawling person: Kim Xuân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trọng Nhân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Diệu Đức
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mã Trung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quốc Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lục Diệp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lập Xuân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lộc Uyển
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quách Hữu Lộc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vân Trang
# Bỏ qua 'Kịch nói' (không phải bảng wikitable)
#  Mở rộng phim mới: Dù gió có thổi
#  Mở rộng phim mới: Sông dài (phim truyền hình)
#  Mở rộng phim mới: Mật mã chuông gió
#  Mở rộng phim mới: Danh vọng phù hoa
#  Mở rộng phim mới: Dòng nhớ
#  Mở rộng phim mới: Sài Gòn Yo!
#  Mở rộng phim mới: Tiền chùa
#  Crawling person: Khương Thịnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Huỳnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thiên Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Thy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Yến Trang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoài Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Võ lâm truyền kỳ (phim)
#  Mở rộng phim mới: Nụ hôn thần chết (phim)
#  Mở rộng phim mới: Bóng ma học đường
#  Mở rộng phim mới: Hoán đổi thân xác
#  Mở rộng phim mới: Nhà có 5 nàng tiên
#  Mở rộng phim mới: Tía tui là cao thủ
#  Crawling person: Tấn Beo
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Tây Sơn hào kiệt
#  Mở rộng phim mới: Bay vào cõi mộng
#  Mở rộng phim mới: Tình thắm duyên xuân
#  Crawling person: Chí Tài
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Thần tượng (phim)
#  Crawling person: Mạnh Tràng
#  Mở rộng phim mới: Xóm nước đen
#  Crawling person: Hiếu Hiền
# Bỏ qua 'Hài đã đóng (Tiêu biểu)' (không phải bảng wikitable)
# Bỏ qua 'Dẫn chương trình' (không phải bảng wikitable)
# Bỏ qua 'Chương trình truyền hình' (không phải bảng wikitable)
#  Crawling person: Khổng Tú Quỳnh
#  Crawling person: Kim Thư
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Sơn diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chí Thiện ca sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ưng Hoàng Phúc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đông Nhi
#  Crawling person: Noo Phước Thịnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngô Kiến Huy
#  Mở rộng phim mới: Chàng trai năm ấy
#  Mở rộng phim mới: Em là bà nội của anh
#  Mở rộng phim mới: Yêu đi, đừng sợ!
#  Mở rộng phim mới: Chị trợ lý của anh
#  Mở rộng phim mới: Em là của em
#  Crawling person: Phước Sang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Việt Anh nghệ sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tuyết Thu
#  Mở rộng phim mới: Con khỉ mồ côi
#  Mở rộng phim mới: Kế hoạch hoàn hảo
#  Mở rộng phim mới: Sút
#  Crawling person: Bảo Quốc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khánh Nam
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Cát Phượng
#  Mở rộng phim mới: Ròm
#  Mở rộng phim mới: Hạnh phúc của mẹ
#  Mở rộng phim mới: Sắc đẹp và danh vọng
#  Crawling person: Mai Thanh Dung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tuyền Mập
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bé Hòa Bình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phương Bình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phi Phụng
# Bỏ qua 'Sitcom' (không phải bảng wikitable)
#  Mở rộng phim mới: Lật mặt (phim)
#  Mở rộng phim mới: Sài Gòn, anh yêu em
#  Mở rộng phim mới: Cô hầu gái
#  Mở rộng phim mới: 4 năm, 2 chàng, 1 tình yêu
#  Mở rộng phim mới: Cổ tích Việt Nam (phim)
#  Mở rộng phim mới: Tiệm bánh Hoàng tử bé
#  Mở rộng phim mới: Tiệm bánh Hoàng tử bé 2
#  Mở rộng phim mới: Gia đình là số 1 (phim truyền hình 2017)
#  Crawling person: Phương Trinh Jolie
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kelly Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vương Khang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tam Thanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tấn Bo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tấn Hoàng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Ngọc nghệ sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thành Nam
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thành Chiến
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Trí
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Kim Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kiều Lan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hứa Minh Đạt
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đại Ngọc Trâm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huỳnh Mến
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Dũng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Thanh Hoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Isaac ca sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Dương Cẩm Lynh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Sơn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Hoàng D1
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Ngọc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Maika
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Jennie
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nho
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thu Thảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyên Lộc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Hà
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Anh Đức
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Dung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo My
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Chiến
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Hy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: D1 Team
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tony Vinh Hiển
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trung Hiệp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hữu Nghiệp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Minh Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Minh Trí
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lý Duy Phong
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phùng Nhựt Tân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồ Cát Trắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Sơn Master
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Châu Xuân Dưỡng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Diệp Quốc Tuấn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồ Hiếu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Bảo Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phù Lợi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Dung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chí Thành
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phi Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Anh Tuấn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Duy Lực
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thành Long
# Bỏ qua 'Thành công ban đầu: 1976–1980' (không phải bảng wikitable)
# Bỏ qua 'Thành công với thể loại phim hành động hài: 1980–1987' (không phải bảng wikitable)
# Bỏ qua 'Thành công của phim nối tiếp và đột phá tại Hollywood: 1988–1998' (không phải bảng wikitable)
# Bỏ qua 'Chuyển sang phim chính kịch: 1998–nay' (không phải bảng wikitable)
#  Crawling person: Nguyễn Minh Giang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trúc Như
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Bình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Đài
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Phong Vỹ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thế Minh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Huy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chiến Công
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thành Công
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tôt Ty
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Phương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Trường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thùy Trang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Ngân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thiên Ngân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Loan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tuyết Loan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đinh Thủy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mỹ Vân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thu Hiền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mỹ Huyền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Thị Tuyết
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thùy An
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Như Ý
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nhóm Number One
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Anh Tú sinh 1993
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mạc Văn Khoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khả Như
# Bỏ qua 'Kịch nói - Hài kịch' (không phải bảng wikitable)
#  Mở rộng phim mới: Ai chết giơ tay
#  Mở rộng phim mới: Gieo gió
#  Mở rộng phim mới: Sao đổi ngôi (phim truyền hình Việt Nam)
#  Crawling person: Hữu Châu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Giang nghệ sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Minh - Hồng Đào
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trung Dân
#  Crawling person: Hari Won
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thuận Hoàng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Thanh Mai
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thùy Dương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Tân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tuấn Trần
# extract_films_from_subsection: Section không có heading cấp 3
# Bỏ qua 'Phim' (không phải bảng wikitable)
#  Crawling person: Ngân Chi
#  Mở rộng phim mới: Lật mặt 7: Một điều ước
#  Crawling person: Ngọc Giàu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Mèo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lan Phương
#  Mở rộng phim mới: Nữ bác sĩ
#  Mở rộng phim mới: Những đứa con biệt động Sài Gòn
#  Mở rộng phim mới: Váy hồng tầng 24
#  Mở rộng phim mới: Người cộng sự
#  Mở rộng phim mới: Mẹ ơi, bố đâu rồi?
#  Mở rộng phim mới: Nàng dâu order
#  Mở rộng phim mới: Thương ngày nắng về
#  Mở rộng phim mới: Gia đình mình vui bất thình lình
#  Mở rộng phim mới: Tết ở làng địa ngục
#  Mở rộng phim mới: Kẻ ăn hồn
#  Crawling person: La Thành
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quốc Khánh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Thành Phát
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Trang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Minh Tú
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Uyển Ân
# Bỏ qua 'Phim truyền hình / Web-drama' (không phải bảng wikitable)
#  Mở rộng phim mới: Cái giá của hạnh phúc
#  Crawling person: Lê Giang
#  Mở rộng phim mới: Sóng tình (phim truyền hình)
#  Mở rộng phim mới: Chị chị em em 2
#  Mở rộng phim mới: Gặp lại chị bầu
#  Crawling person: Song Luân
#  Crawling person: Quỳnh Lý
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phương Lan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Dương Bảo Lâm
# Bỏ qua 'Phim đã tham gia' (không phải bảng wikitable)
# Bỏ qua 'Chương trình truyền hình' (không phải bảng wikitable)
#  Crawling person: Ngân Quỳnh
#  Mở rộng phim mới: Bỗng dưng muốn khóc
#  Mở rộng phim mới: Cha rơi
#  Mở rộng phim mới: Khúc hát mặt trời
#  Mở rộng phim mới: Sông phố nhà ghe
#  Mở rộng phim mới: Kẻ ngược dòng
#  Mở rộng phim mới: Về nhà đi con
#  Mở rộng phim mới: Lời nguyền Domino
#  Mở rộng phim mới: Luật trời
#  Mở rộng phim mới: Mẹ trùm
#  Mở rộng phim mới: Mẹ rơm
#  Mở rộng phim mới: Hoa hồng cho sớm mai
#  Mở rộng phim mới: Chúng ta phải hạnh phúc
#  Mở rộng phim mới: Án mạng lầu 4
#  Crawling person: Huỳnh Hạo Khang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huỳnh Đông
# Bỏ qua 'Diễn viên' (không phải bảng wikitable)
# Bỏ qua 'Đạo diễn' (không phải bảng wikitable)
#  Crawling person: Bích Ngọc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Ánh
# Bỏ qua 'Kịch nói' (không phải bảng wikitable)
#  Mở rộng phim mới: Cầu thang tối
#  Mở rộng phim mới: Phố Hoài
#  Mở rộng phim mới: Lục Vân Tiên (phim truyền hình)
#  Mở rộng phim mới: Kính vạn hoa (phim truyền hình)
#  Mở rộng phim mới: Cây nước mắt
#  Mở rộng phim mới: Đường đua (phim năm 2013)
#  Mở rộng phim mới: Chuyến đi cuối cùng của chị Phụng
#  Mở rộng phim mới: Đảo của dân ngụ cư
#  Crawling person: Phương Anh Đào
#  Mở rộng phim mới: Tro tàn rực rỡ
#  Crawling person: Hồng Đào diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Sầu Anh Thư
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Anh Phạm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Tiểu Vy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vũ Quốc Khánh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lý Hạo Mạnh Quỳnh Quỳnh Lý
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Hằng nghệ sĩ cải lương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kiều Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Nga
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lộ Lộ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Nam
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nhà bà Nữ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Cao Kỳ Duyên người mẫu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Quốc Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: AQuay
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thái Công
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huy Phan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Negav
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hùng Huỳnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quân AP
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vinh Râu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phạm Anh Duy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ali Hoàng Dương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chị Ca Nô
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hải Vót
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Gia Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nhâm Phương Nam
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bé Rio
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Võ Lan Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thu Hoài
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Hoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Năm Chà
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trinh Hoan & Như Khuê
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lệ Quyên ca sĩ sinh 1981
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Trần
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: đóng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phương Bình đóng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lưu Hoàng Gia Bảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đinh Ứng Phi Trường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Phước
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Hằng
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Đối mặt (phim truyền hình)
#  Mở rộng phim mới: Bao giờ có yêu nhau
#  Mở rộng phim mới: Sắc đẹp ngàn cân (phim 2017)
#  Mở rộng phim mới: Bẫy ngọt ngào
#  Crawling person: Nhã Phương diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phương Thanh
# Bỏ qua 'Phim điện ảnh' (không phải bảng wikitable)
# Bỏ qua 'Phim truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Phim chiếu mạng' (không phải bảng wikitable)
#  Crawling person: Văn Tùng
#  Mở rộng phim mới: Những cô gái chân dài
#  Mở rộng phim mới: Chị chị em em
#  Mở rộng phim mới: Cho một tình yêu
#  Mở rộng phim mới: Ầu ơ ví dầu
#  Mở rộng phim mới: Cuộc chiến nhân tình
#  Crawling person: La Quốc Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chi Bảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đào Bá Sơn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đồng Thanh Phong
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tùng Haru
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bá Trường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hà Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Amy Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Hiếu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trúc Vân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Minh Luân
#  Crawling person: Thiên Bảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tường Vi diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đức Thịnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đào Anh Tuấn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Don Nguyễn
#  Mở rộng phim mới: Hot boy nổi loạn và câu chuyện về thằng Cười, cô gái điếm và con vịt
#  Mở rộng phim mới: Âm mưu giày gót nhọn
#  Crawling person: Dustin Nguyễn
#  Mở rộng phim mới: Huyền thoại bất tử
#  Crawling person: Đỗ Thị Hải Yến
#  Mở rộng phim mới: Mùa hè chiều thẳng đứng
#  Mở rộng phim mới: Vũ khúc con cò
#  Mở rộng phim mới: Chuyện của Pao
#  Mở rộng phim mới: Chơi vơi
#  Mở rộng phim mới: Cha và con và...
#  Crawling person: Võ Thanh Hòa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tăng Thanh Hà
# Bỏ qua 'Kịch' (không phải bảng wikitable)
#  Mở rộng phim mới: Đẹp từng centimet
#  Mở rộng phim mới: Mỹ nhân kế (phim)
#  Crawling person: Thái Hòa diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tinna Tình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bùi Văn Hải
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phi Thanh Vân
# Bỏ qua 'Phim điện ảnh' (không phải bảng wikitable)
# Bỏ qua 'Phim truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Phim chiếu mạng' (không phải bảng wikitable)
#  Crawling person: Mai Thành
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Hậu
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Hai Cũ
#  Mở rộng phim mới: Vị đắng tình yêu
#  Mở rộng phim mới: Ông cố vấn
#  Mở rộng phim mới: Xích lô (phim)
#  Mở rộng phim mới: Lưỡi dao (phim)
#  Mở rộng phim mới: Đợi tàu
#  Mở rộng phim mới: Thung lũng hoang vắng
#  Mở rộng phim mới: Người đàn bà yếu đuối
#  Mở rộng phim mới: Mùa len trâu
#  Mở rộng phim mới: Cổ tích Việt Nam
#  Mở rộng phim mới: Mười (phim)
#  Mở rộng phim mới: Khí phách anh hùng
#  Mở rộng phim mới: Đồng quê (phim truyền hình)
#  Mở rộng phim mới: Mỹ nhân Sài thành
#  Mở rộng phim mới: Giữa hai bờ thiện ác
#  Crawling person: Quốc Huy diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khắc Duy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tiến Thành
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mi Minh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Thy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phương Ngân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Jayvee Mai Thế Hiệp
# Bỏ qua 'Phim đã tham gia' (không phải bảng wikitable)
# Bỏ qua 'Đạo diễn' (không phải bảng wikitable)
#  Crawling person: Trần Trung Lĩnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Annie Huỳnh Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Bùi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Johnny Trí Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Yaya Trương Nhi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Tưởng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thân Thúy Hà
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Diệp
#  Mở rộng phim mới: Người bí ẩn
#  Mở rộng phim mới: Bước nhảy ngàn cân
#  Crawling person: Mai Thế Hiệp
# Bỏ qua 'Phim đã tham gia' (không phải bảng wikitable)
# Bỏ qua 'Đạo diễn' (không phải bảng wikitable)
#  Crawling person: Hùng Cửu Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Sáp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thu Trang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tiểu Bảo Quốc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Khâm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoài Minh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đạt Doremon
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quốc Tân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thụy Mười
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hạ Vi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: 365daband
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Võ Ngọc Trai
#  Mở rộng phim mới: Kính vạn hoa: Bắt đền con ma
#  Crawling person: ST Sơn Thạch
# Bỏ qua '2016–2018: Dấu ấn tại các chương trình truyền hình' (không phải bảng wikitable)
# Bỏ qua '2019: Thay đổi nghệ danh và giải thưởng quốc tế đầu tiên' (không phải bảng wikitable)
# Bỏ qua '2020–2023: Mở rộng hoạt động nghệ thuật' (không phải bảng wikitable)
# Bỏ qua '2024–2025: Sự nghiệp cá nhân để lại nhiều dấu ấn' (không phải bảng wikitable)
#  Crawling person: Jun Phạm
# Bỏ qua 'Phim truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Phim ngắn' (không phải bảng wikitable)
#  Mở rộng phim mới: 100 ngày bên em (phim điện ảnh)
#  Crawling person: Thành Lộc
#  Mở rộng phim mới: Đất khổ
#  Mở rộng phim mới: Nụ hôn thần chết
#  Mở rộng phim mới: Lời nguyền huyết ngải
#  Mở rộng phim mới: Lạc giới
#  Mở rộng phim mới: Ma da (phim)
#  Crawling person: Hồng Vân diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Diễm My 9x
#  Crawling person: Diễm My
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Oanh Kiều
#  Mở rộng phim mới: Bán chồng
#  Mở rộng phim mới: Gia đình là số 1
#  Crawling person: Tùng Leo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hải Triều
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kaylee Hwang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Tú
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thúy Vy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thủy Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trác Thúy Miêu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hà Trúc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vũ Hà Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Aaron Toronto
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bùi Thị Mỹ Cảnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Khanh
# Bỏ qua 'Phim điện ảnh' (không phải bảng wikitable)
# Bỏ qua 'Phim truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Phim chiếu mạng' (không phải bảng wikitable)
# Bỏ qua 'Phim Video' (không phải bảng wikitable)
# Bỏ qua 'MV' (không phải bảng wikitable)
#  Crawling person: Lê Xuân Tiền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bình An diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khương Lê
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Dũng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Khánh
#  Mở rộng phim mới: Độc thân tuổi 30
#  Mở rộng phim mới: Gái già lắm chiêu V
#  Crawling person: Huỳnh Kiến An
#  Crawling person: Anh Dũng diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hạnh Thúy
#  Crawling person: Sĩ Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trang Hý
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Trân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: TyhD Thùy Dương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Cao Thiên Trang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Cao Ngân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Chánh Tín
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Văn Đây
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Stephane Gauger
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: David Minetti
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quốc Cường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Anh Tuấn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Phúc diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lâm Minh Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Thế Vinh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đặng Trung Tuấn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lý Anh Kiệt
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Hữu Phúc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Điền Thái Minh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Alain Bruxelles
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: François de la Torre
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thomas Michel Meyer
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Rémi Recher
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Yann Williot
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Jérôme
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Huỳnh Kim Sang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tawny Trúc Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Bảo Sơn
# Bỏ qua 'Truyền hình' (không phải bảng wikitable)
#  Mở rộng phim mới: Đoạt hồn
#  Mở rộng phim mới: Đập cánh giữa không trung
#  Mở rộng phim mới: Những đứa con của làng
#  Crawling person: Phan Thị Mơ
#  Mở rộng phim mới: Hoa hồng thép
#  Crawling person: Lê Thiện
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thịnh Vinh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Roger Yuan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bé Ben Nguyễn Hoàng Quân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Phát
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Jason Ninh Cao
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mỹ Lệ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kiều Mai Lý
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Diễm Trinh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Quang Hiếu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tiko Tiến Công
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Will
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chí Tâm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bạch Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Lan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bá Đức
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chị Thu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bé Khanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bé Dâu Tây
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phước Tính
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đông Sương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Giang Kim Chung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bích Hợp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Chi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Sương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Hồng Hậu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vương Cao Hải Lam
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Tấn Hải
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phan Lê Quốc Thanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Liên Bỉnh Phát
#  Crawling person: Tú Quyên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kiều Trinh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nghệ sĩ ưu tú
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khánh Như
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khả Ngân
#  Crawling person: Mai Cát Vy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phan Thanh Nhiên
#  Crawling person: Phạm Anh Khoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Pom
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Bình diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thạch Kim Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vỹ Hoàng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hai Phượng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Taekwondo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Huỳnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thạch Thảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trung Ruồi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Thắng
# Bỏ qua 'Phim truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Phim điện ảnh' (không phải bảng wikitable)
# Bỏ qua 'Truyền hình' (không phải bảng wikitable)
# Bỏ qua 'Quảng cáo' (không phải bảng wikitable)
#  Crawling person: Hoàng Phi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trung Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Nghị
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đồng Ánh Quỳnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tóc Tiên ca sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Rima Thanh Vy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thuận Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Gi A Nguyễn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phan Thanh Hiền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Thị Thanh Hoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Mai MC
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Công Tuấn Anh
# Bỏ qua '1985–1989: Khởi đầu với Đoàn kịch nói Kim Cương và các vai diễn điện ảnh' (không phải bảng wikitable)
# Bỏ qua '1990–1996: Thành công với ''Vị đắng tình yêu'' và các vai diễn sau đó' (không phải bảng wikitable)
#  Crawling person: Lê Tuấn Anh diễn viên sinh 1968
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Chung Vũ Thanh Uyên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Vy
# Bỏ qua 'Sân khấu' (không phải bảng wikitable)
#  Mở rộng phim mới: Vòng xoáy tình yêu
#  Mở rộng phim mới: Áo lụa Hà Đông (phim)
#  Mở rộng phim mới: Trăng nơi đáy giếng
#  Crawling person: Thùy Liên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vân Sơn nghệ sĩ hài
# ...
#  Crawling person: Lưu Mạnh Dũng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Can Đình Đình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Uy Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Hồng Quang diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Vũ Hải Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thúy Ngà
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Lan Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trương Thương Huyền
#  Crawling person: Ngô Quang Hải
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thế Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Lư
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bùi Đại Lượng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đỗ Hữu Thiện
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thu Hà diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Vân -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Quí -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vũ Đình Thân
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Mùi cỏ cháy
#  Crawling person: Thanh Tâm -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Trung -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Quân -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Việt Bắc -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Bích diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đỗ Vân -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Tuất -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bùi Văn Huệ -
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thúy Loan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Vĩnh Xương
#  Crawling person: Hoàng Lan diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phạm Hồng Minh diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vũ Mai Huê
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Anh Quân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngọc Thủy
#  Crawling person: Phạm Bằng
# extract_films_from_subsection: Section không có heading cấp 3
#  Mở rộng phim mới: Ngày hè sôi động
#  Crawling person: Nguyễn Bích Ngọc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Thị Tần
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Cường Túc
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tuấn Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thanh Hương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Nhân Hậu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hiền Vi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tạ Đình Đoàn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thu Hằng nghệ sĩ chèo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Duy Thanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Thùy Liên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Thu Hiền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vũ Thủy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Cường Việt
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Huyền Thanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phạm Dương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trương Việt Thường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Võ sư Khắc Trịnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngô Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Quan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Vịnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Võ sư Sỹ Lai
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kiên Trung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Oanh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hà Phương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ngô Xuân An
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Hà
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Cao Sang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tâm Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Văn Thái
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phí Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thân Thanh Giang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Chương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồ Quốc Phong
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Duy Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hà Hoàng Hiệp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đới Thành An
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Đại Mý
#  Crawling person: Hương Ly
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Chung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phạm Ngọc Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Khắc Trịnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đức Kiên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoài Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Phương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Bình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thúy Mùi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Hòa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Cúc diễn viên
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Châu Sa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bé Hồng Nhung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Việt Dũng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Lê
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Ái Châu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đường Minh Giang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Hồ Lan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Lâm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng Nhuận Cầm
#  Crawling person: Tuyết Hoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thương Hà
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trung Quân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quyết Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoa hậu Vân Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Giang Còi
# Bỏ qua 'Phim' (không phải bảng wikitable)
# Bỏ qua 'Tạp kĩ' (không phải bảng wikitable)
# Bỏ qua 'Dẫn chương trình' (không phải bảng wikitable)
#  Crawling person: Minh Phong
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bùi Xuân Thảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Linh Vân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Diệu Thảo
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồ Tháp
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Thị Loan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phan Đăng Lưu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Trọng Hùng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Đoàn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Linh Miu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quốc Triệu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tiến Đại
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hùng võ sư
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quốc Lâm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Nhật Anh Thư
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Vũ Minh Hiền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mã Văn Thắng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đào Lê Duy Hòa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Hoa ca sĩ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Bộ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trịnh Nhật
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Quang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSND Bạch Diện
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tiến Bình
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quang Huy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Thu Bảy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mạnh Quyền
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Thanh Thủy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hoàng San
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hữu Dũng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Kiểm
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Duyệt
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đức Hoàn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Kim Tuyến
# Bỏ qua 'MV đã tham gia' (không phải bảng wikitable)
#  Crawling person: Văn Triệu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Như Quỳnh (diễn viên)
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Văn Sang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Quỳnh Hoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Việt An
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đặng Loan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mi Hai
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Tuyết Mai
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: NSƯT Sơn Đồng
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phanh Lee
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Duy Long
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Anh Tuấn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Đỗ Bạch Diện
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Phạm Tuấn Quang
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bùi Bá Thiện
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thiên Anh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Việt Dương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lưu Đê Ly Ly Ba Lan
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Bảo Kỳ
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Tuấn Phong
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trịnh Mai
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Xuân Phương
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Linh Nga
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Thế Tục
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hùng Bống
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Duy Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Hiếu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Tâm Cường
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Văn
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Mai Hạnh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lâm Thùy Linh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Linh Phi
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Kiều Trinh
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Quang Vân
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Hiếu
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Trần Nam Khoa
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lan Thy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Lê Anh Huy
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Nguyễn Văn Chung
# extract_films_from_subsection: Section không có heading cấp 3
#  Crawling person: Hồng Tài
# extract_films_from_subsection: Section không có heading cấp 3
# Mở rộng hoàn tất.

# %%
from typing import List

from pyparsing import Dict


def clean_text(text: str) -> str:
    """Làm sạch text, loại bỏ markup và templates"""
    if not text or not isinstance(text, str):
        return ""
    
    # Loại bỏ HTML tags
    text = re.sub(r'<br\s*/?>', ', ', text)
    text = re.sub(r'<ref[^>]*>.*?</ref>', '', text, flags=re.DOTALL | re.IGNORECASE)
    text = re.sub(r'<ref[^>]*/?>', '', text)
    text = re.sub(r'<[^>]+>', '', text)
    
    # Loại bỏ Wikipedia links [[link|text]] -> text
    text = re.sub(r'\[\[([^\]|]+)\|([^\]]+)\]\]', r'\2', text)
    text = re.sub(r'\[\[([^\]]+)\]\]', r'\1', text)
    
    # Loại bỏ external links
    text = re.sub(r'\[https?://[^\s\]]+ ([^\]]+)\]', r'\1', text)
    text = re.sub(r'\[https?://[^\]]+\]', '', text)
    
    # Loại bỏ comments
    text = re.sub(r'<!--.*?-->', '', text, flags=re.DOTALL)
    
    # Xử lý templates {{...}}
    while '{{' in text:
        match = re.search(r'\{\{([^{}]+)\}\}', text)
        if not match:
            break
        
        template_content = match.group(1)
        replacement = parse_template(template_content)
        text = text[:match.start()] + str(replacement) + text[match.end():]
    
    # Clean up whitespace
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\s*,\s*,\s*', ', ', text)
    text = text.strip(' ,')
    
    return text


def parse_template(template_str: str) -> str:
    """Parse Wikipedia template"""
    if not template_str:
        return ""
    
    parts = [p.strip() for p in template_str.split('|')]
    template_name = parts[0].lower()
    params = parts[1:] if len(parts) > 1 else []
    
    country_codes = {
        'vie': 'Việt Nam',
        'us': 'Hoa Kỳ',
        'nor': 'Na Uy'
    }
    
    if any(keyword in template_name for keyword in ['ngày sinh', 'năm sinh', 'birth date', 'birth year']):
        return parse_birth_date(params)
    elif template_name == 'marriage':
        return parse_marriage(params)
    elif template_name in ['hlist', 'ubl', 'plainlist']:
        return parse_list(params)
    elif template_name == 'convert':
        return parse_convert(params)
    elif template_name == 'height':
        return parse_height(params)
    elif template_name == 'small':
        return f"({params[0]})" if params else ""
    elif template_name in country_codes:
        return country_codes[template_name]
    elif template_name in ['chú thích', 'citation', 'cite']:
        return ""
    
    return ', '.join(params) if params else ""


def parse_birth_date(params: List[str]) -> str:
    try:
        numbers = []
        for p in params:
            matches = re.findall(r'\d+', p)
            numbers.extend(matches)
        
        if len(numbers) >= 3:
            year, month, day = numbers[0], numbers[1], numbers[2]
            return f"{year}-{month.zfill(2)}-{day.zfill(2)}"
        elif len(numbers) >= 1:
            return numbers[0]
    except Exception:
        pass
    return ""


def parse_marriage(params: List[str]) -> str:
    if not params:
        return ""
    spouse = clean_text(params[0])
    if len(params) > 1:
        year_match = re.search(r'\d{4}', params[1])
        if year_match:
            return f"{spouse} ({year_match.group()})"
    return spouse


def parse_list(params: List[str]) -> str:
    items = []
    for param in params:
        cleaned = clean_text(param)
        if cleaned and cleaned not in ['', ' ']:
            items.append(cleaned)
    return ', '.join(items)


def parse_convert(params: List[str]) -> str:
    try:
        value = params[0] if params else ""
        unit = params[1] if len(params) > 1 else ""
        value = re.sub(r'[^\d.,]', '', value)
        if 'm' in unit.lower():
            return f"{value}m"
        return f"{value}"
    except Exception:
        return ""


def parse_height(params: List[str]) -> str:
    for param in params:
        if 'm=' in param:
            height = param.split('=')[1]
            return f"{height}m"
    return ""


def parse_person_info(info_dict: Dict) -> Dict:
    
    if not info_dict:
        return {}
    
    field_mapping = {
        'tên': 'name',
        'name': 'name',
        'tên khai sinh': 'birth_name',
        'tên khác': 'other_names',
        'alias': 'alias',
        'ngày sinh': 'birth_date',
        'birth_date': 'birth_date',
        'nơi sinh': 'birth_place',
        'birth_place': 'birth_place',
        'quốc tịch': 'nationality',
        'dân tộc': 'ethnicity',
        'nghề nghiệp': 'occupation',
        'công việc': 'occupation',
        'occupation': 'occupation',
        'năm hoạt động': 'active_years',
        'năm hoạt động điện ảnh': 'active_years',
        'chiều cao': 'height',
        'học vấn': 'education',
        'education': 'education',
        'người hôn phối': 'spouse',
        'spouse': 'spouse',
        'con cái': 'children',
        'người thân': 'relatives',
        'tác phẩm nổi bật': 'notable_works',
        'hình': 'image',
        'image': 'image'
    }
    
    parsed = {}
    
    for key, value in info_dict.items():
        # Bỏ qua các trường không cần
        if key in ['ghi chú hình', 'signature', 'giải thưởng']:
            continue
        
        field_name = field_mapping.get(key, key)
        parsed_value = clean_text(str(value))
        
        if parsed_value:
            parsed[field_name] = parsed_value
    
    return parsed


def parse_persons_data(persons_data: Dict) -> Dict:
    
    parsed_persons = {}
    
    for person_name, person_data in persons_data.items():
        # Parse info
        raw_info = person_data.get('info', {})
        parsed_info = parse_person_info(raw_info)
        
        # Giữ nguyên films list
        films = person_data.get('films', [])
        
        parsed_persons[person_name] = {
            'info': parsed_info,
            'films': films
        }
    
    return parsed_persons


def parse_film_info(infobox_dict: Dict) -> Dict:
    
    if not infobox_dict:
        return {}
    
    field_mapping = {
        'tên phim': 'title',
        'tựa đề': 'title',
        'năm phát hành': 'year',
        'năm': 'year',
        'thể loại': 'genre',
        'đạo diễn': 'director',
        'diễn viên': 'cast',
        'nhà sản xuất': 'producer',
        'thời lượng': 'duration',
        'quốc gia': 'country',
        'ngôn ngữ': 'language',
        'kinh phí': 'budget',
        'doanh thu': 'box_office'
    }
    
    parsed = {}
    
    for key, value in infobox_dict.items():
        # Bỏ qua các trường không cần
        if key in ['hình', 'ghi chú hình']:
            continue
        
        field_name = field_mapping.get(key.lower(), key)
        parsed_value = clean_text(str(value))
        
        if parsed_value:
            parsed[field_name] = parsed_value
    
    return parsed


def parse_films_data(films_data: Dict) -> Dict:
    
    parsed_films = {}
    
    for film_name, film_data in films_data.items():
        try:
            # Parse infobox
            raw_infobox = film_data.get('infobox', {})
            if raw_infobox is None:
                raw_infobox = {}
            parsed_infobox = parse_film_info(raw_infobox)
            
            # Parse actors (clean character names)
            actors = film_data.get('actors', [])
            if actors is None:
                actors = []
            
            parsed_actors = []
            for actor in actors:
                if isinstance(actor, dict):
                    parsed_actor = {
                        'actor_name': actor.get('actor_name', ''),
                        'character': clean_text(str(actor.get('character', ''))) if actor.get('character') else ''
                    }
                    parsed_actors.append(parsed_actor)
            
            # Parse director (clean names) - XỬ LÝ TẤT CẢ TRƯỜNG HỢP
            directors = film_data.get('director', [])
            parsed_directors = []
            
            if directors is None:
                # Nếu là None, để list rỗng
                parsed_directors = []
            elif isinstance(directors, str):
                # Nếu là string đơn lẻ
                cleaned = clean_text(directors)
                if cleaned:
                    parsed_directors = [cleaned]
            elif isinstance(directors, list):
                # Nếu là list
                for d in directors:
                    if d is not None:
                        # Có thể là dict hoặc string
                        if isinstance(d, dict):
                            director_name = d.get('director_name', '')
                        else:
                            director_name = str(d)
                        
                        cleaned = clean_text(director_name)
                        if cleaned:
                            parsed_directors.append(cleaned)
            
            parsed_films[film_name] = {
                'title': film_data.get('title', film_name),
                'infobox': parsed_infobox,
                'actors': parsed_actors,
                'director': parsed_directors
            }
            
        except Exception as e:
            print(f"⚠️  Lỗi khi parse phim '{film_name}': {e}")
            # Vẫn thêm phim nhưng với dữ liệu tối thiểu
            parsed_films[film_name] = {
                'title': film_name,
                'infobox': {},
                'actors': [],
                'director': []
            }
    
    return parsed_films



persons_data = parse_persons_data(persons_data)
films_info = parse_films_data(films_info)

import networkx as nx

# xay do thi 2 phia: nguoi va phim
def build_bipartite_graph(persons_data, films_data):
    
    B = nx.Graph()

    # Thêm diễn viên / đạo diễn
    for person_name, person_data in persons_data.items():
        B.add_node(person_name, type='person', info=person_data.get('info', {}))

    # Thêm phim
    for film_name, film_data in films_data.items():
        B.add_node(film_name, type='film', infobox=film_data.get('infobox', {}))

    # Thêm các cạnh
    actor_edges = 0
    director_edges = 0

    for film_name, film_data in films_data.items():
        # dien vien
        actors = film_data.get('actors', [])  # Lấy danh sách actors một lần
        
        for cast_member in actors:
            # XỬ LÝ CẤU TRÚC LỒNG NHAU
            
            # Trường hợp 1: cast_member là list chứa dict
            if isinstance(cast_member, list):
                for item in cast_member:
                    if isinstance(item, dict):
                        actor_name = item.get('actor_name')
                        character = item.get('character', '')
                        
                        if actor_name and actor_name.strip():
                            actor_name = actor_name.strip()
                            if actor_name in B.nodes:
                                B.add_edge(actor_name, film_name, 
                                         role='actor', 
                                         character=character)
                                actor_edges += 1
                    
                    elif isinstance(item, str):
                        # List chứa string
                        actor_name = item.strip()
                        if actor_name and actor_name in B.nodes:
                            B.add_edge(actor_name, film_name, 
                                     role='actor', 
                                     character='')
                            actor_edges += 1
            
            # Trường hợp 2: cast_member là dict trực tiếp
            elif isinstance(cast_member, dict):
                actor_name = cast_member.get('actor_name')
                character = cast_member.get('character', '')
                
                if actor_name and actor_name.strip():
                    actor_name = actor_name.strip()
                    if actor_name in B.nodes:
                        B.add_edge(actor_name, film_name, 
                                 role='actor', 
                                 character=character)
                        actor_edges += 1
            
            # Trường hợp 3: cast_member là string
            elif isinstance(cast_member, str):
                actor_name = cast_member.strip()
                if actor_name and actor_name in B.nodes:
                    B.add_edge(actor_name, film_name, 
                             role='actor',  
                             character='')
                    actor_edges += 1

        # dao dien
        director = film_data.get('director')
        if director:
            # co the la str hoac list
            if isinstance(director, str):
                directors = [director]
            elif isinstance(director, list):
                directors = director
            else:
                directors = []

            for dir_name in directors:
                if dir_name and dir_name in B.nodes:
                    B.add_edge(dir_name, film_name, role='director')
                    director_edges += 1

    print(f"Graph built successfully: {B.number_of_nodes()} nodes, {B.number_of_edges()} edges.")
    print(f"{actor_edges} actor edges, {director_edges} director edges.")

    return B

# Sử dụng
B = build_bipartite_graph(persons_data, films_info)
# Out:
# Graph built successfully: 3629 nodes, 8166 edges.
# 8079 actor edges, 148 director edges.

# %%
import networkx as nx
from collections import defaultdict
# xay do thi mqh giua nguoi va nguoi
def build_collaboration_graph(bipartite_graph):
   
    G = nx.Graph()

    # Lấy danh sách người
    people = [n for n, attr in bipartite_graph.nodes(data=True) if attr['type'] == 'person']

    # Thêm nút người
    for person in people:
        G.add_node(person, **bipartite_graph.nodes[person])

    # Dùng defaultdict để lưu thông tin hợp tác
    collaborations = {}

    # Duyệt qua từng phim trong đồ thị hai phía
    films = [n for n, attr in bipartite_graph.nodes(data=True) if attr['type'] == 'film']

    for film in films:
        # Lấy tất cả người tham gia phim đó
        film_people = [n for n in bipartite_graph.neighbors(film) if bipartite_graph.nodes[n]['type'] == 'person']

        # Tạo cặp hợp tác giữa các người cùng tham gia phim
        for i in range(len(film_people)):
            for j in range(i + 1, len(film_people)):
                p1, p2 = sorted([film_people[i], film_people[j]])
                if (p1, p2) not in collaborations:
                    collaborations[(p1, p2)] = {
                        'weight': 0,
                        'films': [],
                        'roles': [],
                        'same school': False,
                        'school': None,
                        'same location': False,
                        'location': None
                    }
                role1 = bipartite_graph[p1][film]['role']
                role2 = bipartite_graph[p2][film]['role']

                collaborations[(p1, p2)]['weight'] += 1
                collaborations[(p1, p2)]['films'].append(film)
                collaborations[(p1, p2)]['roles'].append(f"{role1}-{role2}")
                
    # them quan he cung truong, cung que
    for i in range(len(people)):
        for j in range(i + 1, len(people)):
            p1, p2 = sorted([people[i], people[j]])
            
            # Lấy thông tin của 2 người
            info1 = bipartite_graph.nodes[p1].get('info', {})
            info2 = bipartite_graph.nodes[p2].get('info', {})
            
            # Kiểm tra cùng trường
            school1 = info1.get('education') or info1.get('học vấn')
            school2 = info2.get('education') or info2.get('học vấn')
            
            same_school = False
            school_name = None
            if school1 and school2:
                school1 = school1.strip()
                school2 = school2.strip()
                if school1 == school2:
                    same_school = True
                    school_name = school1
            
            # Kiểm tra cùng quê
            loc1 = info1.get('birth_place') or info1.get('nơi sinh')
            loc2 = info2.get('birth_place') or info2.get('nơi sinh')
            
            same_location = False
            location_name = None
            if loc1 and loc2:
                loc1 = loc1.strip()
                loc2 = loc2.strip()
                if loc1 == loc2:
                    same_location = True
                    location_name = loc1
            
            # Nếu có bất kỳ quan hệ nào
            if same_school or same_location or (p1, p2) in collaborations:
                # Khởi tạo nếu chưa có (trường hợp chỉ cùng trường/quê, không cùng phim)
                if (p1, p2) not in collaborations:
                    collaborations[(p1, p2)] = {
                        'weight': 0,
                        'films': [],
                        'roles': [],
                        'same_school': False,
                        'school': None,
                        'same_location': False,
                        'location': None
                    }
                
                # Cập nhật thông tin
                if same_school:
                    collaborations[(p1, p2)]['same_school'] = True
                    collaborations[(p1, p2)]['school'] = school_name
                
                if same_location:
                    collaborations[(p1, p2)]['same_location'] = True
                    collaborations[(p1, p2)]['location'] = location_name

    # 7. Thêm edges vào graph
    for (p1, p2), data in collaborations.items():
        weight = 0
        film_count = data.get('weight', 0)
        weight += film_count
        if data.get('same_school'):
            weight += 0.5
        if data.get('same_location'):
            weight += 0.3
        
        G.add_edge(
            p1, p2,
            film_count=data.get('weight', 0),
            films=data.get('films', []),
            collaboration_types=list(set(data.get('roles', []))),
            same_school=data.get('same_school', False),
            school=data.get('school'),
            same_location=data.get('same_location', False),
            location=data.get('location'),
            weight=weight  
        )

    return G

G_bipartite = build_bipartite_graph(persons_data, films_info)
G_actor_collab = build_collaboration_graph(G_bipartite)
print(f"Số nút trong đồ thị cộng tác diễn viên: {G_actor_collab.number_of_nodes()}")
print(f"Số cạnh trong đồ thị cộng tác diễn viên: {G_actor_collab.number_of_edges()}")
print(f"So node trong do thi bipartite: {G_bipartite.number_of_nodes()}")
print(f"So canh trong do thi bipartite: {G_bipartite.number_of_edges()}")
# Out:
# Graph built successfully: 3629 nodes, 8166 edges.
# 8079 actor edges, 148 director edges.
# Số nút trong đồ thị cộng tác diễn viên: 2985
# Số cạnh trong đồ thị cộng tác diễn viên: 84418
# So node trong do thi bipartite: 3629
# So canh trong do thi bipartite: 8166
